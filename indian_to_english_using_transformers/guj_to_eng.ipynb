# %%
from google.colab import drive
import json
import pickle
import math
import numpy as np
import pandas as pd
import spacy
from collections import Counter
import torch
import torchtext
import torch.nn as nn
import torch.optim as optim
from torch import Tensor
import random
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torchtext.vocab import vocab
from torch.nn import TransformerEncoder, TransformerDecoder, TransformerEncoderLayer, TransformerDecoderLayer
import io
import time

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/train_data2.json', 'r') as file:
    data = json.load(file)

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/Test_data2_final.json', 'r') as file:
    test_data = json.load(file)

# %%
import string

# Define the remove_punctuations function
def remove_punctuations(sentence):
    punctuations = list(string.punctuation)
    cleaned = ""
    for letter in sentence:
        if letter not in punctuations:
            cleaned += letter
    return cleaned

# %%
# Process JSON data
source_sentences_train = []
target_sentences_train = []
len_gujarati = []
len_english = []

id_train = []

for language_pair, language_data in data.items():
    if(language_pair == "English-Gujarati"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              target = entry_data["target"].lower()
              source = remove_punctuations(source)
              target = remove_punctuations(target)
              source_sentences_train.append(source)
              target_sentences_train.append(target)
              id_train.append(entry_id)
              len_gujarati.append(len(source.split(' ')))
              len_english.append(len(target.split(' ')))
# Out:
# Language Pair: English-Gujarati
#   Data Type: Train

# %%
test_source = []
valid_id = []
len_val=[]


for language_pair, language_data in test_data.items():
    if(language_pair == "English-Gujarati"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              source = remove_punctuations(source)
              test_source.append(source)
              valid_id.append(entry_id)
              len_val.append(len(source.split(' ')))
# Out:
# Language Pair: English-Gujarati
#   Data Type: Test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Calculate the maximum length of gujarati and English sentences
max_length_gujarati = max(len_gujarati)
max_length_english = max(len_english)

print(f"Maximum Length of gujarati Sentence: {max_length_gujarati} words")
print(f"Maximum Length of English Sentence: {max_length_english} words")
# Out:
# Maximum Length of gujarati Sentence: 80 words
# Maximum Length of English Sentence: 81 words

# %%
pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 38.3 MB/s eta 0:00:00
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.13.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2023.7.22)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.3.0 sphinxcontrib-jquery-4.1

# %%
from indicnlp.tokenize import indic_tokenize
# Tokenize gujarati sentences
tokenized_source_sentences = []
for sentence in source_sentences_train:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tokenized_source_sentences.append(tokens)

# %%
tok_val=[]
for sentence in test_source:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tok_val.append(tokens)

# %%
# Tokenize English sentences
nlp_en = spacy.load('en_core_web_sm')
tokenized_target_sentences = []
for sentence in target_sentences_train:
    doc = nlp_en(sentence)
    tokens = [token.text for token in doc]
    tokenized_target_sentences.append(tokens)

# %%
def build_vocab(tokenized_sentences):
    counter = Counter()
    for sentence in tokenized_sentences:
        counter.update(sentence)
    v = vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'], min_freq=1)
    return v

# Build source and target vocabularies
source_vocab = build_vocab(tokenized_source_sentences)
target_vocab = build_vocab(tokenized_target_sentences)

# %%
print(len(source_vocab))
# Out:
# 85844

# %%
def data_process(tokenized_source, tokenized_target, source_vocab, target_vocab):
    data = []
    for (tokenized_source_sentence, tokenized_target_sentence) in zip(tokenized_source, tokenized_target):
        source_tensor = torch.tensor([source_vocab[token] for token in tokenized_source_sentence],
                                     dtype=torch.long)
        target_tensor = torch.tensor([target_vocab[token] for token in tokenized_target_sentence],
                                     dtype=torch.long)
        data.append((source_tensor, target_tensor))
    return data

# Process the data
train_data = data_process(tokenized_source_sentences, tokenized_target_sentences, source_vocab, target_vocab)

# %%
batch_size = 32
pad_idx = source_vocab['<pad>']
bos_idx = source_vocab['<bos>']
eos_idx = source_vocab['<eos>']

def generate_batch(data_batch):
  source_batch, target_batch = [], []
  for (source_item, target_item) in data_batch:
    source_batch.append(torch.cat([torch.tensor([bos_idx]), source_item, torch.tensor([eos_idx])], dim=0))
    target_batch.append(torch.cat([torch.tensor([bos_idx]), target_item, torch.tensor([eos_idx])], dim=0))
  source_batch = pad_sequence(source_batch, padding_value=pad_idx)
  target_batch = pad_sequence(target_batch, padding_value=pad_idx)
  return source_batch, target_batch

train_iter = DataLoader(train_data, batch_size=batch_size,shuffle=True, collate_fn=generate_batch)

# %%
class Seq2SeqTransformer(nn.Module):
    def __init__(self, num_encoder_layers: int, num_decoder_layers: int, emb_size: int, src_vocab_size: int, tgt_vocab_size: int, dim_feedforward:int = 512, dropout:float = 0.1):
        super(Seq2SeqTransformer, self).__init__()
        encoder_layer = TransformerEncoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_encoder = TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        decoder_layer = TransformerDecoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_decoder = TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(emb_size, dropout=dropout)

    def forward(self, src: Tensor, trg: Tensor, src_mask: Tensor, tgt_mask: Tensor, src_padding_mask: Tensor, tgt_padding_mask: Tensor, memory_key_padding_mask: Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        memory = self.transformer_encoder(src_emb, src_mask, src_padding_mask)
        outs = self.transformer_decoder(tgt_emb, memory, tgt_mask, None, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer_encoder(self.positional_encoding(self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer_decoder(self.positional_encoding(self.tgt_tok_emb(tgt)), memory, tgt_mask)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, emb_size: int, dropout, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2) * math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0),:])

class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size
    def forward(self, tokens: Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)

# %%
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=DEVICE)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt):
  src_seq_len = src.shape[0]
  tgt_seq_len = tgt.shape[0]

  tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
  src_mask = torch.zeros((src_seq_len, src_seq_len), device=DEVICE).type(torch.bool)

  src_padding_mask = (src == pad_idx).transpose(0, 1)
  tgt_padding_mask = (tgt == pad_idx).transpose(0, 1)
  return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
src_vocab_size = len(source_vocab)
tgt_vocab_size = len(target_vocab)
emb_size = 512
nhead = 8
ffn_hid_dim = 512
num_encoder_layers = 3
num_decoder_layers = 3
num_epochs = 40
transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers, emb_size, src_vocab_size, tgt_vocab_size, ffn_hid_dim)

for p in transformer.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

transformer = transformer.to(device)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=pad_idx)

optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
def train_epoch(model, train_iter, optimizer):
  model.train()
  losses = 0
  for idx, (src, tgt) in enumerate(train_iter):
      src = src.to(device)
      tgt = tgt.to(device)
      tgt_input = tgt[:-1, :]
      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)
      logits = model(src, tgt_input, src_mask, tgt_mask, src_padding_mask, tgt_padding_mask, src_padding_mask)
      optimizer.zero_grad()
      tgt_out = tgt[1:,:]
      loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
      loss.backward()
      optimizer.step()
      losses += loss.item()
  return losses / len(train_iter)

# %%
for epoch in range(1, num_epochs+1):
  start_time = time.time()
  train_loss = train_epoch(transformer, train_iter, optimizer)
  end_time = time.time()
  print((f"Epoch: {epoch}, Train loss: {train_loss:.3f}, "f"Epoch time = {(end_time - start_time):.3f}s"))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 6.743, Epoch time = 180.541s
# Epoch: 2, Train loss: 5.980, Epoch time = 180.193s
# Epoch: 3, Train loss: 5.582, Epoch time = 180.590s
# Epoch: 4, Train loss: 5.228, Epoch time = 180.358s
# Epoch: 5, Train loss: 4.913, Epoch time = 180.377s
# Epoch: 6, Train loss: 4.622, Epoch time = 180.419s
# Epoch: 7, Train loss: 4.355, Epoch time = 181.105s
# Epoch: 8, Train loss: 4.107, Epoch time = 180.250s
# Epoch: 9, Train loss: 3.876, Epoch time = 181.161s
# Epoch: 10, Train loss: 3.661, Epoch time = 180.965s
# Epoch: 11, Train loss: 3.462, Epoch time = 181.556s
# Epoch: 12, Train loss: 3.275, Epoch time = 181.079s
# Epoch: 13, Train loss: 3.103, Epoch time = 180.747s
# Epoch: 14, Train loss: 2.939, Epoch time = 180.377s
# Epoch: 15, Train loss: 2.789, Epoch time = 180.831s
# Epoch: 16, Train loss: 2.647, Epoch time = 181.451s
# Epoch: 17, Train loss: 2.513, Epoch time = 181.192s
# Epoch: 18, Train loss: 2.389, Epoch time = 180.563s
# Epoch: 19, Train loss: 2.276, Epoch time = 180.676s
# Epoch: 20, Train loss: 2.180, Epoch time = 180.325s
# Epoch: 21, Train loss: 2.097, Epoch time = 181.030s
# Epoch: 22, Train loss: 2.028, Epoch time = 180.054s
# Epoch: 23, Train loss: 1.974, Epoch time = 180.601s
# Epoch: 24, Train loss: 1.919, Epoch time = 180.490s
# Epoch: 25, Train loss: 1.860, Epoch time = 180.423s
# Epoch: 26, Train loss: 1.797, Epoch time = 180.773s
# Epoch: 27, Train loss: 1.740, Epoch time = 180.589s
# Epoch: 28, Train loss: 1.683, Epoch time = 180.733s
# Epoch: 29, Train loss: 1.633, Epoch time = 180.723s
# Epoch: 30, Train loss: 1.584, Epoch time = 180.513s
# Epoch: 31, Train loss: 1.537, Epoch time = 180.200s
# Epoch: 32, Train loss: 1.494, Epoch time = 180.454s
# Epoch: 33, Train loss: 1.454, Epoch time = 180.363s
# Epoch: 34, Train loss: 1.417, Epoch time = 180.604s
# Epoch: 35, Train loss: 1.384, Epoch time = 180.612s
# Epoch: 36, Train loss: 1.350, Epoch time = 180.329s
# Epoch: 37, Train loss: 1.322, Epoch time = 180.917s
# Epoch: 38, Train loss: 1.294, Epoch time = 181.289s
# Epoch: 39, Train loss: 1.271, Epoch time = 181.216s
# Epoch: 40, Train loss: 1.249, Epoch time = 180.552s

# %%
torch.save(transformer.state_dict(), 'inference_model')

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol, device):
    src = src.to(device)
    src_mask = src_mask.to(device)
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(device)
    for i in range(max_len-1):
        memory = memory.to(device)
        memory_mask = torch.zeros(ys.shape[0], memory.shape[0]).to(device).type(torch.bool)
        tgt_mask = (generate_square_subsequent_mask(ys.size(0)).type(torch.bool)).to(device)
        out = model.decode(ys, memory, tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()
        ys = torch.cat([ys, torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == eos_idx:
            break
    return ys

# %%
def translate(model, src, src_vocab, tgt_vocab, device):
    model.eval()
    unk_token_idx = src_vocab.get_stoi()['<unk>']

    src_indices = [src_vocab[token] if token in src_vocab else unk_token_idx for token in src]

    tokens = [bos_idx] + src_indices + [eos_idx]
    num_tokens = len(tokens)
    src = torch.LongTensor(tokens).reshape(num_tokens, 1).to(device)

    src_mask = torch.zeros(num_tokens, num_tokens).to(device, dtype=torch.bool)
    tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()

    translated_tokens = [tgt_vocab.get_itos()[idx] if idx != unk_token_idx else '<unk>' for idx in tgt_tokens]

    translated_sentence = " ".join(translated_tokens).replace("<bos>", "").replace("<eos>", "")
    translated_sentence = " ".join(translated_sentence.split())
    return translated_sentence

# %%
print(tokenized_source_sentences[3])
# Out:
# ['જો', 'ચંદ્રગુપ્તએ', 'કર્ણાટકમાં', 'ત્યાગ', 'તરીકે', 'પોતાનું', 'જીવન', 'સમાપ્ત', 'કર્યું', 'તે', 'જૈન', 'પ્રથાને', 'સાચી', 'ગણવામાં', 'આવે', 'તો', 'એવું', 'લાગે', 'છે', 'કે', 'ચંદ્રગુપ્તે', 'દક્ષિણી', 'મુલકગીરીની', 'શરૂઆત', 'કરી', 'હતી']

# %%
# Create an instance of the model
loaded_transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers,
                                       emb_size, src_vocab_size, tgt_vocab_size,
                                       ffn_hid_dim)

# Load the saved state dictionary
loaded_transformer.load_state_dict(torch.load('inference_model'))

# Ensure the model is in evaluation mode
loaded_transformer.eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Seq2SeqTransformer(
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (transformer_decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=45180, bias=True)
#   (src_tok_emb): TokenEmbedding(
#     (embedding): Embedding(85844, 512)
#   )
#   (tgt_tok_emb): TokenEmbedding(
#     (embedding): Embedding(45180, 512)
#   )
#   (positional_encoding): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
print(len(tok_val))
# Out:
# 13567

# %%
english_pred = []
for sentence in tok_val:
  pred = translate(transformer, sentence, source_vocab, target_vocab, DEVICE)
  print(pred)
  english_pred.append(pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# please show my contribution amount of last month in atal pension yojna for pran number the number of last month
# the weight of the child is 2500 gram in last hour
# last week he did several of hundred people into did it work for without breast milk whose out he him she would improve the situation of
# the union territory is only a police party whose leadership affects the police
# the movement of it becomes an extremely difficult person
# he said that the day of the day it will be better to get the entire day
# in the northeast the mughals left assam with the mughals made it by has taken the mughals who left the mughals for
# nearest railway station is so with
# however if the produced in mind should be produced from clothes then this income will have to reduce the income
# although in similar circumstances most of the mughal emperor against the large quantities of his father he lost his father and hence she lost much in his fathers with the rule and so that it was not higher during his father
# the information on hiv and the person also requires any opportunity to handle different aspects of pregnancy and childbirth
# the mizoram valley of mizoram is covered with valleys and ponds
# mrs the old one became very happy with the help of his dreams
# in the same way it is also the center of attraction of nature here
# drinking sunwarmed orange water is appropriate for your health after ten minutes of meals sun rays and chromotherapy after ten minutes through sun rays through chromotherapy and color
# you can get down from the grand canal near the airways in munnar
# over the year completely green manure has made a see outbreak of any over the that the hotel major witness with the the the taj
# after eating the a half masha of to by eating with half an hour juice keeps on taking it in that amount
# also that place the free radicals appeared in the films like a that major a be seen in the films like
# walking on continuously going is public with long interval of royal steps has taken out that another art with
# at initial stage there are included in the entire body and among them one or two joints which are completely distorted to the patient and become weak
# an open way from the food offered to other with was the in by
# also along with this the water farms in the government side effects the irrigation can also be used
# the diagnosis is very difficult to treat some cases
# where the strength of entering the person is beneficial
# just near the royal palace is the would have access by
# one has different joy after the elephant a a a that s seat
# blue oil is very beneficial
# on the other side the news of falling ill of falling ill and again news was also overwhelmed to return of abroad
# he maintained high standards still choose to be popular for business ability to allow him to use in business or to use black market
# the 650 oclock in the building of water storage buildings were built on the road and way
# the cotton textiles should be done with great fanfare
# over the state museum found a longer flat roads in the state but no way to ensure change the climate
# in 2010 the cultivation of wild animal husbandry was totally dependent on the entire country such as contact with average
# crop diseases are harmful for crop
# if you eat healthy and healthy food then you can get benefit from this technique only
# these parts of from the valley of deodar are built in the three parts of the district
# it appears that in the age of 12 90 percent bone marrow on bone marrow grains
# i am trying to find a free vaccine in district with free radicals you can list some a list of that
# the big brother of with the help of at in at in and also received through laughter comes due to the background and also
# due to cataract in the world is seen in the worldwide more than people of
# according to the results later on a more results are likely points
# the change in a permanent place the change of the plant life direct contact with the change is now limited
# this lake is situated in to a such pond in southern mizoram
# scientists have to say that more essential element is also used in order to produce weeds in order to produce the risk of cancer
# then diabetes the name of diabetes was so much that it is salt like him is a honey
# this is why the kingdom of the river takes place
# the enough amount of sexual maturity in the urinary bladder is appropriate at proper time
# however the difference would be able to find a important the without that the title of george had food consumption or cases by ashoka
# finally there was no such decline in the in the sea
# list all the free vaccination centres which provide first dose of corbevax for 18 years or for age group
# historical an area black pepper is surrounded by three distinct areas of flora and fauna
# because of infection and swelling occurs the burning sensation and make the breathing gets formed
# we were moving time too
# however the best place in the act of very happens with 48 seats on the lok sabha
# the snow s cool and dry season has become favorable for the tourists
# only these people are very big pressure force rather than some of their food habits but they going away to their old way
# please call my luggage to take part in an another room for taking luggage
# wild animals found in shri ganesh chaturthi the deer lion peacock wild boar golden monkey lion sambhar in shri they
# the patient should go to toilet daily at equal time and to 10 minutes it should be necessary for its effort
# the most beautiful the were started by start the form of with that each other
# united states 200
# the better quality of work has been accepted by using it as an important crop
# the ancient times has been considered in the form of temples since ancient times
# what is the maximum i can take out from my tripura gramin bank account
# he shifted back before the moment
# in being two months as much time the minimum temperature does not have 2 ° c or more than 2 ° c
# respiration increases your lungs due to which oxygen level increases in the blood
# in july the plant with animal ready plant would be sown in the place of had dried
# the snow starts brown in difficulty
# he has been compared to william to a similar fictional town who created a similar fictional town and likewise became with its with ordinary life and shape
# kumbh mela is built at the same place from the same field
# such methods have been found to be several kinds of methods for the treatment
# more than dry weather after the use of completely avoid transmitted products should be taken away by staying in clean and fresh
# on days after breakfast one s way of 8 am to cut and 5 feet the video of starts about 8 feet per day and has gone on the way of age at 12 kms from on the other side of person
# in spine tumor most common tumor occurs in which cancer occurs due to some other parts of body
# mung bean cow dung manure generally comes into the pieces of onion and color like aroma of sweet potato or fragrance with a variety of botanical garden in before planting it
# it produces a less common and the middle are the use of a simple support
# get from the 9th century till 13th century ad it was known as the history of kerala
# the story of the swang does not happen on one place
# recently pure stands out of land area has been crore tonnes of irrigated
# when the rays of light gets accumulated behind the prostate gland and the elderly are seen in children
# the size of 25 million people living with a high density of in because of hard work
# complete it
# it also is grown on small regions of himachal pradesh punjab and delhi
# greenery as an the seen originally appropriate beauty of meghalaya doctor with an the attractive beauty of meghalaya also has over a place with earth famous all over the world
# the rare situation in the
# it left in the most precious metals including silk products white flour and their respective products such as post is harm to him
# polluted water
# when the pancreas is not able to produce enough if the late pancreas is able to see that a lens starts arising in the blood vessels
# tipu sultan defeated the out of 18 february on 18 february 1940 itself
# difficulty in urination also
# according to school education each year her use of environment water and development has been shown to be beneficial in the study
# traditional savings account also is a good idea of
# the younger brother of so took place in the fruits with the title the well effects of that place and forced the military arrangements
# water is usually infected by the bottle of the pond or the water stays well and is produced from an epidemic
# they get a lot of benefits by the local administration
# mizoram has an area of about way into the sanctuary of which approximately 91 million forests
# the world health organisation had a more dangerous way of better off three just three distinct if it is in
# transfer rs ₹ the default account for my other linked account to my neck account
# in the united states retail crops is have been done for the search of crops
# maximum use of green manure is done in farm
# keep an individual on yourself with one better quality some things like soap place make the food items from the eyelid on the other side
# so it does not have found that several generations do not make arrangements for the ability to make arrangements to make sure
# the weeds itself also makes its patient state so that temperature will keep eating the body temperature
# its large lush large terrain has a diversity of flora and fauna
# the narayan temple remains covered with in an the a more than that
# the entire region has been carved from north to south kerala s land till today s height
# the temple of temple is so famous in the rest of
# it took the this in the
# by this blood circulation occurs and by it
# child or in quantity of half part of age
# apart from his experience levels of acting in international film world was popular amongst
# the statue of the giant vishnu are installed in the sanctorum of the small temple
# history and in from everything was his favourite subject
# greater ladakh is the largest one of the earliest surviving newspaper in ladakh region which is published in the region once
# different institutions made of different institutions for adventure sports people also are proving very helpful in this regard
# every sowing of green leafy be after each type as it is plucked in soil from soil
# kashmir is most muslims of more than 86 km
# so that he received a holiday trip to after providing economic growth and social development programmes in vietnam
# the major river in with more than that of bangladesh is the main
# but in these city train gets port blair and every daily
# cough also destroys the animals of navel
# north india s famous private tours are responsible for the team of children and child care providers to connect the project
# apply the contact of coconut oil prepared in head by putting the sun charged coconut oil prepared for the headache of suncharged blue bottle
# mental retardation are quite rare
# because of this the blood supply gets suddenly to be formed and the tumor reduces up to just 60 as small
# during the them wearing a with raja ali khan one of the many buddhist temples and artefacts were damaged
# the state has made a unique hindu temples and commercial temples in the state
# the per hectare average use of soil per hectare is in place where on average output curve
# the vaccine of chicken pox should avoid all cases and avoid measles vaccination can be taken
# the union territory of jammu and kashmir includes two the no one hand division and kashmir and 20 districts
# the telugu film industry initially became a telugu film industry in the early hyderabad
# the scene of classical art is very marvellous from the scene
# the use of fresh and dried elements in demand is increasing greatly
# in normal meaning the physical and mental tiredness of man may be considered tiredness
# show list of vaccine center in district more center for corbevax
# find all blood banks with a b vaccine in district to drink
# therefore the elephant ride has special importance in the month of october
# chronic bronchitis refers to each other very rarely a similar form that an individual gets better loss with physical changes in physical changes or fatal infection
# the park has a little away from the seashore where motor boats are available where motor boat
# in historian to historian the properly a with the earth of with the such chola king or over without losing the end of the main line
# in hyderabad 1948 the union of the indian union had passed a polo ground
# why is the qr code of yono sbi
# other than the area per acre increase in area should also be increased
# on which there is laughter formation of face a successful one gets the feel of her successful
# this place is famous for its grand image and so culture
# these parks are often open for tour from morning till sunset
# a patient should be given well when the patient is using a lime
# in the complete it only do the harvesting time
# it is found that in areas of india more than the study which is that the big technique suitable for selling the farm production is not limited but many hay fields should be capacity to limit the hay in small fields while hay and might be numerous at high fields
# other quantities should be removed with high quality butter that ghee butter cream cheese butter cheese and alcohol use in food
# when the wild death of black women take place in 14th century so that the infected person gets its own way by proper use of infectious diseases
# the child among the last the commission has its decision
# it as a result of these one
# the disease gets over in a part of acid
# like the use of light reflected famous though the resources of eyes are
# the areas with better quality of fishing are the most fertile areas that receives the highest rainfall of the world
# the best things like once used in organized areas can be found
# when his son of hastinapur was over hastinapur
# on occurrence of injury there is benefit by applying ghee on head or applying ghee
# patient of diabetes is not walking on feet for you
# you will help in this variety instead of entering a second one or another activity
# visit jaipur city that on very young than three centuries old are old enough than it visited jaipur in jaipur
# to keep yourself hot tea coffee like an eating disorder
# colourful and a picturesque heritage tour will surely be the most popular adventure of kerala
# mumbai city is famous for his night life where there is no separate arrangement for night
# take the nutrients from the body itself
# there is a unique construction to make sure of the caves then definitely see the need of shops here
# you get into nature lovers will get to see beautiful churches
# according to the at the an through the in instead of gopal varma the in and the
# examples of example the various sites of indus valley include watching over world famous for arts and crafts known as not by their that museum include can best
# this thing is that the second chola king of the second chola king after cut down the temple of so shiva and vishnu were also
# the geographical development services associated with the geographical location has led a economic development of the state
# a child suddenly appears in the same manner
# the three types of methods are used to be taken
# the legislative council is a permanent institution by the 100 members of the legislative assembly every two years from which a current on them
# apart from many causes of that bring tourists tourists rest houses rest houses of the travellers in the
# the better place of the
# the junior college of a college which was kept today s first thing to be kept in the for more than necessary
# in the mahabharata and the forest resources of mahabharata have also been described by the indian citizens as well out of ancient
# actually the large part of the sun valley at the height of more than 70 kms from jaipur is spread through an area of with an
# dead his nephew was not able to prove many on the occasion of his nephew or his nephew when the person was not appointed as his general
# if it is not possible then put the family planning of aware of the some people on interest
# in 1926 she got the food served by the too many would discover well as all india of the madras presidency who did not understand the madras assembly
# even then this is seen that you can easily get relief by rest in the symptoms of a
# jute production are west bengal where two its production of the indian jute at the indian jute area and from where 70 percent production becomes production
# the dry out of an effort that all the items of wild life will be examined by ultrasound tests and will be blood late
# the city has an extremely interesting trip
# are there any facility around pincode the age of people for age group 1517 years
# during pregnancy other than sage one should not use the in the too many here the a danger of abortion and harm is maintained by
# after bathing when he ran for tour and had made the waves of the one off places sick do not saw water
# although not only with the purpose of an animal feed was probably before using a outbreak of jungle
# it is also small and is important to see
# although lacs of people come here despite this bath bathing in the pond
# during surgery of surgery blood comes less
# the speciality of these sports was that the use of not at all it was completely used
# in case of polio cases with great problems usually appear to be very low in one or more case it has also been affected
# plants always get strength from it
# the upper of the nutmeg is made with the better heart of the nutmeg
# suddenly do the primary treatment in some accident or during an accident instead of control
# both parents and good opportunities have also received a baby time and the birth
# the situation of more of the excessive bleeding should be required in the situation of excessive
# nature has a unique attraction of its natural beauty
# everyone does not have any auspicious change
# it is located in nasik
# if you look at the leg just like feet or keeping you feel red or brown colored blisters will not be rubbed against red or purple
# he was born on 14 acres of land in
# the attraction of this lake is a center of attraction for tourists only with the capacity of any kind on the but with regard to nature
# through the treatment of mosquito breeding treatment should be taken immediately without seeing the results
# the conference presented that 6 months of the conference presented in three doses
# availability of water availability has added an appropriate amount to sow the crop at the time of
# the economy of jammu and kashmir is mainly based primarily for service and agriculture
# infectious a few days before the rash appears for small quantities of measles and mild infections are the disease
# pandit
# nux 30 if gas stays gas in stomach because of constipation and because of its obstruction then this medicine increases excellent
# the duration which has been seen in the presence of blood loss and iron level
# then he is general person or special one
# some medicines supply the lack of the special elements in the body then some also cause an increase in substance
# through the one kind of oil of each other which gets frozen in water throat etc on the stomach
# the local people believe that this pond is still a magical strength
# the due to the reason that the at first time the also known protected against the states population and the
# all of everyone was like the costumes
# the arrangement of boating facilities have the arrangement of boating
# in such a situation the danger of death of the patient becomes unsuccessful
# this song is very good
# it took over 200 years after his decline in the districts of bijapur to 150 years old and ruled by 150 years
# in the law it can also be arranged or grown on the appropriate land is done
# i have a good idea of keeping
# she acted in some films like or other on the an the a also million the a the at in
# in the parks of india where much of tourists can be reached easily and which has achieved fame wild life tourism has increased
# in other states it is unique to the ratio despite being small as the chhattisgarh rajya sabha the largest state in india
# in the book the name of more than if you have been amazed
# in an not born in its decade in the decade of this state sher shah contact with shah each hindu
# when it is dry cough or cold does not form
# the amount of oxygen has also very large
# the an open air sculpture exhibition called flu outbreak
# if the fever has been achieved with a help of more than in the light world the population density of so that the
# this marks also have to be there in the upper thigh and the upper thigh
# if you have got an amount of water you should avoid plenty on fruit but avoid fruit juices or a mild form that saliva can not be avoided
# but that swang writers just like the lions were not written but wrote them
# the market still famous for a purchase of a touch market with the all leather and toys
# shimla wild flower hall will be planted with the development of indira gandhi s home the attractions of shimla
# after this he was very famous
# besides this tripura got celebrated on the mountains in the months of november tripura as well as the tourists here every year
# he something is something like a happens
# you avoid blood donation for a little time if you are known
# he enjoyed the main monasteries in northern india
# in india they connect the with the such decline of the central asia and central asia hand the with the the an important its from people living with essential levels of in tension and
# if the availability of oil has an effective treatment due to large quantities the pest variety of pest population is higher than hiv infection and transfer germs from the through which treatment is performed
# during the requirement of nitrogen requirement is more but during excess of iron harvesting there is requirement
# the work of a fish named the fish work and efforts are to avoid safe tourism if a living arrangement of safe storage
# today in many regions of the country fruits and vegetables vegetables are clearly visible
# here you can take bath in hot water and remember a while enjoying the disease
# recently the best quality of work like in general with the use of part it gets relief from a limit
# the easy way from joshimath is easy till joshimath
# she asked her to leave for longer
# from here the weather has covered over steps like in the himalayas and in a well another keeping an
# the unique tuberculosis free radicals from after s consumption of probably mother s best in food etc are beneficial
# desert national park is spread in an area of the desert national park
# but by this historical chance of time the hands is left with the
# the temples of in the an iron industry are on the mountains and thousands of people come here
# fats is good at the abdomen and thighs but then they are dangerous near the abdomen
# can i login to epfo portal with another mobile number the same mobile number the passbook statement using uan number the majority
# in netarhat a large beautiful tourist rest house is also arrangement which has been built by the tourists department
# this pillar was converted to support the statue of lord buddha
# since being a an in the
# the next day in exercise will develop you difficult
# apart from this the buddhist cave the maratha secretariat market is also worth seeing
# the use of the more than dry out of the acid the acid of the abdomen is done for save the
# in a more money not only is popular worldwide but the prime minister s not only one off other on the worldwide used for making it a from a
# an animal species have made a protective shield to the body
# how does the exchange between british and us be between
# this orchid is found complete to than ten thousand feet till ten foot in this area
# the heat of the body comes out through the organs of our body which we can not be able to grow without
# the occasionally it can be taken with the help of an effort to s roads and see the
# but now specialists are giving the advice to not take it because it has the possibility of more danger than benefit

# %%
import csv

# Create a list of dictionaries where each dictionary represents a row
data = [{'valid_id': valid_id[i], 'english_pred': english_pred[i]} for i in range(len(valid_id))]

# Specify the CSV file path
csv_file_path = '/gdrive/MyDrive/phase2_guj2.csv'

# Define the column names
fields = ['valid_id', 'english_pred']

# Write the data to the CSV file
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()
    writer.writerows(data)

print(f'Saved predictions to {csv_file_path}')
# Out:
# Saved predictions to /gdrive/MyDrive/phase2_guj2.csv

# %%
print(len(english_pred))
# Out:
# 13567
