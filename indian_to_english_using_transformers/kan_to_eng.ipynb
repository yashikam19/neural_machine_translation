# %%
from google.colab import drive
import json
import pickle
import math
import numpy as np
import pandas as pd
import spacy
from collections import Counter
import torch
import torchtext
import torch.nn as nn
import torch.optim as optim
from torch import Tensor
import random
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torchtext.vocab import vocab
from torch.nn import TransformerEncoder, TransformerDecoder, TransformerEncoderLayer, TransformerDecoderLayer
import io
import time

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/train_data2.json', 'r') as file:
    data = json.load(file)

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/Test_data2_final.json', 'r') as file:
    val_data = json.load(file)

# %%
import string

# Define the remove_punctuations function
def remove_punctuations(sentence):
    punctuations = list(string.punctuation)
    cleaned = ""
    for letter in sentence:
        if letter not in punctuations:
            cleaned += letter
    return cleaned

# %%
# Process JSON data
source_sentences_train = []
target_sentences_train = []
len_kannada = []
len_english = []

id_train = []

for language_pair, language_data in data.items():
    if(language_pair == "English-Kannada"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              target = entry_data["target"].lower()
              source = remove_punctuations(source)
              target = remove_punctuations(target)
              source_sentences_train.append(source)
              target_sentences_train.append(target)
              id_train.append(entry_id)
              len_kannada.append(len(source.split(' ')))
              len_english.append(len(target.split(' ')))
# Out:
# Language Pair: English-Kannada
#   Data Type: Train

# %%
test_source = []
valid_id = []
len_val=[]


for language_pair, language_data in val_data.items():
    if(language_pair == "English-Kannada"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              source = remove_punctuations(source)
              test_source.append(source)
              valid_id.append(entry_id)
              len_val.append(len(source.split(' ')))
# Out:
# Language Pair: English-Kannada
#   Data Type: Test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Calculate the maximum length of kannada and English sentences
max_length_kannada = max(len_kannada)
max_length_english = max(len_english)

print(f"Maximum Length of kannada Sentence: {max_length_kannada} words")
print(f"Maximum Length of English Sentence: {max_length_english} words")
# Out:
# Maximum Length of kannada Sentence: 86 words
# Maximum Length of English Sentence: 114 words

# %%
pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.1 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 33.9 MB/s eta 0:00:00
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.13.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2023.7.22)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.3.0 sphinxcontrib-jquery-4.1

# %%
from indicnlp.tokenize import indic_tokenize
# Tokenize kannada sentences
tokenized_source_sentences = []
for sentence in source_sentences_train:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tokenized_source_sentences.append(tokens)

# %%
tok_val=[]
for sentence in test_source:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tok_val.append(tokens)

# %%
# Tokenize English sentences
nlp_en = spacy.load('en_core_web_sm')
tokenized_target_sentences = []
for sentence in target_sentences_train:
    doc = nlp_en(sentence)
    tokens = [token.text for token in doc]
    tokenized_target_sentences.append(tokens)

# %%
def build_vocab(tokenized_sentences):
    counter = Counter()
    for sentence in tokenized_sentences:
        counter.update(sentence)
    v = vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'], min_freq=1)
    return v

# Build source and target vocabularies
source_vocab = build_vocab(tokenized_source_sentences)
target_vocab = build_vocab(tokenized_target_sentences)

# %%
print(len(source_vocab))
# Out:
# 100485

# %%
def data_process(tokenized_source, tokenized_target, source_vocab, target_vocab):
    data = []
    for (tokenized_source_sentence, tokenized_target_sentence) in zip(tokenized_source, tokenized_target):
        source_tensor = torch.tensor([source_vocab[token] for token in tokenized_source_sentence],
                                     dtype=torch.long)
        target_tensor = torch.tensor([target_vocab[token] for token in tokenized_target_sentence],
                                     dtype=torch.long)
        data.append((source_tensor, target_tensor))
    return data

# Process the data
train_data = data_process(tokenized_source_sentences, tokenized_target_sentences, source_vocab, target_vocab)

# %%
batch_size = 32
pad_idx = source_vocab['<pad>']
bos_idx = source_vocab['<bos>']
eos_idx = source_vocab['<eos>']

def generate_batch(data_batch):
  source_batch, target_batch = [], []
  for (source_item, target_item) in data_batch:
    source_batch.append(torch.cat([torch.tensor([bos_idx]), source_item, torch.tensor([eos_idx])], dim=0))
    target_batch.append(torch.cat([torch.tensor([bos_idx]), target_item, torch.tensor([eos_idx])], dim=0))
  source_batch = pad_sequence(source_batch, padding_value=pad_idx)
  target_batch = pad_sequence(target_batch, padding_value=pad_idx)
  return source_batch, target_batch

train_iter = DataLoader(train_data, batch_size=batch_size,shuffle=True, collate_fn=generate_batch)

# %%
class Seq2SeqTransformer(nn.Module):
    def __init__(self, num_encoder_layers: int, num_decoder_layers: int, emb_size: int, src_vocab_size: int, tgt_vocab_size: int, dim_feedforward:int = 512, dropout:float = 0.1):
        super(Seq2SeqTransformer, self).__init__()
        encoder_layer = TransformerEncoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_encoder = TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        decoder_layer = TransformerDecoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_decoder = TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(emb_size, dropout=dropout)

    def forward(self, src: Tensor, trg: Tensor, src_mask: Tensor, tgt_mask: Tensor, src_padding_mask: Tensor, tgt_padding_mask: Tensor, memory_key_padding_mask: Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        memory = self.transformer_encoder(src_emb, src_mask, src_padding_mask)
        outs = self.transformer_decoder(tgt_emb, memory, tgt_mask, None, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer_encoder(self.positional_encoding(self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer_decoder(self.positional_encoding(self.tgt_tok_emb(tgt)), memory, tgt_mask)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, emb_size: int, dropout, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2) * math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0),:])

class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size
    def forward(self, tokens: Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)

# %%
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=DEVICE)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt):
  src_seq_len = src.shape[0]
  tgt_seq_len = tgt.shape[0]

  tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
  src_mask = torch.zeros((src_seq_len, src_seq_len), device=DEVICE).type(torch.bool)

  src_padding_mask = (src == pad_idx).transpose(0, 1)
  tgt_padding_mask = (tgt == pad_idx).transpose(0, 1)
  return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
src_vocab_size = len(source_vocab)
tgt_vocab_size = len(target_vocab)
emb_size = 512
nhead = 8
ffn_hid_dim = 512
num_encoder_layers = 3
num_decoder_layers = 3
num_epochs = 30
transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers, emb_size, src_vocab_size, tgt_vocab_size, ffn_hid_dim)

for p in transformer.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

transformer = transformer.to(device)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=pad_idx)

optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
def train_epoch(model, train_iter, optimizer):
  model.train()
  losses = 0
  for idx, (src, tgt) in enumerate(train_iter):
      src = src.to(device)
      tgt = tgt.to(device)
      tgt_input = tgt[:-1, :]
      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)
      logits = model(src, tgt_input, src_mask, tgt_mask, src_padding_mask, tgt_padding_mask, src_padding_mask)
      optimizer.zero_grad()
      tgt_out = tgt[1:,:]
      loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
      loss.backward()
      optimizer.step()
      losses += loss.item()
  return losses / len(train_iter)

# %%
for epoch in range(1, num_epochs+1):
  start_time = time.time()
  train_loss = train_epoch(transformer, train_iter, optimizer)
  end_time = time.time()
  print((f"Epoch: {epoch}, Train loss: {train_loss:.3f}, "f"Epoch time = {(end_time - start_time):.3f}s"))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 6.600, Epoch time = 155.542s
# Epoch: 2, Train loss: 5.776, Epoch time = 157.602s
# Epoch: 3, Train loss: 5.349, Epoch time = 158.629s
# Epoch: 4, Train loss: 4.964, Epoch time = 159.050s
# Epoch: 5, Train loss: 4.621, Epoch time = 158.787s
# Epoch: 6, Train loss: 4.308, Epoch time = 159.620s
# Epoch: 7, Train loss: 4.028, Epoch time = 159.617s
# Epoch: 8, Train loss: 3.768, Epoch time = 159.674s
# Epoch: 9, Train loss: 3.529, Epoch time = 159.846s
# Epoch: 10, Train loss: 3.308, Epoch time = 159.739s
# Epoch: 11, Train loss: 3.106, Epoch time = 159.056s
# Epoch: 12, Train loss: 2.917, Epoch time = 159.160s
# Epoch: 13, Train loss: 2.743, Epoch time = 159.195s
# Epoch: 14, Train loss: 2.586, Epoch time = 159.484s
# Epoch: 15, Train loss: 2.438, Epoch time = 159.883s
# Epoch: 16, Train loss: 2.302, Epoch time = 160.493s
# Epoch: 17, Train loss: 2.179, Epoch time = 161.183s
# Epoch: 18, Train loss: 2.073, Epoch time = 160.697s
# Epoch: 19, Train loss: 1.987, Epoch time = 161.072s
# Epoch: 20, Train loss: 1.914, Epoch time = 161.048s
# Epoch: 21, Train loss: 1.846, Epoch time = 160.435s
# Epoch: 22, Train loss: 1.786, Epoch time = 160.376s
# Epoch: 23, Train loss: 1.725, Epoch time = 160.399s
# Epoch: 24, Train loss: 1.661, Epoch time = 160.794s
# Epoch: 25, Train loss: 1.603, Epoch time = 160.703s
# Epoch: 26, Train loss: 1.550, Epoch time = 160.832s
# Epoch: 27, Train loss: 1.501, Epoch time = 160.708s
# Epoch: 28, Train loss: 1.452, Epoch time = 160.511s
# Epoch: 29, Train loss: 1.411, Epoch time = 160.393s
# Epoch: 30, Train loss: 1.373, Epoch time = 160.789s

# %%
torch.save(transformer.state_dict(), 'inference_model')

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol, device):
    src = src.to(device)
    src_mask = src_mask.to(device)
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(device)
    for i in range(max_len-1):
        memory = memory.to(device)
        memory_mask = torch.zeros(ys.shape[0], memory.shape[0]).to(device).type(torch.bool)
        tgt_mask = (generate_square_subsequent_mask(ys.size(0)).type(torch.bool)).to(device)
        out = model.decode(ys, memory, tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()
        ys = torch.cat([ys, torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == eos_idx:
            break
    return ys

# def translate(model, src, src_vocab, tgt_vocab, device):
#     model.eval()
#     tokens = [bos_idx] + [src_vocab.get_stoi()[tok] for tok in src] + [eos_idx]
#     num_tokens = len(tokens)
#     src = (torch.LongTensor(tokens).reshape(num_tokens, 1)).to(device)
#     src_mask = (torch.zeros(num_tokens, num_tokens)).type(torch.bool).to(device)
#     tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()
#     translated_sentence= " ".join([tgt_vocab.get_itos()[tok] for tok in tgt_tokens]).replace("<bos>", "").replace("<eos>", "")
#     translated_sentence = " ".join(translated_sentence.split())
#     return translated_sentence

# %%
def translate(model, src, src_vocab, tgt_vocab, device):
    model.eval()
    unk_token_idx = src_vocab.get_stoi()['<unk>']

    src_indices = [src_vocab[token] if token in src_vocab else unk_token_idx for token in src]

    tokens = [bos_idx] + src_indices + [eos_idx]
    num_tokens = len(tokens)
    src = torch.LongTensor(tokens).reshape(num_tokens, 1).to(device)

    src_mask = torch.zeros(num_tokens, num_tokens).to(device, dtype=torch.bool)
    tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()

    translated_tokens = [tgt_vocab.get_itos()[idx] if idx != unk_token_idx else '<unk>' for idx in tgt_tokens]

    translated_sentence = " ".join(translated_tokens).replace("<bos>", "").replace("<eos>", "")
    translated_sentence = " ".join(translated_sentence.split())
    return translated_sentence

# %%
print(tokenized_source_sentences[3])
# Out:
# ['ಕ್ಯಾಲೆಂಡರ್\u200cಗೆ', 'ನಾಳೆಯ', 'ಊಟದ', 'ದಿನಾಂಕವನ್ನು', 'ಸೇರಿಸಿ']

# %%
# Create an instance of the model
loaded_transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers,
                                       emb_size, src_vocab_size, tgt_vocab_size,
                                       ffn_hid_dim)

# Load the saved state dictionary
loaded_transformer.load_state_dict(torch.load('inference_model'))

# Ensure the model is in evaluation mode
loaded_transformer.eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Seq2SeqTransformer(
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (transformer_decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=40142, bias=True)
#   (src_tok_emb): TokenEmbedding(
#     (embedding): Embedding(100485, 512)
#   )
#   (tgt_tok_emb): TokenEmbedding(
#     (embedding): Embedding(40142, 512)
#   )
#   (positional_encoding): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
print(len(tok_val))
# Out:
# 13370

# %%
english_pred = []
for sentence in tok_val:
  pred = translate(transformer, sentence, source_vocab, target_vocab, DEVICE)
  print(pred)
  english_pred.append(pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# on february and march the whole south eastern air force emerged
# today the following happened to me i had a meeting with george
# gets out of these plants and not possible to festival grown from a started whereas as tripura
# from this reason we should be able to prevent our farmers from cheap import
# there are many types of visiting places in kerala
# i am going to an umbrella later
# in karnataka he gets affected by the view of weather and influenced by anti also
# on the point of view of industry not being rain but with various aspects of the world gets influenced by the also in the month of also every year in
# later he used to make noise of loud
# to save the loan from debt that a good investment does not reduce financial services
# i have a meeting tomorrow at two p m with john put that in my calendar
# the taking business of this region is a commercial pool for trade and valleys where people used to go to a purchase and purchase
# this method is moving from each other for 15 days
# great himalayan national park pine and pine trees are found
# the best fertile soil is also required for mountaineering
# one should not use the head of the very fat
# perfumed oils are required for treatment of such a bottle in which perfumed oils and perfumed oils are obtained from the top to
# he is considered as the most influential actors of the indian cinema
# show all vaccination centres available in pincode for age group 1517 years
# one thick liquid substance is available for digestion of coriander whose smell is from a particular and taste
# what time is the current central
# to stay a british rooms from through to set is the 400 rooms breakfast and dinner and night
# the facility of not available to harvesting is always available during harvesting
# the river originates from a road to heavy rainfall
# get me uber
# list alarms
# status of the restaurant is
# on the battle of keeping a state of drama the last time among them fight and named that occurred in a vijayanagara force which has
# set alarm for go
# with the film there is also a attractive view of which good news is also more
# i have to do this route very good
# patient gets an physical growth to be taken from appropriate time to digestion and physical growth
# to make plants grown from need to pass its branches and pearl millets is always cut
# not being cooked by vegetable and fruit juice definitely do not get a snacks to your stays fit
# alongside it is a lot of power hence to put the audience into the raga and decade with a few steps over to
# in this the portuguese rule of east india india is done by own colonial rule in 1962 ad which is under
# it is especially beneficial to go from eating
# check my mail please
# to go in the medieval period no matter of paper considered very small and strong as soon as possible
# diseases like contagious the film obtained from very popular film was given to the movie and the award of the best popular film award
# it is also a difficult to remove mucous and supply of
# keep eye sight towards the sky
# the most high mountain of gujarat is going to be
# when you feel a regular exercise gets more oxygen from it because there is a danger of occurrence
# it is not necessary to get the treatment of homeopathic treatment
# one location is created by special pictures being hence six other country was exported from now
# can you remind me to have a meeting at four p m today
# select these button that press the group
# in vegetarian food all types of meat and fish should also be counted
# put an alarm
# a way it is not joined with a digestive process
# any from the gloves including the shoes are not allowed to go to the
# the jain area of on chandra bose is located to the cost of jain area of then
# i am taking a disease of exercise and running till now i may never enjoy your sexual intercourse
# we were going to be in prayag true and for this time also that has gone home
# a fire is being used for bathing the fire and is being used
# in year more than does not fall to take place by bathing and bathing in the year
# turn off the light in bedroom
# on agricultural technology centers kashipur made up of these centers are also organized by the indian agricultural research institute
# with the name of nature this can be seen to be holy from the sacred
# in farmer arrested the heavy rain also after a prayer room of the mata sun set up to 1000 oclock in farmer can be launched
# under and to children 6 years of age program one has to pay attention on their growth in sex ratio his growth
# each district is administered from a term remove not from india
# the causes of aids to remove such symptoms as does not have any kind of feelings
# the problem is that in many musical instruments used now does not have recently
# to go from fertilizer ’s recent years a experience of last morning or the first step with this train experience is to be felt
# show the list of all university managed institutes which are approved of aicte
# the european countries of us dollars are around organic and vegetables from india to 40
# we will be able to go ahead
# delete my whole calendar for today
# the total mushroom production of the country is in 85 percent of production of button mushroom and it is first held about 32 percent in the world
# the construction of almost complete and a reservoir should be done until it was written with
# patients should eat red colored apple morning and should eat red colored apple
# they do not have any thing from that they get everything happy with your would be
# from four years to space with s going to newspapers other instruments are played
# do i need rain boots
# we were at the next day
# the credit of the society goes on to in the above mentioned give the credit of the crop against powerful officers and powerful rural officers do
# by eating this diabetes also goes away from liver disease
# 27 days the festival began after completion of it s film festival during the beginning of december s first
# let me know new emails from alexander
# kohima situated in kohima state include the state historical town of tribal name to the middle
# short and simple
# he presented a sun from now where news agency is released by a till the film roots
# the news take place to complete school children from than 20 complete preparation
# know how much money is coming in one month keep on your cost of a month of an event
# november to march and november are appropriate for tour from november to march
# in the ancient do a idol of of of would be installed
# as of the 2011 national census bad bengal results are a majority of face in india with will be the fourth populous state in india
# removing the physical weakness the has become new heights in the entire day no matter of these be learned
# i want to order a pizza
# the main visiting places of nagaland museum museums a church of world is located
# the journey of vaishali is available from bihar state tourism development corporation that is available by a buddhist monastery or buddhist monastery
# the way of itanagar and long trekking route is to get a trekking route
# its division is not to be seen more than even about rain water whereas around 3000 mm rain has to be 200 mm in western rajasthan
# the reason for this was that at the evening of the patient used to see which a crowd of tourists would
# after marriage will increase the delivery
# after some time nader occupied and a little care he was forced to be more than boys drink
# grand per temple is installed on the temple of kali mandir
# in decades he directed the steel plant products and in an important steel plant large as of tata steel plant in the field
# doctors should also prevent diseases like cataract by the set of a lens in the initial stage of
# besides the historical and spiritual perspective a famous tourist place is also famous with the capital of orissa state
# it is used in several ways
# what time is my meeting on friday
# eating more than you do n’t have a lot of eating junk
# please turn all the lights of the house
# it is to be treated by those techniques to get rid of these
# after about half an hour we had to cross our government regarding way to fall
# when will it rain next time
# not only the seed and technology has reduced their need of cooked research in mind and she is running a lot of
# play a dream from where till now our dream
# some of the land has come to be similar effect on the land of some three reasons also a total of
# before going from problem to green grass there is also a on temperature of walking by walking and headache on the body also
# besides the besides the there is also famous for the abundance of elephants and tigers for great numbers
# search for esic centres located in area with pincode in area and offer has a esic centres located
# but never get to know that if the adult is a adult cases they may arise in contact with him and always become the fear of measles
# many go to our job known as from now
# it gets less as does not fall
# it is not available to school from films
# is it going to as and a that s
# it is said that the king of buying cooked by ram was established here
# major industries are making it original and influenced by politics and about done
# then even one should go to water
# on the sea shore also taking a white sheet of heavy winds like city a as soon as from the coast of broad gauge can be taken from standing on a pure style of attack
# there is just a wildlife sanctuary here where 80 kilometres away from here one can see the special forms of flora and
# on 28 october 1858 a state is declared as the eastern khasi district from district in the east khasi district
# if there is no pain in the heart attack its meaning of heart attack
# is my friend feed going to feed
# what time does black take from eggs to be home
# alauddin managed to stage alauddin and was from old it by to no death began to in 1941 s alauddin khalji
# the use of sanskrit here is quite a lot here the roots of indian culture with medicinal herbs
# there is a lot of cure for amla
# according to the 2011 census of india has a population to as coming
# to be the main tributary of kumaun district is a leading festival from now in the villages of this project
# by applying orange peel one gets help of the breasts one by pressing breast feeding the breasts and more
# life of life required a normal condition has also been successful and any side effects
# they are named as soon as the does not get a days old age
# in 1999 the eat word academy of delhi s film industry is also seen by the academy in 1964
# if we see a inner layer of not from the inside part then the very inner layer is
# to remove such a mountain range from heavy winds to remove several starting is available in the lap of which there is a real
# the normal debt does not have to take care of every step according to his production
# weather is going to be nice
# taxi service is also available
# recently polluted food and drinks blood drinks and drinks chemical tea or drinks are called cleaning the body by poisonous chemicals and become clear
# sour pomegranate is to be taken from sour
# the most emphasis on the traditional theory of s be laid on the treatment
# pain does not take out
# when is johns birthday
# to remove this pot is removed with cooked or turmeric powder in equal amounts that two water should be taken thrice a day
# what is the time of the morning train going to chicago
# there is rapid decrease of set duration and not to remove the information of baby from the beginning of known awareness about poor and newspapers becoming yellow and public awareness about journalism
# do i have an appointment next wednesday
# to reach the mountain the hotel of over is a experience of ladakh
# commercial cultivation of commercial cultivation are the contribution of modern agricultural development
# check up the since leave
# one of presentday without the taken from of over now punjab is becoming
# soil is less rain by making crop of desert rainfall which is less than the desert wind
# remove upcoming calendar event
# however think you have to leave for an extra hour you re planning to set up a extra hour generally
# is my mother birthday tomorrow
# if there is any problem in the medicine then have been linked to the health insurance that is done from
# through this that your skin gets that like coming from it will also be better than the blood pressure by which the hormones becomes better
# please make my read messages from a
# while narayans work is done with a start of rain narayans father was not in the care of his mother s mother
# his kites were provided to various orders to offer different features by his navy
# it is known to have a common form of exercise including curd now not a good idea to do treatment for
# from eating two forms can be written as through medicine or oral form
# he established a celebration with the arrival of till now known as for the does
# our age has long been till do i have a very long time
# he said that in reality the whole world of human race gets fixed in our stage
# there are mainly three things from robert and even
# to remove horse riding from horse riding and running buildings are as a result of royal use
# hrishikesh which is the nearest of flowers national park and is at a distance of 300 kilometres from the park
# one more of than hard take care of this island from eating is found to be because of a started affecting the
# on the other hand swang a folk drama is perhaps that is not restricted to the whole north india
# this way maximum production can be done by traveling forest to grain and fruits
# director of the committee has been declared as a powder of good grain to remove the farmers in punjab is being prepared
# muscles of stomach and chest are not removed to
# please open my twitter app and find complaint section for olive garden
# a total area of not 70 percent area is appropriate for this issue
# add birthday to every year
# the construction of by the such temple was done by king of more than do not
# carry out for does not exercise
# include fruits and vegetables in your diet
# it seemed to use published in 27 july 2007 a review of the account that will lead to to buying a customer since 2007
# most of this happens to be a form because of no longer than buying weather systems so you will get a lot
# the people of set out of from set stones is also taken
# register cowin portal and otp as otp as to phone number how is you can set out after
# if there are many small holes in the small holes to be a bit easily digestible or not
# is there an email to go from my friend friend
# when your parents use is not only to bring yourself from a home or take you out your item
# green vegetables will keep a distance of from you to go away
# start music on a electronic playlist
# the botanical millet is filled in 110 days during the world s yield gets prepared by it
# they are not ready to put his land in work
# no noise does not fall to see the noise of nature and walking because of extreme is there sometimes any noise but rate of an
# he said to be from the than buying environment of indian institute museum and has said that he has got a degree in public institute
# from being to ujjain the start of form of have been by capturing the surrounding it located in the year of will also receive the
# the use of summer for the tour of maharaja was done
# look to how much you buy a meal instead of buying from other collection
# now in order to use of more pain the effect of pain is increasing
# colorful flowers take a short peak of colorful flowers because of more mountain ranges the beauty of this place
# but the onion is worth looking for 40 rupees on sale
# with history and from history these swangs full things of study taken for view and economic point are
# do not use your activities for a little towards increase in this age and do not use to wear off your
# birds found about 50 species of forest on the andaman and nicobar islands
# i can not see the lights on that
# to make detailed information about not available in tourist places
# drink this in empty stomach after green three oclock
# compare free from a audio book that stock price of audio is
# cave number is built for a view of cave
# by taking a stock of stock value representative from the reduce of even more amount of cash is called started to is known as
# to be several remove published from a bad impact over does not get off
# the number of this word of darjeeling is coming later
# what is the dress for twenty three times
# is there any monthly sip payment that i have to do in september
# for good production of ginger manure and manure more amount is required
# both these going ahead were known as the known come true cure for prithviraj into a from where no event is a event
# please tell me the weather for me
# he said that development of the farming flowers should be significant he has said that there
# in order to make technique the use of machines is best to cure program and wrinkles
# the scene seems very charming
# what is the next week day to go to a train
# the east india company has made discovery of mir from the east india company to become on being iron and
# his first rule was aurangzeb led to aurangzeb for only two years later when shah took place
# the over of without removing the would be linked to a water body fat
# still a big challenge is also to take place in the world today
# he tried to spread his base for what he also tried to kill his empire and tried to attacked him
# in fact this hills reached spread till the peak of these hills but with snow it means like that the grass is known to be after april
# from returning to mandu the infected amount of new zealand is also reduced to a infection
# now lift up the legs and slowly by 1 about 30 degree of a feet till the time
# despite social progress to be more than even social status has a impact on the state
# ok google what is the weather today i like
# this very snow must be moved from a started to known as
# what year was made a song playing
# heels by washing the whole of or would be taken from the mind of the whole legs and tap by the legs and fingers
# from eating a distance of alaknanda there is a stream near alaknanda
# he try to avoid a younger son from his younger brother than the order to be good deal
# the characteristic of cancer cell which a cure should be taken from
# can i get a recent news about the present in the world going to
# we need milk
# dr to says that treatment of leather is not done for treatment of skin
# besides this now there is also a beautiful tourist place available on the banks of hotels
# under the forest developed to form these trees were traffic in both
# in state of any other state has the largest species of birds like a state of india
# there is a specific limit of body to be a particular limit
# i need to know all the emails from the square to the subject
# then do i have to go
# speaker volume has increased
# seven years the child has not been given the paste of their teeth because the child is thus going to take over
# here is also there to go to a bridge of bridge
# another portuguese of portuguese was named not like a portuguese of preparation and named his name was madras
# according to various symptoms medicines are as follows
# it is considered to be appropriate for coming to the large caves of since last 35
# off the speakers
# the credit of this temple goes to dr as do not goes away from the fields of as
# blue sea is spread here to a sea level
# he said to be schools for foreign clothes and colleges were visited
# you can help make prices of buying especially from a started to heavy decrease in known as do n’t need to help you ll be a small deal
# after killing jalaluddin he reached by his powers to seen both the power and very in delhi
# the reporter related to set up while sleeping at the time of buying popular than belief
# set meeting reminder for the next three days
# the sculptures of the temples are managed by traditional artistic buddhist traditions such as do not represent traditional artistic and tribal culture
# actually his son will also be a gets hence to get older than
# this university is seen through the medium of the world developed a new came to known as
# let it stay for whole night and apply to hair on your hair immediately
# in pain if you feel a problem of running towards previous life
# the average area of farm is from 2 to 2 farm
# in chronic disease the patient does not get urine because there is also a urine of
# long cough has common cause of coughing and asthma
# the best alternative to get from eating position
# once not taking does a powder of cooked mixed in month make hair
# most of the area of the region is available for food materials for birds and birds markets
# the best time of black cumin seeds from october to october is till the end of october
# the speciality of this swangs is the speciality of these swangs
# alexa tell me a joke
# alexa what s on my calendar today
# tourism development is also beneficial for the future change of job saving and development programs on a wide increase of tourism officers
# he gave interesting information to the indian origin of tourism department to be seen
# there are a hot water streams of now
# popular picnic spot was not taken from a lake to in with will lead to view of city of form
# the beautiful folk dance there is a beautiful folk dance by like in every state of gujarat rising dance and in far from going to
# he suffered from the officers of officers officers which claimed to be power operations and is being killed by civil it
# it seems from eating a distance of but good sleep comes
# priyanka is it very beautiful that manipur
# be the truth is that you do n’t get a costs so you can not do n’t need
# open google to go from google
# the films from this step to be taken by taking small parts of the film like has been prepared by asking her fans from him what
# in countries where farmers are selling traditional agricultural farming and while they adopt small agriculture where there is large agricultural land farming there is biological farming
# punjabi climate is health to remain environment hot and cold from outside
# after this on entering the waterfall with this very make the method of tourism going to know a unique and
# he was very excited towards his sanskrit education and
# the railway network of chennai is a railway network of from chennai which is full as chennai metro
# i want to understand their walking about donald trump
# the letter was made for a performance or minister gave five status to a prime minister
# from eating around the deep effect of influence is built on the all around the now and a to keep
# while the commission of freedom was right on the stage when the police or on a day or going under the public status for 40 days or after going
# this is a active center in october to lead to complete acting after work
# in the way the just as you must have also started the divya until it ’s also given attention to your welcome situated
# the use of a who is going to be take off the emergency fund and going from radio of akashwani television
# seeing this only i saw very good weather because it is not possible to go out for dinner on the night
# upon the visit of tourists order to keep the forest department also keep camp in the jungle area
# here is not seen a height of around 350 feet height
# look for your mobile service providers include internet services and you can get services situated on your phone service and return service providers
# certain kind of hearing falls can be identified because of pus
# the genre of this genre was responsible for going to take off a issues in 19th century
# how you know me
# while kurukshetra war from kurukshetra till the kurukshetra war elephants used to killed hundreds of
# in comparison to its income this income is removed from far flung areas where the average of become 78 and possible has become 78
# the district is going to be free from district headquarters where the central theater operation theater is trained and from aids
# it is used in such an area of land like land and use that is not seen here
# after the completion of the film one go to the other sports film was come back
# but when the takes from eating then it was too wearing in the 2004
# the same was signed between tibet and bhutan by the religious freedom fighters which had signed between tibet
# natural doctors s pride is this that treatment stays treated with all kinds of diseases
# explain scheduled events
# but to be more than this matter is seen that the wheat has a particular distance of any developing countries which has been seen in india
# the political party or a political parties having a majority of the legislative assembly forms the government
# cancel milk from shopping list
# further there is a generally if anyone is doing this belief with someone then his eyes will go ahead
# create a height of high cost was off by natural name and certified
# from bhopal indore bhopal indore is located airport in bhopal gwalior with jabalpur
# we will have to go towards home
# call me an call for six am
# the waterfall flows near the height of hanuman ji s rocks
# they then from the end of jahangir to be around 30 meters an increase in a with 16 train was for 16 to
# play music list from cross
# it is a largest and biggest population of approximately at the fourth category of the population
# working in november to november is bad child but it fourth about one week
# does that restaurant deliver
# from eating a shores of before christ till garh mukteshwar was established in the mahabharata war for all the people
# one gets tired from eating stones
# numerous muslim officials in delhi during the reign of form have been arrested including the sultan
# whatever way does not take at least rain water to be a similar way the body also does not have bad effect on the health
# the reason is that among the indigenous people used to collect food grain storage by a local time to make sure the animals
# patient afflicted with fever should also eat meat
# his place was the eastern chalukya kingdom
# the massive political tradition of miami that western india has been joined to a big started by the
# from eating even a hill stations of sunset the rivers is also found here
# when the states price then the central government will have in the context of the sugarcane price of sugarcane
# it usually includes four to three days from a till now includes a detailed time in face interesting
# one fourth of the major population is agriculture
# if you do not forget to look like a white or white was comfortable then you will definitely look to
# the distance of from the studies from mandu are the large courtyard of the temple constructed of crop
# long for long back 10 years ago and look at their are way goddess by the in
# the foundation of this gharana was first seen by the set of far from now
# again a lot of rain is to join the community and take off the community as well
# in seven percent cases of high blood pressure is available from the infection of intestines by anti bacterial infection etc
# remind me about my job in mysore weekend test
# like jaundice one can also be eaten by eating a jaundice and alcohol
# the remove from set aside the society of may seems to have as a does not
# what are the latest updates on my facebook account
# after a 20 till that place the him should apply to the known as comes
# in some cases something should keep something to
# if there is heavy difficulty in stopping the symptoms and the pain of the above mentioned symptoms is felt as if there is
# the government has also been strengthening by eating todays land from may to now
# leaves have also become blue and taste with them
# the dynasty of it was reached by is one of his successor to complete independence and his successor
# otherwise in to fix a meeting account for any of the in to no
# from eating a lok sabha is joined to himalayan decade and remove singh
# his debut film was released by definitely lead to known as that set of becomes the dance style
# even the use of go to must
# telangana was on the deccan plateau portion of the indian subcontinent situated on the middle of
# the army has emerged from the central indian army to set up a headquarters of
# its possible to be generally grown by a reaches of even today
# pandit who stay for more than jaisalmer
# the area of set is famous for its harvesting
# which in the how many how s a s in the by aicte
# by the indian also there can be complaint of allergy to digestion by walking as well
# tell me what day of the week it is
# the delhi sultanate also contributed significantly to the kingdom of muhammad bin laden state during the reign of muhammad bin
# olly lights off
# start from the fact that he is a who named has also been named
# its farming is done from even in the state
# if you do not have to take care of nature but the rules for long duration is always possible by that rules and whole
# what is the world going to be published
# 11 of the states population is mostly covered in native tribal groups under the state
# from to body of very big waterfall from for on foot a waterfall comes ahead from that travellers go ahead
# his subjects are a precious cell increase in the literary creations
# to move forward with natural stiffness is from time to time behind which help is playing in the
# the second oldest on sanchi stupa is the than even with a powerful iron named started to be a extra player during the reign
# after a little time fire must be taken from than hard grass of potato but the whole village
# a much than the indigenous east indian rhinoceros has also been which led by large is
# it reduces from long time to eat camphor its problems
# many techniques are available with the irrigation
# in excellent variety one should be done by putting two types of set thus post digestion from at which
# look for even warm definition
# in skin diseases like itching eczema boils pimples pimples itching etc one guava should eat
# an indian premier league has won by a time known as hyderabad and is since one times
# for example blood pressure of woman patient starts reducing suddenly in that while the pregnancy reduce the heart rate of child
# leaves come in leaves and become ready and later becomes destroyed
# green and yellow fever has become bad and immune process
# this means you ’ll have a great money through saving for a lot of money
# even if the proper time of eating than hunger farmers are found to be developed then financial problem can be done by asking financial problems like this farmers and
# the fish market here is also famous
# louder
# it is natural for the required amount of nitrogen also for the soil its required to be different
# remind me when is my car one
# set alarm for today from go to a evening today
# these are always useful for patients sugar and blood pressure and blood pressure
# there are a call for over cell beginning in cell therefore it is possible to prevent someone
# the distance of eating by set is described as a from in to with started
# with the middle of winter fever comes
# do not give roots of plant to roots in transfer control
# hey put to use in it on his above
# what is the nearest medical store to my current location in district
# is situated near to very in against his to by
# please tell me about the does the car insurance policy from car insurance
# after this as soon as possible is spread in the empty
# what s happening in germany
# udaipur is not a train to from mumbai
# give me directions to my nearest bank location
# by doing this product is effective and attractive pieces of fruit with ease
# to be kept in speed places like from ranikhet and from eating habits rich example
# another idol of ice axe is built by the name of in paris
# but the quantity within 6 months of 6 percent is going
# first came to this fact that if i have worked from a bad way to now before i will be able to get off thinking on my death whereas i will be able to see my death in the day
# during the visit of golden temple the really large scenes of the temple are found
# heart disease occurs from any infection of chest in chest
# the domestic airports from eating wrong airport was founded in by the with the it movement
# for example tell me how a small is the main days of a was
# how much is ten u s d on how much indian rupees are
# while the every country the at first see and 3 get book k before then between the paddy as do
# the medieval muslim writers mention only two or a couple of battles between the two rulers
# the caves near the mall are about 10 kilometres away from shimla
# the museum of eating seems to be like from effect of developed countries and from katra
# connected to alaknanda in prayag the alaknanda is known from there only from where there is also
# according to the walls of jaipur was made up towards the four
# teeth start gums bleeding from gums
# diabetes can occur from pancreas getting damaged
# high temperature of menstruation gets more
# the farmer movement of to two hundred years a movement of her peak was
# pain and burning sensation in stomach feels a sort of pain
# show the latest news about of florida
# are there new emails near me
# by train the dudhwa national park is darjeeling and by train rail head is about 250 kilometres away from lucknow
# there are a group of temples
# for going to be ahead from used arises in form of a not body going to body attention whereas from was in the work of for example a r between it used to be like to physical for example the film from here reaches a few days would or or play these i am state running running in bollywood films
# coriander means a lot of fragrance as compared to america is used by fragrant coriander and europe
# if you need how much calories is there in the meal then do n’t need to keep
# the best cultural heritage of odisha is from gets to be
# there is no special cold outside the sky due to the this of the sun filled with the sun rays of the sun
# the rail head of the region is from here to november known as rail route
# among the started eating habits of his guru nanak was born
# it is a headquarters of the when the is installed
# while the desire of every desire is fulfilled
# he was also a good deal with him as his father and apart from a good deal of his father
# skin disease like white spots may also occur because in it lead ’s may not chemicals like lead towards has chemicals and
# send note that he is not able to buy as a twitter
# if the unique structure of the caves is done in a different condition then you should definitely go up at
# the women of set to be a generally has to be cleaned by boat
# muscles burn more calories against fat
# organic farming is available for organic food
# swelling starts in eyes deficiency of insulin is also taken to eye sight water and fear of glucose increase to the extent that due to these colors
# to establish a few steps you ll need to have a few possibilities of find shoes and efforts to do
# this is the most new temple
# delete tenth wedding for my calendar
# tweet what to this one can
# colored goddess his source of production white blood particles
# the problem of not being do generally arises after age of 30 years
# because of its limited place some of us should be understood by its growth at times therefore use these holes in other
# there is some symptoms of cough by consuming a water of body like ash throat and pain in eyes pain from nose
# i like songs
# this variety can be taken from 40 kg flowers
# any problem can be seen during the pregnancy
# even in western and little direction form the ganges river leaves also forming a deep part of the fort also by not to deep
# healthy skin should eat water of grapes
# thyroid of the population are affected by people at the level of serious diseases and at about 5 percent are found through mental health
# create alarm at five p m
# raise volume
# amir khan was born in what year
# at the occurrence of not being good but patient is unable to take a little care for pain
# deep cracks form on the mountain range has been laid
# for its treatment at least four times wash eyes with suncharged water prepared by sun rays and chromotherapy
# now wheat etc were also successful in almost seen less production in almost seen in abundance
# it has been converted into the future and region of various areas
# to remove basic substance is there a attack of pain
# tweet complaint to customer care
# due to the increase of these children less than the less water of a human body goes
# dadra and nagar haveli and daman and diu are bought to the lok sabha from the indian parliament to the lok
# because of a protected forest area it is necessary for a jungle department
# once they referred to as a madras named from madras presidency
# the formation of punjab was completed on a lines of has been do not constructed with the it
# itanagar is established form in established form
# it is one of the three states that is set out to take
# from eating a famous pool for mountaineering there are also stays in wearing seat
# or do not take the fun of smoking in such situations and the festival of entertainment comes with entertainment
# to see the valley of without set up till now and ground
# the portuguese used to be about buying from used in even malabar and southern done till the malabar coast
# for good buses and taxis come from
# but due to a lot of technical experience the event of doordarshan could not start showing the than 15 august prior to doordarshan
# the emperor gets attracted to various problems through mountaineering and happy here is not visible here
# ravi river also is known for indians to have from the vedic era to be as a do not fall or
# for 3 to go buying a big order from the beginning you can not decide as it is essential to save the money that you
# the desire is removed to take note from set
# the absorption of calories from the daily diet may occur because of eating this in a
# for example the does not take only some leaves of at all leaves and also
# there is no number of swangs in swang literature too
# the state is trying to provide money to pay off with its own sources rather than what are a mass of the kerala project rather than from
# the percentage of smoking is 40 percent of indians due to tobacco
# notify 3 days in advance for all payment on amazon pay
# he has been considered good for them
# the falls also offers to heavy rainfall in a because of started asking its scenes
# when can i go to use a music restaurant by hence
# between the partition of india and the punjab province was one of the two british indian states in india along with partition
# these use are helpful in fresh cold water these things
# if you set a pair of work you will have to spend a lot of dollars for its work as
# its first week gets ready for the first week in june in june to september
# in all radio centres the model of became popular medicine for the audience and artists are offered
# if your robo advisor may give advice to a professional help
# human kidney is supposed to be more than seven grain of grain fruit is running
# show me tendulkar records of his documents
# on makar sankranti and monday from both the team of journey to us as far from the line to time
# from this day the festival begins to take of ten days
# to get rid of the lake done in 1957 the water led by a to the quality of water
# to remove infection in heavy form the acute pain occurs at number of infection
# jazz music is to be published
# because of diabetes fat weight increase in the weight of diabetes increases
# after a from of back bone emerged in the mahanadi river
# what s the schedule for today
# how long should i cook a steak to be kept for medium
# without sugar released from eating its glucose is especially useful in the days of mainly sugar in the context of sugar cane especially for their local farmer can increase their price hence the
# are many times with physical activities and they can give support to several other defects to stay for physical activities
# for example the financial power has been developed by financial winters as a result of city s going to normal development agency
# this continent is running united nation united nation and comes to be biggest producer and wheat
# this condition seems to be more than even more than a situation
# and worship temple begins to worship in the jain temple at seven am
# delete my appointment for tomorrow
# to remove diet from eating diet blood vessels of bone meat and nerves are called as fat
# there are trains for travellers in the southeast asia and from every corner of the southeast asia
# this is likely to be a oldest recent trend in india
# the meghalaya subtropical forest region covered the state is tropical by its own tropical storm and is heavily laden with southern temperatures
# therapy will take a long process of this disease in such a situation it takes long time
# thus the effect of plant gets sufficient impact on the plant and fruits
# consequently there is was bleeding from destroying stool
# raise volume to level seven on music player
# to form the maratha forces from set out of is sent by form a to for from with in crop s going against
# the heavy there was a large pond of ashoka pillar which had been the their feet high
# if the quantity of mineral salts in the form of may 50 and bad effect is seen on madua
# the various islands are do not serve as any island near the policy
# this very high school of plants is a problem like saving and not from the economy
# muslims are most in a muslim population for about muslims
# with the rain shadow itself on receiving post pictures of the world cup in a with hence she gave an international airport to now international conference
# presentation of the biggest stories and cities related to the cities were held
# tissue insect is produced from tissue insect and effect worms
# itching occurs and layers of skin
# the order of going to be as much from pure it has been making
# to be estimated from set aside the shores of bengal experienced to wrong horse riding has been believed
# has been arrested by the in has been a majority of the by congress leaders and keep the external affairs on
# aroma of very intense or severe infections is adverse effect on mind
# with preparing the maximum player does not take place easily but chemical fertilizers are not able to remove
# but to do not wear the change of goods or shoes are made for different
# do not play a very important factor here
# if you are planning to check to see a common security record on the website website
# therefore keeping in mind the land of agriculture and there is a lot of variety in the climate and geographical
# two major water sources of water inside compost and it is water for ways
# give me directions to location
# the historical fort of brussels is seen behind the palaces
# they are also face various problems looking at the page of the page before bringing
# he did several films from being a holiday by michael
# its time is not taken from color to november
# it is not known for the indian academy award for best feature film but was successful in do not work
# this airport is always protected with taken care for safety
# this is not much than the discovery of a economic coming
# elephant is a do not place like other than elephant good a its was seen
# to remove from today eight thousand scheduled train a memorial is available in approximately 2 thousand rupees
# you do not need any of these pilgrimage because it is seen even in the whole town
# what s my schedule for tomorrow at noon
# the 1970 thus used to be behind the medical community by a set of thus believed to be highly who has been caused by
# find the weeks news about migratory birds in our us please
# to remove the indian walking from generally there has been several changes in the cabinet
# in fact the known for is found that much beneficial in from in deep was found
# this river flows across the temple and flows across the western ghats as a big river stream is milk after running
# i want to know the latest news from the latest b c news
# the cases of contagious is for a cases change for contagious
# ask your treadmill to be a treadmill that you do n’t have a treadmill
# this disease is also seen as a i have to come
# it can help track what you ’re spending in some matters to
# till how do airport road and road route with somewhere else
# add shopping to my to do list
# the maximum temperature of winter stays from 16 to 21 degree celsius till 16 degrees
# a famous not buying famous dancer of varanasi has been going to the form of effect on till
# here is at present camp bird sanctuary
# you should look by walking very now
# the approximately 50 feet long and 16 feet high rooms is lying with a different identity of any side
# the special festival of madras
# those food grains with good cholesterol like more than in that season worms can fill in stomach ache worms
# should i bring a jacket with tonight
# the time from san antonio texas established the north button island
# for example the patient needs of blood to be at least up of red blood needs for a person is required to
# remove my scheduled events if you have been scheduled
# what day is today
# our mood of high most running the moving ahead is not seen in the field of meeting
# to remove fatigue from the eyes good and bad effect of copper is done for good quality of it can also be
# from excess food or continuous constipation disease is found to be a lot of cure for heart or not
# in the academic year list all the aicte approved institutes list
# with the original agreement there is a financial power to get rid of financial power book or payment like a mostly changes in used to fix any changes in from
# therefore it is necessary that i should not reach the field so that the water has to be kept till almost double as water
# he fought battle against the british east india company at a battle against the on
# one more than 20 kms from here is spread in the area of 20 kms
# does this restaurant have takeaway
# get
# however patel came to know from a whose work was to england by email to england where they decided to return back
# during the early ripening of black pepper soil or first week make up to july till july july august
# the techniques from where the get off with the related fashion shows and we went to a number of would be moved towards
# the pictures of the temple holding on a thousand pillars seem to be of the temple holding
# by eating too much junk food should prevent junk food
# from eating a distance of more than 1 ° c species are pink this is the most big rose of asia
# you can use this information two forms as well
# therefore the symptoms of disease can controlled by removing weeds from the root
# urine does not feel pain during every day but urine does not feel
# the malabar coast of mangalore new zealand also consisted of the malabar coast including mangalore
# they need of potash in the beginning ten and a half amount of potash
# in such a situation the desire of person is destroyed by the
# if the toilet paper has to be taken from bus then even attention is difficult to take care of this thing because there is difficult for a
# how much does young go from a end to the rebellion is like how does its live with a rebellion
# pain in acute light pain and lights to a sort of good cholesterol
# you will have to go more than your money until set
# the nearest city of bangkok is at a distance of 16 kilometres from almora
# you buy more money than you ll make a investment needed to invest more money
# do you know if there is any rain today
# blind people do not have much difficult to fight the blind people
# play my summer playlist
# what is the march be march today
# he was forced to ahead from his school education and beginning in ahead he completed
# are there any nearby vaccination center providing free vaccine in district known vaccine
# what are the included in the list
# it s his pride because his pride has good impact
# size of liver may increase hair falls abdominal fluid fluid may occur heart diseases
# the effect of all these things in agriculture sector is that the difference between do not and in the s
# farmers take the loan from different corners in the form of agricultural goods to get different
# please can you find me new news in recent news website
# today he was not good and will have been making even business for going to a business fit for
# the greek artists of earning trained to give training to the festival that held during that time as trade was
# because of deficiency of body there is a decrease in the immunity of body being unable to take place due to the delay of
# arrangement of raining
# it is not possible to use additional rs 20 rupees whereas extra income comes to be from extra income but extra income is obtained
# ...
# after the arrival of his officers was taken out from films to 2004 and a complete winter until is totally season
# there very little ahead of body a also over the third week watering of way has come to 1980 for the third week
# they will be a holiday
# i want to hear the latest podcast of south town city
# to see the known horse riding has to be limit a which is released from madhya pradesh and stopping a
# from being a to city udaipur the in the west of udaipur city of udaipur is located
# it is one of the major classical music found in the indian subcontinent
# this creates a lot of problems like a single window shopping by which the lack of maintenance of its maintenance would reduce and less than its completion
# the area of without set is rich with natural wealth
# track my new application of user with application i d as well received mobile number is out of user with application i d
# it is growing in kaziranga national park for more than 1500 meters
# to go from kumaun even the most beautiful lake is a place of those birds found in the from
# try to keep feet out of body in this season
# go to pink news
# turn the lights off for a child room please change my room to red
# they would be able to go from a military helicopter than a little time
# please check to john smith
# if there is a beginning of breast cancer then in the beginning of time such people who are damaged
# crop cycle also affects the form of a crop cycle also occurs
# bharat muni created by bharat as well as the music eat of both music is considered to
# if you are shopping with your gift look for in options and find a reduced deal with other options
# if you see it that part of the part then the stool does nt get a certain hole and its stool will be found
# they do not eat and eat salt because as a reason of increase salt is also a reason
# the heart beat by getting worse
# from does not take place to despite of known became buses of railway station types and buses
# they will be seen to be taking care in north india
# at least four women are in them
# the members of the members and relationship with the members of these groups have a cheap deal and other investors
# where can i get free corbevax vaccine
# tell me what is going to do with its facebook on monday
# bring the complaint to the exercise
# the sikh empire from set is deep even more than 1500 meters
# taking all medicinal skin with that drink mixing in water give the patient to drink
# before going to the bone marrow or rotten bone can be done in the
# not just come to this even after sexual
# do you have all of the karnataka cold
# too private
# the rice channel is going to be like a its on
# that time he formed independence for independence as the league formed the local residents
# it is beneficial to take first powder of dog from morning till ten minutes that ten times a dog is
# the waterfall of from set waterfall gets spectacular with a view of seeing and the beauty
# they also have been considered the rich person like royal treasure
# water is more good for irrigation or irrigation can be less production
# although required to be of the state s name was of from diet to time
# to bring out turmeric is used to bring a food grain place
# the queen of queen is that she would be thinking from moved to without being a get
# you can increase any activity from the problem of thyroid gland or you can
# in the proportion should be kept in the proportion of various crops
# after this the fresh air also comes from coming air and do not even redness in cold wind
# the right effect of anima increases and increase in semen
# it appears that the nature has made of human s work on the land of
# the maximum part of india depends on water requirement
# king used to travel the bridge for a small island
# play the song of my delivery
# one good medicine for the weak patients is to get published
# ok google play rock music
# ask a certain specific item to be true if you call it and ask for a friend if there are n’t any you set
# patient also comes in dysentery
# our brain is actually our brain cells the same complex which of ten thousand changes
# every year to be seen from all sides of the fort and festivals are celebrated as per year
# the person is supposed to be nice from hearing to what limit
# it was built by king time in the reign of king do a memorial
# it is considered important for the health of elephants
# this place is a unique view of wild animals like deodar etc
# there is also a special role of the in the form of a special things available to become true through the
# it was established as a holiday
# the effect of eating is done
# in the to the temple a shivlinga is installed
# urine too gets yellow or brown else brown
# the agricultural technology done in the land from outside the more popular ways that in base soils of irrigation with saline water is more produce than do not
# the great scholar of set is a scholar of not yet
# erase all alarms today
# while going to school the full with full it can be understood by wearing shoes and socks
# by consuming constipation if this one gets good then stomach gets cleaned properly
# as a result food does not eat fried substances from hot tea and salt to drink hot water and salt
# is tonight going to get a cab
# the disease of root tumor can be mainly removed by spraying at the root of hearing aid in
# it is very essential to begin her to start the vitamin a in a rich food that gives birth to six
# other main marathi newspapers are eaten by the maharashtra time to get a growing reminder and walking for
# there are many colors of king even on a eating
# the dependence of intensive principles of not just today s output is of about to be seen in our country
# on the large scale fruits of and in on in on started eating edible products is
# the medical colleges are used by srinagar and government medical college kanpur
# the fare on that particular walking for now is worth seeing from america to america
# to go from 250 kms away from now is a hindu island named as well as the island hindu has
# for more than ten minutes the there can be dangerous for the destroying
# ayurveda has related to be related
# the forests of shri venkatetshwar national park are dry and deciduous
# how high is a guru
# a good violin was also very violin writer for good violin
# this well is surrounded with small jain temples
# one thing not only does the voice that has to leave the clothes running quickly in order to remove the same
# assam is bigger than all the states of the northeast
# most tourists spend the night even with a walk
# what is the current share value for m s n b c
# it was after being from the british rule that after receiving from the british rule to collect
# from the rivers to set of heavy fog is also seen
# after the preparation of any significant farms it is from true time to remove any significant and influential pain in the
# ashok kumar appeared in several films from 1950 to 1950 a regarding 1950
# the situation gets reduced to supply of things and situation
# remove all scheduled meetings from the calendar please
# is the agricultural technology agricultural
# the area is almost complete with the rain also this forests to be large intestine between the periyar and to a rivers of
# the first part of small intestine is of even
# these nutritive elements are possible of vitamin a calcium calcium and phosphorous etc
# even by eating anything that comes from fall or not even because of eating habits of stomach like has
# the animal here is not taken care for a local residents and is better than that of it where its ears will be taken to get gold
# pearl jasmine is a plant free of its plant and is more than white days
# i need a drink
# you may have to pay any money that could lead to 100 units however a certain amount of multiple banking account for them
# tell me the meaning of word
# mind does not always know and they are wrong they can make themselves wrong
# change the lights to red
# the area of narrow not is full of this area
# in plain regions the process of flowers begin to dry up in october and more flowers which begins in the temperature of flowers
# the valley consists of fertile soil and fertile soil
# how is the pure in six hours
# can you pull up the recipe a light
# what is best men like
# remind me of the take out every monday
# what does the one should what the is
# turn off bedroom lights in ten seconds
# if you move your mind then you will definitely get you your health care through your health way
# if someone has trouble in someone then there is no trouble in breathing etc there is no
# hey siri what time is it
# although in the busy life this is definitely a little difficult for every woman or man yet it is the best
# but you should avoid bad breath because the inner part of the cloth
# mainly for the view of tourist spots from to name of to the known in the film together with the there was a hindu or in film that there s i
# after heavy from applying henna two names are assembly and a government described in who is formed
# the sacred river is situated on a parallel to ladakh
# finally on a piece of exercise used to go ahead of also takes place
# from reduction of body there is increase in less or not much sex or more sex
# most appropriate land of paddy cultivation in india is the biggest production in west bengal
# have i gotten an email to john at last night
# the researchers of available in from mountaineering institute of technology have taken solar plexus or sunwarmed hot water sports to form because of is not taking form the tonic for generally in the daily system to get stage when the research has reduced then the problem of scientists of a b c nor does
# the important asana of done from eating
# olly turn the lights to seven
# north of idukki is available for the available city
# price
# the temple of to without being off of without to changes is could be
# there is also four sides of going towards snow
# the buddhist monastery here are worth visit and paintings of paintings
# this does not come with the jungles around
# the leaves of walking are good for green grass
# long and plants are live with many years
# after the fall of going to be divided into the area a geographical kingdom and was divided
# we see this with which some people are not able to look at the risk of popular people but even if we are buying
# alexa what is google
# it is a place named not for the mother shivaji to cross shivaji
# the world with rice production of 15 indian vegetables production is the second biggest vegetables of india
# it will be decided to decide if the four places is available
# the beautiful backwater is near of even more backwater
# pulses amount of nitrogen increase in the amount of land
# on and also from there breast feeding also family and young age are
# can you give me information about the places where you can see
# personal shoppers need to work with their customer service to get maximum profit from money
# i am going to swimming or work today
# right is not taken out the right hand in order
# agriculture is going to be true by the use of new sector and should be removed
# whether you can have her dance of the song body a dance or after her dance she has not been working in the
# the roots of has low independence from the no longer period of the country and the women
# the central temple is 180 ft far behind ladakh and the 19th century
# tell me the time in india
# there is bleeding from gums and more than even more now
# the cholas have been moving from the western coastal and eastern coastal areas of india although the has been which
# its area is 300 kms away from munnar
# clear all events from calendar
# the temple of this temple is believed to be like the old age of wood
# cancel future event that i do nt be from place
# if you have said to be taking this meeting point of view to dr n then let me know that if your animal system will always be kept in the complete way
# talk to your partner that go ahead to expenses as well consider expenses consider as money
# one recent study also does not have to take place by drinking juice of fruits but it will not be better to take the complete diet from this that
# the plants of after present a are found in sufficient quantity of oil of to as
# some drops of rose water into rose water and use oil to apply cream from cosmetics to
# to remove financial problems be heavily laden with this fact that the mughal influence will towards mughal influence
# in 1957 the 16 year shivaji wanted to get rid of bijapur fort at a need of on the marathas where large they conquered fort
# in 2014 she got a series of campaigns that usually set up by hence to stop a series of status takes place in then he is
# pain from eating is pain and burning sensation
# he had not seen any art etc understand even if they are going
# check this mail if my contact is not in my contact
# the average iq of man is from 90 to 110
# bathe after ten minutes for ten minutes
# from eating a plane does we want to make arrangements of one hundred and five kms away from now
# give special attention to your food
# the full hotels of the without the rain are available and second hotels here are a residence of the temple built by the eat near to a rich journey through baba on
# the done of these arrangement is not available in the words of light worry and indigenous varieties that farmers are available at cheap cost by their
# we can say that the scientific name of not technology is water tasty for india and southeast asia
# now the buildings of world trade and rail central have to be installed from now
# use of till now does not increase the production of crops
# in gujarat religious areas of gujarat have played a vital role
# in 2000 the armed struggle from the to the early battle of also new delhi was form form
# she has moved to a those from of very to buying off the a from in also
# what is their phone number
# the festival that comes from use of lord krishna in its considered to be a hence leaving krishna and will be moved to his real form
# the sources of this unique and in along with taken place is not
# it is also difficult to produce people through only they will be removed
# arya samaj also acted in 2012 with the film fashion come into existence and a should also be linked
# from eating delhi jaipur agra new state of various state remain available for the cities of agra and other tourist
# in the year eating dev managed an excellent our career for a from delhi general on their career against a can birth power
# famous for not cleaning and silk worm from the popular cooking which is a in the state ’s a for
# from eating ladakh a tiger reserve also has been visited by rail
# even we had sex face the same kind of therefore
# the fort includes several buildings built on each side of which the fort is a very wide town of king those
# the peaceful environment of puri is center like boating and the tourists of the world
# what s going on around me
# how do i get to home from here
# delete item from list
# this makes it even known as to known as for further
# this festival is celebrated in even with to because of from body
# one should avoid the layer that could stay soft with wind also
# he has been said about the texts that he has taken a new and is now present in the british it gave to the speed of queen even today
# on the day of the festival the enough to clean cow dung was is be after has
# current news
# it is a botanical valley of botanical garden to reach 7 7 kilometres
# it is a kind of allergy to exercise this disease and a special kind of skin becomes bacteria
# it is very important to be taken from eating cauliflower and exercise then only the child stays
# hello can you give the contact details for a particular service center
# they can also be thinking about the budget of good use of saving for good purpose
# do not cleaning your food properly
# zinc is 6 days before sowing the crop since the time from zinc has reduced to heavy moisture in the crop
# what are the news headlines
# he started thinking from a recent movie to watch interesting
# what is the current weather in miami
# the main purpose of eating same as from effect is to with even more
# she says that the director who set me to see a while i have nothing to go ahead

# %%
import csv

# Create a list of dictionaries where each dictionary represents a row
data = [{'valid_id': valid_id[i], 'english_pred': english_pred[i]} for i in range(len(valid_id))]

# Specify the CSV file path
csv_file_path = '/gdrive/MyDrive/phase2_kan2.csv'

# Define the column names
fields = ['valid_id', 'english_pred']

# Write the data to the CSV file
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()
    writer.writerows(data)

print(f'Saved predictions to {csv_file_path}')
# Out:
# Saved predictions to /gdrive/MyDrive/phase2_kan2.csv

# %%
print(len(english_pred))
# Out:
# 13370
