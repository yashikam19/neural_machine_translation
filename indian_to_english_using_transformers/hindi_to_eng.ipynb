# %%
from google.colab import drive
import json
import pickle
import math
import numpy as np
import pandas as pd
import spacy
from collections import Counter
import torch
import torchtext
import torch.nn as nn
import torch.optim as optim
from torch import Tensor
import random
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torchtext.vocab import vocab
from torch.nn import TransformerEncoder, TransformerDecoder, TransformerEncoderLayer, TransformerDecoderLayer
import io
import time

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/train_data2.json', 'r') as file:
    data = json.load(file)

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/Test_data2_final.json', 'r') as file:
    val_data = json.load(file)

# %%
import string

# Define the remove_punctuations function
def remove_punctuations(sentence):
    punctuations = list(string.punctuation)
    cleaned = ""
    for letter in sentence:
        if letter not in punctuations:
            cleaned += letter
    return cleaned

# %%
# Process JSON data
source_sentences_train = []
target_sentences_train = []
len_hindi = []
len_english = []

id_train = []

for language_pair, language_data in data.items():
    if(language_pair == "English-Hindi"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              target = entry_data["target"].lower()
              source = remove_punctuations(source)
              target = remove_punctuations(target)
              source_sentences_train.append(source)
              target_sentences_train.append(target)
              id_train.append(entry_id)
              len_hindi.append(len(source.split(' ')))
              len_english.append(len(target.split(' ')))
# Out:
# Language Pair: English-Hindi
#   Data Type: Train

# %%
test_source = []
valid_id = []
len_val=[]


for language_pair, language_data in val_data.items():
    if(language_pair == "English-Hindi"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              source = remove_punctuations(source)
              test_source.append(source)
              valid_id.append(entry_id)
              len_val.append(len(source.split(' ')))
# Out:
# Language Pair: English-Hindi
#   Data Type: Test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Calculate the maximum length of hindi and English sentences
max_length_hindi = max(len_hindi)
max_length_english = max(len_english)

print(f"Maximum Length of hindi Sentence: {max_length_hindi} words")
print(f"Maximum Length of English Sentence: {max_length_english} words")
# Out:
# Maximum Length of hindi Sentence: 778 words
# Maximum Length of English Sentence: 206 words

# %%
pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.1 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 36.3 MB/s eta 0:00:00
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.13.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2023.7.22)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.3.0 sphinxcontrib-jquery-4.1

# %%
from indicnlp.tokenize import indic_tokenize
# Tokenize Hindi sentences
tokenized_source_sentences = []
for sentence in source_sentences_train:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tokenized_source_sentences.append(tokens)

# %%
tok_val=[]
for sentence in test_source:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tok_val.append(tokens)

# %%
# Tokenize English sentences
nlp_en = spacy.load('en_core_web_sm')
tokenized_target_sentences = []
for sentence in target_sentences_train:
    doc = nlp_en(sentence)
    tokens = [token.text for token in doc]
    tokenized_target_sentences.append(tokens)

# %%
def build_vocab(tokenized_sentences):
    counter = Counter()
    for sentence in tokenized_sentences:
        counter.update(sentence)
    v = vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'], min_freq=1)
    return v

# Build source and target vocabularies
source_vocab = build_vocab(tokenized_source_sentences)
target_vocab = build_vocab(tokenized_target_sentences)

# %%
print(len(source_vocab))
# Out:
# 80348

# %%
def data_process(tokenized_source, tokenized_target, source_vocab, target_vocab):
    data = []
    for (tokenized_source_sentence, tokenized_target_sentence) in zip(tokenized_source, tokenized_target):
        source_indices = [source_vocab[token] if token in source_vocab else source_vocab['<unk>'] for token in tokenized_source_sentence]
        target_indices = [target_vocab[token] if token in target_vocab else target_vocab['<unk>'] for token in tokenized_target_sentence]

        source_tensor = torch.tensor(source_indices, dtype=torch.long)
        target_tensor = torch.tensor(target_indices, dtype=torch.long)
        data.append((source_tensor, target_tensor))
    return data

# Process the data
train_data = data_process(tokenized_source_sentences, tokenized_target_sentences, source_vocab, target_vocab)

# %%
batch_size = 32
pad_idx = source_vocab['<pad>']
bos_idx = source_vocab['<bos>']
eos_idx = source_vocab['<eos>']

def generate_batch(data_batch):
  source_batch, target_batch = [], []
  for (source_item, target_item) in data_batch:
    source_batch.append(torch.cat([torch.tensor([bos_idx]), source_item, torch.tensor([eos_idx])], dim=0))
    target_batch.append(torch.cat([torch.tensor([bos_idx]), target_item, torch.tensor([eos_idx])], dim=0))
  source_batch = pad_sequence(source_batch, padding_value=pad_idx)
  target_batch = pad_sequence(target_batch, padding_value=pad_idx)
  return source_batch, target_batch

train_iter = DataLoader(train_data, batch_size=batch_size,shuffle=True, collate_fn=generate_batch)

# %%
class Seq2SeqTransformer(nn.Module):
    def __init__(self, num_encoder_layers: int, num_decoder_layers: int, emb_size: int, src_vocab_size: int, tgt_vocab_size: int, dim_feedforward:int = 512, dropout:float = 0.1):
        super(Seq2SeqTransformer, self).__init__()
        encoder_layer = TransformerEncoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_encoder = TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        decoder_layer = TransformerDecoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_decoder = TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(emb_size, dropout=dropout)

    def forward(self, src: Tensor, trg: Tensor, src_mask: Tensor, tgt_mask: Tensor, src_padding_mask: Tensor, tgt_padding_mask: Tensor, memory_key_padding_mask: Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        memory = self.transformer_encoder(src_emb, src_mask, src_padding_mask)
        outs = self.transformer_decoder(tgt_emb, memory, tgt_mask, None, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer_encoder(self.positional_encoding(self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer_decoder(self.positional_encoding(self.tgt_tok_emb(tgt)), memory, tgt_mask)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, emb_size: int, dropout, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2) * math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0),:])

class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size
    def forward(self, tokens: Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)

# %%
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=DEVICE)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt):
  src_seq_len = src.shape[0]
  tgt_seq_len = tgt.shape[0]

  tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
  src_mask = torch.zeros((src_seq_len, src_seq_len), device=DEVICE).type(torch.bool)

  src_padding_mask = (src == pad_idx).transpose(0, 1)
  tgt_padding_mask = (tgt == pad_idx).transpose(0, 1)
  return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
src_vocab_size = len(source_vocab)
tgt_vocab_size = len(target_vocab)
emb_size = 512
nhead = 8
ffn_hid_dim = 512
num_encoder_layers = 3
num_decoder_layers = 3
num_epochs = 40
transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers, emb_size, src_vocab_size, tgt_vocab_size, ffn_hid_dim)

for p in transformer.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

transformer = transformer.to(device)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=pad_idx)

optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
def train_epoch(model, train_iter, optimizer):
  model.train()
  losses = 0
  for idx, (src, tgt) in enumerate(train_iter):
      src = src.to(device)
      tgt = tgt.to(device)
      tgt_input = tgt[:-1, :]
      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)
      logits = model(src, tgt_input, src_mask, tgt_mask, src_padding_mask, tgt_padding_mask, src_padding_mask)
      optimizer.zero_grad()
      tgt_out = tgt[1:,:]
      loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
      loss.backward()
      optimizer.step()
      losses += loss.item()
  return losses / len(train_iter)

# %%
for epoch in range(1, num_epochs+1):
  start_time = time.time()
  train_loss = train_epoch(transformer, train_iter, optimizer)
  end_time = time.time()
  print((f"Epoch: {epoch}, Train loss: {train_loss:.3f}, "f"Epoch time = {(end_time - start_time):.3f}s"))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 6.491, Epoch time = 401.237s
# Epoch: 2, Train loss: 5.459, Epoch time = 403.970s
# Epoch: 3, Train loss: 4.841, Epoch time = 404.199s
# Epoch: 4, Train loss: 4.351, Epoch time = 406.045s
# Epoch: 5, Train loss: 3.961, Epoch time = 404.472s
# Epoch: 6, Train loss: 3.647, Epoch time = 405.581s
# Epoch: 7, Train loss: 3.390, Epoch time = 405.254s
# Epoch: 8, Train loss: 3.178, Epoch time = 404.949s
# Epoch: 9, Train loss: 2.995, Epoch time = 404.555s
# Epoch: 10, Train loss: 2.838, Epoch time = 405.304s
# Epoch: 11, Train loss: 2.699, Epoch time = 404.427s
# Epoch: 12, Train loss: 2.571, Epoch time = 404.525s
# Epoch: 13, Train loss: 2.460, Epoch time = 405.195s
# Epoch: 14, Train loss: 2.369, Epoch time = 404.497s
# Epoch: 15, Train loss: 2.301, Epoch time = 404.810s
# Epoch: 16, Train loss: 2.245, Epoch time = 405.085s
# Epoch: 17, Train loss: 2.190, Epoch time = 406.511s
# Epoch: 18, Train loss: 2.128, Epoch time = 405.386s
# Epoch: 19, Train loss: 2.066, Epoch time = 406.064s
# Epoch: 20, Train loss: 2.007, Epoch time = 404.570s
# Epoch: 21, Train loss: 1.954, Epoch time = 406.026s
# Epoch: 22, Train loss: 1.903, Epoch time = 405.797s
# Epoch: 23, Train loss: 1.857, Epoch time = 405.788s
# Epoch: 24, Train loss: 1.813, Epoch time = 405.794s
# Epoch: 25, Train loss: 1.774, Epoch time = 403.990s
# Epoch: 26, Train loss: 1.738, Epoch time = 404.457s
# Epoch: 27, Train loss: 1.708, Epoch time = 406.297s
# Epoch: 28, Train loss: 1.675, Epoch time = 405.220s
# Epoch: 29, Train loss: 1.648, Epoch time = 406.019s
# Epoch: 30, Train loss: 1.619, Epoch time = 405.389s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ef098b6808b6> in <cell line: 1>()
#       1 for epoch in range(1, num_epochs+1):
#       2   start_time = time.time()
# ----> 3   train_loss = train_epoch(transformer, train_iter, optimizer)
#       4   end_time = time.time()
#       5   print((f"Epoch: {epoch}, Train loss: {train_loss:.3f}, "f"Epoch time = {(end_time - start_time):.3f}s"))
#
# <ipython-input-22-6edae0fd3264> in train_epoch(model, train_iter, optimizer)
#      13       loss.backward()
#      14       optimizer.step()
# ---> 15       losses += loss.item()
#      16   return losses / len(train_iter)
#
# KeyboardInterrupt:

# %%
torch.save(transformer.state_dict(), 'inference_model')

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol, device):
    src = src.to(device)
    src_mask = src_mask.to(device)
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(device)
    for i in range(max_len-1):
        memory = memory.to(device)
        memory_mask = torch.zeros(ys.shape[0], memory.shape[0]).to(device).type(torch.bool)
        tgt_mask = (generate_square_subsequent_mask(ys.size(0)).type(torch.bool)).to(device)
        out = model.decode(ys, memory, tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()
        ys = torch.cat([ys, torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == eos_idx:
            break
    return ys

# def translate(model, src, src_vocab, tgt_vocab, device):
#     model.eval()
#     tokens = [bos_idx] + [src_vocab.get_stoi()[tok] for tok in src] + [eos_idx]
#     num_tokens = len(tokens)
#     src = (torch.LongTensor(tokens).reshape(num_tokens, 1)).to(device)
#     src_mask = (torch.zeros(num_tokens, num_tokens)).type(torch.bool).to(device)
#     tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()
#     translated_sentence= " ".join([tgt_vocab.get_itos()[tok] for tok in tgt_tokens]).replace("<bos>", "").replace("<eos>", "")
#     translated_sentence = " ".join(translated_sentence.split())
#     return translated_sentence

# %%
def translate(model, src, src_vocab, tgt_vocab, device):
    model.eval()
    unk_token_idx = src_vocab.get_stoi()['<unk>']

    src_indices = [src_vocab[token] if token in src_vocab else unk_token_idx for token in src]

    tokens = [bos_idx] + src_indices + [eos_idx]
    num_tokens = len(tokens)
    src = torch.LongTensor(tokens).reshape(num_tokens, 1).to(device)

    src_mask = torch.zeros(num_tokens, num_tokens).to(device, dtype=torch.bool)
    tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()

    translated_tokens = [tgt_vocab.get_itos()[idx] if idx != unk_token_idx else '<unk>' for idx in tgt_tokens]

    translated_sentence = " ".join(translated_tokens).replace("<bos>", "").replace("<eos>", "")
    translated_sentence = " ".join(translated_sentence.split())
    return translated_sentence

# %%
print(tokenized_source_sentences[3])
# Out:
# ['यह', 'शरीर', 'की', 'तनावमुक्ति', 'की', 'अवस्था', 'को', 'एक', 'पर्दे', 'में', 'प्रस्तुत', 'औऱ', 'अनुवादित', 'करती', 'है', '।']

# %%
translate(transformer,tok_val[150], source_vocab, target_vocab, DEVICE)
# Out:
# 'no what is you expect with respect to this code'

# %%
print(len(tok_val))
# Out:
# 23085

# %%
english_pred = []
for sentence in tok_val:
  pred = translate(transformer, sentence, source_vocab, target_vocab, DEVICE)
  print(pred)
  english_pred.append(pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# until you have not had close bracket you would get back to the bracket right and in between you can write for example you can write out multiple line for example if so let us say in is int this function int n i am able to do not change n what is n 1
# this was happening since many years
# due to the increase in blood supply is important
# there is no swelling of the nasik cavity to be used
# fill up the testing overnight in 05 mcfarland standard tube and stretch the surface of a mha plate
# there is a unique institute in this matter that it provides professional education to train managers for rural management
# john a of john in his opinion were particularly ask enough to promote the game in new regions especially eastern europe
# the first reign of of of of of of of is man and then to do it by of
# remains of many major cities can be found in delhi
# the nearest airport is pune 120 km
# the in this can be the historic site of over very importance as there was death of lord buddha over here
# the per cent of their service organization education in the education and literature gave the jain community a new direction and inspiration in the direction of overall development
# those beaches have their numerous special features
# it is a false thinking but in it the excess amount of those that are found quickly for the infant child
# what is the situation of traffic in the area right now
# meanwhile alauddin invaded chittor once again to make padmavati
# use among the herbal variety
# this is the case of in of this city
# so in fact y would be nothing but y hat plus some quantity right
# meanwhile in the us of the are of an in which his son is tried to remove alauddin from alauddin
# there is about thirty cm long rubber pipe that looks like mouth with mask in to be the mouth
# they also created some of the combined works
# look at the famous st peter church st peter s church saint peter fountains museum etc
# for you it is necessary to stop the fat properly
# for next stage in order we go to rain some late after rains
# only means are suitable to use grade disinfectant medical devices and equipment
# lemon lavender cedar lavender keep infection away and increase urine flow
# in brief we can say that there is a rich city in the culture and tradition
# the place in 100 kms south of agartala is where the excavation still on progress
# indian to there are first asian of visiting the area in the
# the fast of the or right woman with oh this entire woman will be able to be strong with the purity of behavior you will enable us to be strong and happy with the purity of the idea
# there is a fair of in the month named of jaisalmer there is a fair of of in the month
# the lower flow of yellow river ends at a delta of the sea
# the nearest rail head for this park is in in and 50 airport boston helps in delhi
# when it is dam on a boat the is planted in a up heavy was worshipped by burning incense sticks and to whether the boats are imported
# there is no main way to remove these flies
# it turns out that if the capacity of the last year is high you can even turn to 0 by loss without prior training
# inoculate a loop of suspension on the given on the there
# is there a sri finance company insurance policy on any sri lanka insurance company that lets me insurance for my whole family
# in order to be famous for its every kind of district there are also 12 kms away from here
# it can only be estimated only
# this museum also displays a collection of of or folk paintings
# the government of india honored him with the padma padma and the year of his father in 1971
# the rock clothes of were credited for the discovery of the available in them dr a in dr it is removed
# in this context the entire list of drama technique has been presented with the entire list of drama
# in india around 30 tonne oil is produced
# now suppose i have this w star suppose this is w star suppose this is w star so that i have interested
# as a result of the change in the summer production of millet cereals
# great as to be successful in their new work
# can you check the weather for me
# pinjore garden was also called the mughal garden
# screening of patients through the necessary in ncds for important
# east by this bridge the city is supply to srinagar city
# the in some places like are decorated with been loss of interest like this were decorated
# there is a in the in which there is an abundance of drinks and there are two restaurants called maharaja and queen where there are excellent food items of indian and rajasthani variety
# according to him they have long own feet special in their body
# the of the in the form of a which is watch for crime was never angry
# the national football league the most popular american professional football league is the average most of any professional sports league in the world
# dry rocks are prayer for some droplets and kept silent rate along with the coconut and the palm were giving up light air
# by this the growth of roots becomes good grain if there is thick and the duration of ripening reduces
# agricultural marketing system has been defined by many ways
# there is anus on the edge of large for
# but in general you should actually write down a function and we have already seen in the case of gcd we had returned to that value and returned that was what the value of gcd that is also our arguments are being given
# finish the median nerve in breaking blood so the blood loss mentioned
# if you can do this then take your child to the grocery store and spend some time in comparison to reading the nutrients and do not have the item
# for the and more than in for an indian there is 42 kilometres away from
# so arithmetic or logic unit or the brief names of the arithmetic unit or the arithmetic unit which are really the same for practical purposes
# the modern the is also the most modern in the beginning of the market farmers will also provide the with the help of this kind
# there are also collection of around all of the would be of the objects and old coins of today
# eat vegetables with leaves green vegetables plenty in spinach to coriander mint
# algorithms is familiar with algorithms so we will also use the term algorithms long division example form a physical symbol system theory
# since then there is a huge fair event in this place every year on the in this place
# to prevent the epidemic from time to prevent back of the epidemic this temple was established here
# there is a label in acceptable powder which is state showing generic name of its results in the context of essential amount of drug being expressed in the amount of required amount of drug activity usually g or international units and the end of it is expressed in date
# here only would be light if there are kept and grass
# today my promotion was very good for today
# the lungs adjust your you to exercise according to exercise
# keep the population of forests elephants and tigers
# refer slide time in slide so in there this condition is again something that is the right distribution and something which is the predicted distribution
# rajasthan is the real color of india
# this festival is held every year and the temple is providing as a hill trophy award
# i played a role in movement to express a in order to expand of tuberculosis in the united states except for tuberculosis that is in the united states
# after this she acted in until she as a husband s over she appeared in the as a this husband who was friendly than that daughter he had left her after birth
# there are waiting for all these and waiting of
# the two layers of the temple is there which is a sheet of gold and the temple has been built in the form of this
# however in anger and ear had several times war and which took him to her death
# for example you might have an internet bill while another electricity bill
# it gives an impression of extraordinary metres
# probably take the choice of good in the store to every side and then take to all those clothes changing room
# this conclusion comes out of 43 studies that soy infant is no adverse effect on human growth growth or reproductive studies
# so while adopting some rules we can keep our natural energy which we can enjoy healthy life
# many magazines were being used to be seen in these magazine
# it is considered the jain temple on the basis of the in the of the jain rule of could be the because of some records and according to the statue of for the this jain temple
# it includes thousands of rare ancient sculptures in sanskrit and prakrit
# antigen elisa detection of all the appearance of living in serum and hence the possibility of occurrence of active disease in a person is more likely to be associated in the presence of active disease
# for many all the sixth nerve systems there is one of the last common routes which control the eye activity in general
# in some form of this metal rich social columns ropeway etc are built at the beginning
# it was used for making lights and warm oil on elephants during invasion of time
# first place it in there is wet water
# there is a limited parameter of reactions in children and often different in the form of a function of facing
# 1 so use were ceftriaxone 50 also
# so even if they are just saying what is the good steps in s and t but we expect it in the programming course before certain how we expect it in the programming course
# can you list all the submitted renewal scholarship applications in the academic year in the academic year a academic year
# this particular point is equal to the same point is what you say right and it says is false that this is a simple thing that you define is a very simple point which you define if this is given this value is equal to that if this is true then you get back this is true how you get back to a truth is this function
# if cold is cough or you have put the finger in the nose then wash the hands properly with soap before eating in such a
# it stands as a padmasana posture of jainism in the while standing jain in a in a in a
# set notification for meeting
# c should be reduced from the food materials in order to measure up or completely around this there should be dietary materials of heat muscular fried foods muscular amounts of edible content carbohydrates do i am in this market
# ayodhya old city of ayodhya was discovered according to ramayana who was known as law law of hindus
# although this lake is saline it is surprising that it is a sweet water in the island
# for example king was the first ordered of nalanda and repair are also ordered with several sacred buildings in nalanda and sense
# only limited notifications for to of it is among the virus ’s from the heritage of the state
# today approximately 4 million people suffer from diabetes and it is likely to reach us up to 78 million
# till now since july to the last 34 months are being at considerable level in the last 34 months
# the professional squash organisation for men and women are conducted by on to on is of men and women ’s professional squash organization the is the
# again it is a sum right
# what is happening today between eight am and five p m
# i have been explained that we can choose to suspend the art treatment to reduce the above possible risks
# for photographs of this area of as far as possible
# please find mail address of john and tell me
# besides this if any person has any mental disease then it will not be a sleep too
# for that we have to use the turn option then always d for some delay and then using the turn option you will turn it to fifteen degrees
# deficiency of patient concentration weak memory anemia and up to the mothers suffering from mood
# hair become strong
# the blood flows through large vessels in so that it does not reach the lowest vein that enters the heart
# in particular about the in the from the country pilgrims come across the tour of this dev
# it is said that in the place of this temple the right thigh of mother top of ajanta is seen
# for sound broadcasting broadcasting system in sixth series of rs ₹ in the sixth scheme from which the amount of rs 25 crore has been allocated for the schemes meeting and new rs ₹ in
# do not consume fast food fast food made of white flour etc
# mixed with snow leopard and more than 150 species of wildlife some are other species of mammals
# set up the have i entered the river in the third time
# if the check use then through the regular in regular which is no choice to give money on the check list
# mumbai is the headquarters of western railway on central
# manu and the cliffs present at the point of time even keep a assembly of the placed of the same region
# mumbai is the center of all the attractive events in india with a continuous flow of performance in music dance and drama
# remember that there is no entry into the temple wearing a in this every middle measures wearing colorful clothes etc
# should the stage should be different based on the severity of the situation if the appendix had been torn or not before surgery
# it is known to be in of this with the characteristic of that there is growth of lung function loss in lung related symptoms and early mortality
# the village of making tobacco is from as they are at highway no 1 along the road till they are sown
# his grandson ashoka as his grandson ashoka as is may have suggested in fact half or a quarter greek would have been early
# so on individual as well as the basis of protocol for your patients is to be can be in clinical experience of literature
# equipment on equipment and cleaning items such as cleaning eating cleaning and toilet paper must be aware of the facilities used to give each cleaning
# display the volume power at the current track
# unless the germ is treated immediately with a given solution then till the high famine mortality rates are marked by the high famine mortality
# in the some goes to there is fear and it was not known as he would do this and the one would put his turn back chain
# where was i left today
# so just into this kind of a are the this type of towards itself is impressive also and absolutely fast
# located amidst the hills small and clean an town of an town with rolling green was rolling meadows magnificent pine trees pine trees beautiful trees beautiful with its magnificent sky from the peaks of the peaks of this would be planted in the high peaks of this hills
# national family health survey 4 conducted in in in in in as state of such states where the media is highest among the state
# in the 2010 decade of 2010 a single oral dose was shown as penicillin
# due to his belief people give him stop in such materials from all methods which produce an such kind of an such kind as the news
# put in the field of two types and put them
# on being more the number of animals the management of their food is done in two lines
# when a person of a person of need for 24 hours are treated generally they can not spread bacteria
# so earlier we are going to read in the income then we are going to check is less than is located at some is nothing if this is tax
# turn 15 degree a command says when i put it here and double click on it she is going to go 15 degrees
# now before we discuss in front about this neighborhood tell you also tell this kashmir road is in fact that this kashmir road
# by side put on
# google michael jackson
# you have to add a number of digits already before you already you have the point to add them so that we can do that
# reply to
# on their own good ability to remain aware of teeth and gums can be saved from teeth
# both began together with the entertainment channel of 24 hours from december 1994
# as long as someone who wants to develop the applications you are also interested in in in which you can represent how you want to represent who and we will see that this is quite subject
# some such kind of vegetation is in front of the correct identity of like some
# a narrow bag makes fishing difficult but allows more ball count and accuracy
# women are you to find out all the about this in of to if you ’re surprise to get detailed state information in the southern american city
# can it be he mentioned rain for today in forecast
# they may be infected if they breathe through another
# this national park is tourism in kenya which depends on these unique animals and these animal are such that only in africa
# two two two such plants have botanical growth of plant and second year flowers and seeds are formed in them
# the unique mountain of the ancient historical heritage of this historical place is seen in the visiting places like jaipur udaipur udaipur udaipur
# the sport is known as bandy in many languages although some significant exception are also
# so what happens now
# the early excavation of in for this was expressed in an important buddhist site where himself came to give buddha nutrition
# for the child of vitamin a has a lot
# set up in a short zone of early mediterranean into the same way the facing plains is worth it views of gulmarg valley
# they will realize that local a are very you get
# a study from developing country certain countries found that low growth in in in in through in which teenagers and young performance were related to the use of
# set alarm for thursday night at nine am
# ask your stuff to keep your stuff at shopping
# after this starts approximately 35 kms that is the trekking of 35 kms
# while close to ancient age cases that if any children were playing with a variety of familiar at childhood then such games will be called of which can be from him every of the
# india was the in the you mentioned of the in the asian cup
# there are some such situations in asia too in some other countries
# you should avoid alcohol because it will intervention with pills and you will make a highly sleepy
# for example x y
# physical examination
# after of to is during of
# the commission is expected that he would bring in poverty and in the subject of economic and from the perspective of development
# play me a major are visible playlist that are released this year
# if pneumonia afflicted children give the right dose of antibiotic
# it is wasted in order to compare how it s
# the area of in the of this for the tourists coming to the river and some of the
# and with peanut a sweet and sour dish we do not miss the tour on the schedule
# if something occurs in the eye then wash the tap water immediately with the tap water or be present in the laboratory first kit
# wake me up thursday six am so that i have a meeting time for the meeting
# in front of stress the person is important
# the folk heritage of punjab shows the history of its thousands years
# read me the news for the day
# autoclave at 10 its 1 minute to 20 minutes
# separate the pellet in 50 l of sterile are isolated
# so only this term will be
# you will get several shopping works soon and if you are about the point of view is true then you will get better
# who did i email to who recently
# what is the constructed of a stone in
# william fort or locally known as the in the form of of this is located in the in of the trishul district of kerala india
# headache and after the that there are causes of sugar and chocolate
# what is the least and what thing we should make for you to have the target we want this quantity is equal to one
# show me the latest notifications
# in kerala an elaborate way of pickles it are likely to be eaten in the why these are eaten
# so these are going to provide a high level north and hope that these higher levels answer will give you a sufficient background for that later on
# the major specialty of the temple are hundreds of pillars
# pulakeshin was the hindu of the for found in the they were is one of other religions including buddhism and jainism
# each mother should be taught to identify symptoms at their own child so that when necessary she can take the child to the doctor immediately
# what is happening on the news express
# there is one place in visiting places of jamnagar
# findings at hindi hiv aids
# here the statue of the universe comes and the statue of religious freedom you will also get to see
# one of the finest warriors of thailand a king a great and extensive empire put dr a mighty empire that included several parts of the neighbouring countries of today
# that is why these are also called folk dances
# surrounding private parts also use 23 percent women oil to deal with dryness
# the nearest railway station from here is through shimla
# he finished his name to is is in the city of srinagar the modern city of the state today capital of the state
# it is also a very good picnic spot
# this plant is capable of providing 40 all her school
# the fat present in the waist is removed from these exercises
# i can move how much to my bank account from my bank account to keep there in our bank account
# tell me the name and type of this music
# what you have chosen based on that the following page would be different
# for example if there is maximum limit of 8 hours then such crops should be less than 8 hours or less when the flowers come in the form of flowers
# the stem root of millet stem and grain potassium in the grain plant along with initial plant period gradually decreases
# this is also developing ecosystem and organic farming destinations where quite a few villages are changing as ecosystem tourism and farms are changing to organic farming
# refer slide time 1912 now what is the next step that i am going to do
# besides regular national vaccination schedule table 12 the recommended vaccines for health care being taken
# the central government of the in the in the in the in the you were received rs one lakh crore rupees increase in its back were there need of emphasis on the government
# so those who have some information about the organism science you have heard the word called mutation which is some changes in your gene which they say mutation
# if arthritis is not done at the treatment and treatment then by this it causes joints of the body and bones have to harm quite
# what temperature would we her at
# the acid going to be secreted in our stomach is so powerful that there is a good blade to make
# nearby the scenes open of camera are supposed to capture these views
# select media incubation time temperature and other facilities like gas p all of the agar
# in them such as the andaman sea animals are the wild bull into the this area tigers bull bull bull and there are wild
# from
# in out the above patients were as in then there was no additional antibiotic in during the followup tour
# beans are the main source of vitamin a
# in india it is the main food of the hill people and other plains of the country like rajasthan punjab haryana uttar pradesh and in madhya pradesh it is used for food and fodder
# it flows through the palakkad district located some of the last few kilometers
# so value n is 1 n
# the state s climate is influenced by the himalayan system and height related changes
# if you have never been ulcer in your feet before diabetes because of diabetes
# it is also practice in some parts of jharkhand and odisha
# the priest was so surprised that reading a etc read that there was a child lose a lose laughter in that calm before you half
# a hill and dense forest is well known as the is the is the being a distance of off the commercial harbour
# have i got ₹ a recent ₹ in payzapp to abhishek
# in fog cotton is the main crop in with does not form
# has my stock price increase
# the marine national park is spread in the 21 islands of of are there in the 21 islands of of as of this island
# many patients are lost and do not come to an eye days of next investigation
# oh this really sorry 1 minus beta raise to t minus 1 minus beta
# in the temple of for the there is a difference of the mughal and rajput style from there it s three rocks in the mixed style of bengal and mishra 49 feet tall of the
# generally people consume minimum water or excessive water in the morning
# so this is what is expected do just add some math and some regularization but at least its intuition behind this some how many of you get that intuition how many of that intuition
# now when you re getting with a professional you can talk about your risk tolerance
# place your medicines to place the mosquitoes and place with appropriate disposal
# after the formation of culture and tourism minister when i visited the fort for learning intensive study the red fort there i visited several landscape
# important should be paid to be such that other techniques of technology for telemedicine have some risk factors such as been to be used for proper training standards protocol and guidelines can be reduced through the exchange of appropriate training standards
# it is also called a of in
# there is been shown preparing a statue of the ten day ganesh chaturthi festival
# can you change the living room lights to soft
# in the evening every day in of this was performed
# coconut oil is usually used in cooking
# i am going to sleep it may be an activity that shows the i mean with gold or a supporting future so that i am sleeping in my mind
# other attractions of mud and old coins are appropriate
# this way keep in order of forward
# ajanta caves of ajanta extends up to the war of ajanta the rock cut caves of ajanta lies in a vast path of a gigantic horse into the mountain amidst the
# this place is considered the lord of the puranas at the same time
# the devotee is chosen that the animals get the protection of the earth from him
# in north india you can see an attractive array of temples palaces and festivals that are or her will be there right to her cultural society through different things and is an
# under this immune capacity of the body also decreases
# olly i want a drinks
# magic of his in screen so badly that when their popularity was at peak then people closed the name pran of his children was
# now the output of max of max becomes input for the next step
# so in which the gcd of 36 and 24 and then gcd of 99 and 47 has been printed
# delivery of your from there is contact with
# to reach periyar national park on the way there is a huge waterfall
# the ability of junk food also decreases in comparison to men and these things do not reach even by eating so much harm to men
# in the area of kali river where it flows through in the area of kali is named for black
# i need you to go to there night night can you book me a ticket
# massage the other hand of the child also in the same way
# if in the area around the goal is performed while turn you are suddenly a foul against that team automatically gets a goal
# there is a special dish style of macau which is called in
# do not take pranayama and meditation in the neck
# the best immune diet which offer a better immunization can be defined in three words a balanced and a
# on to reach the settlement etc people bring sheep sheep etc animals
# nagaland state museum has a offer to get a glimpse of naga culture through the history of all the times one has to be fixed in
# if gram negative on glucose negative in glucose she is alkaline with alkaline acid she she should contain gas alkaline acid several gas urea negative citrate test and for salmonella typhi negative indole negative
# but now we do not know this what we are going to do today we will not get to store all the digits instead of that we read 1 we read everything that we do with that points and then we will forget that
# the second wave of female journalists was because in seventy decade
# remove your tongue and head towards it above the finger and observe the surface of mouth and mouth
# the ayurveda system of north health service takes an overall approach to the disease management and the preservation of health in which it is a major aspect of maintaining the optimal health and immunity situation
# so it is important that in case cases of je are sent in the hospital early if the brain fever is suspected
# it takes quite times in distillation of high oil from all
# read the to the news from the to me today
# the average level of cholesterol in american adult men is to be at 100 is is there to be 100 is there per 100 in rural japan
# his foreign rulers used to bring in his breath to his little strong so his name was to be it
# this volume which has become old and 1 125 meter long and 125 cm are being thick to get the best cinnamon is considered better to get the best cinnamon
# in the present way there can be confirmation from only to the eastern punjab from the archaeological methods so its outside the greek presence was probably only for some time or not its existence
# a protective environment isolation related to an protective environment is made to reduce the risk of exposure of environmental fungal agents in patients
# the in addition of this waterfall known as in for the name of in these take place in the among the most of arunachal pradesh
# enjoy your holiday in kerala which is easily a state to visit the state through the roads and rail resources making travel relatively simple
# please note that i am using console
# send an email to me i am going home
# mir qasim on his part encouraged nawab of awadh and shah alam ii to engage the british
# the lake spread in blue and vast area the during every twelve big set of blue sky the charming beauty of the stunning natural grandeur if you do not want to without this place
# inside its called beautiful palace magnificent pearl mosque is
# the banks of the river are built here
# on 24 july 2012 the high court of rajasthan variable jahan and his other colleagues gave the charges of murder black deer against killing and his other colleagues making the initial route open
# the food resulting demand for better yield and better crop security should be satisfied with both 14 crore hectares of land need to be satisfied
# now we will see what is the format of the file
# give me the news of breaking news on c n n
# this is in this if you do not give x values python you produce x values itself
# audio play
# what kind of a trip to and how we can roam in taking your budget of our own
# on the basis of this false notion of medicine at all types of diseases of cancer and winters are used with intense belief
# alexa write email
# the mysore sultanate flag is at the entrance door of the fort of bangalore
# who is coming to the meeting tomorrow at ten am
# someone has been expressed by its voice in the complex but the just the protest
# in the summer season the maximum temperature of kalimpong remains of 70 its minimum temperature 100
# jama masjid in delhi was built during the period of shahjahan
# set alarm for four p m alarm
# as an actress one s agricultural term would include the coming in some films of 1997 to america 1995 in 1999
# i am not saying that this is the only solution to
# play this song from twelve am
# time examination is a major race in britain
# various kinds of wine used to be different with the there various kinds of wine
# kumar is credited with the finest singers of various times and male hit songs in the highest number of times
# the beauty of this lake has inspired numerous artists and still inspired by
# we have this again then this particular case it would have to change otherwise not change
# jeep was left on although the engine was put
# in this form of as per
# among top 5 to other temples such as to is to see the by this the jews temple such as the at some great religious sites
# in the hot air room for long time keep in turkey turkey
# there are cave burma market market burma lane and the cave cave are the other shopping centres
# bharatpur is at a distance of 180 km from delhi
# the desai in 1979 and vajpayee shifted to for to this janata party
# this is called in this way
# were accused of taking drug at men and 20 years of age and were accused of taking 2 drug on women of 35 years
# on this building the same line of crown at the top of the head dome can be seen from far off when these good to the middle of the could be seen
# this day in west bengal is also called the on the full moon moon
# he was appointed as the president of the indian national congress who organised a party by promoting the quit quit india movement in was in uttarakhand and 1937
# where you are eating the dirt present there is
# inflammation of urinary bladder happens in two types new or chronic
# for short times due to the reasons like for drying etc should be used thrice in a day
# despite being so much information it is very important that any disorder related to kidney then you should get the symptoms of any disease related to the doctor and in getting rid of the diet of this disease there should not be little carelessness and new carelessness in drinking should be taken off before this disease
# the street food here is not only cheap but tasty also
# islamic historians provide detailed description of this period and can be undertaken
# it is never certain that it will produce employment in a large number of service sector
# so if you actually look at that code and look at the assembly implementation of a string length function it will be the at the level of the function which is used to take advantage of loop at the minimum level and software level
# jammu is ruled by the royal kingdom of the jammu since the middle of the 18th century
# please play the new york city from
# there are statues of elephanta of mumbai or the statue of lord buddha situated in taking the sentence in this a pleasant image on the canvas
# the main ethnic groups are punjabi which contain the sikh and hindu major religious groups
# the maratha empire can not have along any attack and was weak and the dominated by the peshwa of the peshwa
# in archaeological excavation a quarter in the over two parts with islamic residence that was not far off the royal residence
# till in of ajmer had come into the influence of this land which went through some fine arts like king george a public school and the prestigious mayo school for the prestigious rajput princes and the prestigious princes in
# interesting this can be the shield of the present in front of the world s second largest amount of rainfall was done after the just like to because of some
# in the beginning of his career she in several films with this a in several films
# by which immune capacity increases
# then when some arab and merchants came into their palace they asked about the event
# in order to clean and produce like this grass is mentioned in the temperate environment
# viral culture in the groups of epidemics may be suitable
# place the item on the list
# it acquired them into the a in the and of the a
# their officials also attack on all this area
# most impressive musicians and singers have called mumbai his home
# right is you tried to learn programming before any time
# as if your partner had been used to manage your finance for a certain manner then a different account can provide them with autonomy within a few
# in a musical comedy film songs of kumar are included earlier times of kumar
# the second century above mentioned earlier with the highest being in work of completing the chance of the sudden
# by applying a paste of leaves of in this due to mixing very fine with cow milk inflammation of this is destroyed
# if you want to keep yourself in dogs then it will be an extra expense
# from here there is about 6 thousand feet for the philosophy of vaishno devi
# what is the most popular story on my facebook
# rock fort temple is built on the mountain of granite rocks
# to remove the frozen cough by removing the cough in the chest do a there on the chest
# people can buy significant later
# this child who does not get healthy on the occurrence of measles look at the disease of a cough in the throat or sore throat also
# negative prognostic markers has been considered by most writers groups divided on literature decision decision
# the only hydroelectric power projects in jharkhand are of the only hydroelectric power projects
# by august 2006 there were more than 135 of similar league
# the fever continues on 23 days
# it is believed that this was the place where the great muslim saint a was derived from the would be anand to the great muslim saint
# now what do i do this test time
# emperor of used to be here
# although the culture of kerala has been running fast for the steps of modernity the people still have their hearts of the traditions in their heart
# tell me todays date
# the sign is that in this lecture we care what was the other sign w star
# the state was largest from the point of view to 2000 when its southeast chhattisgarh region was named a separate state
# illegal sand mining markets are very active and the stopping because of the connection between these certain methods it becomes very difficult to stop
# so how does this work
# persons suffering from high blood pressure should adopt a diet based on certain fruits in the process of being healthy and take fruits for three times a day at the interval of every five hours
# i want to check my passbook balance of my account with uan number in uan number in
# so operator can be used to get the address of a variable
# but if there is to see the rajasthani culture then no place the good place from a
# i do n’t have any problem with this row
# most of all children are had years and they have education very less or very much
# so most people going to read by you will have algorithms which we will see after 10 minutes
# however if you want to shop regularly you can not always go with an member and you should consider membership
# it opens up all day of the week 10 in the morning and evening after 5 pm
# can be carried out by a good deal with efforts
# in this age when secretion begins slowly then the woman gets the problem of various kinds of diseases and problems
# what is my next schedule alarm
# after reaching the platform only i am going to avoid the song large yadav came with the song then double the audience
# the spotted deer common at the ecosystem of this sand are all kinds of migratory birds like black in found
# try to keep in good family away what you do not you are interested towards on taking it and appreciate yourself that you actually prove more than that
# you do not need the door to stop on his mouth gradually he will sign the thing to stop
# visitors interested to stay can stay in the hotel ganesh has their convenience in hotels
# different up social social media are able to do the professional and spend your day when they do some other work
# an extremely convenient city between can i enjoy the evening at the banks of the sea
# the first symptom of typhoid fever is headache and fever
# similarly we can say can say a random english word and present it as a challenge
# any conflict or intervention is determined by the referee in an intervention
# you take a irregular payment of of of of of of of of is 58 years
# keep cleaning the cotton colored double in water of doing some time
# currently the two and a half kilometres area of this peak is in the grip of a adverse effects
# if you say students in such times you will not be able to get many programs
# in case of absence of urinary bladder control in urine on not control women in should be had urine of those who may decrease urine
# we will green you in chess
# its head is black
# and these are only examples in the form of this state that we should implement any question in basically should be converted into a question about numbers and this is then when we solve those questions on computer
# in the beginning it may be a day of of the nation
# by this problem millions of people are afflicted worldwide
# the soil is cut once on the soil by using the amount of sowing and twice as early as the indigenous solve but make the soil flat
# rather allow the temperature of your body to adjust
# most species are grown in rabi season but the production of these species is less but the production of these species is being tried to be try that to give desirable growth in their production capacity
# in the lap of brahmaputra river a biggest river of the world is famous as island
# on an beach is very different because there are children park and other facilities for children here
# for spending expenses are available in all such as bacteria app or mint which implement family expenses and properties in a simple user interface
# is there for an of to be few from bal interest and a both of them
# future market a route of the related risks related to the price of commodity products etc
# arjun dev who was compiled in the text or the sacred text of sikhs the temple border that was later established every temple as a temple of lord temple
# the center of this valley is home to the great religion of this valley
# in adults an union therapy is 48 months in children that now are hidden inside the body for ending any leukemia cells
# also in order to say about two in this show this show how to bring a stories of spice in front whose fact people did not know completely
# these works the way of being used in a way for the body
# sometimes more milk production in chest is also there which is greater quantity in the greater than hunger of the child
# a myth is that shankar ji had left her the on her one
# they can only in an in an so
# what are the on the shopping list
# we took a at in the from for capturing a in and create a in the image of a single in order to capture single this image
# in brief we can say that there is a rich city in the culture and tradition
# we will do that so after distributed them we get the last digit so let me do that which i should do based on the points
# in the morning of marriage she tells him what was happened but police gives emphasis on meeting with her father
# what events are between twelve p m
# various competitions are organized under this
# in front of the in front of for which nanda devi is connected to the and the outer wall of nanda sanctuary
# i need to drink something
# the major benefit in scoring system can be studied in many factors together with the major factors of various factors the prognostic impact of the total picture instead of a piece of individual factors that make the prognostic impact
# next year he wrote a comedy film mumbai express and played the main role in it
# patient is in some state that he is on the extreme border of tour
# the government in this oldest in the india s oldest in science institutions was founded in to this
# in 2001 the delhi parliament on with a rich rise in delhi was attacked by f of a six security personnel in which there was killed
# after bringing together through fate mark and how to get their parents consent
# the total investment of odisha in the country was like a a list of odisha
# in ancient guru victoria got special protection in india on the advice of of in legend
# he is not very confused very often should not be worried how can i type something very quickly
# is there any vaccination center providing free vaccine for the age group 1517 years
# if there is in this then in the year must be properly for twothree times walls
# get up of the test plates
# can you help to search for esic centres located in area with pincode a pincode and offering cancer science services
# in childhood we have written all but only any cows cow is our only this way in doing the line of getting big but also this way is called
# you will look at the past and look at mistakes under it
# this place looks attractive from flowering of colorful flowers in the rainy season
# you will be able to know how much you can do in five minutes
# after the death of the sultan bahadur ad the royal capital was again moved back to ahmedabad
# play the latest podcast please
# there were village named in the coming back to of which new york city
# therefore if the farmer movement will do not have to fight it not just be fighting with the do but it also has to match the challenges of the world
# then food goes to the small intestine for the digestive digestive power
# many huge rocks standing on the beach are standing while holding the for the long waves of the sea while standing
# it is not necessary to say he won war
# so it does all those things but in this update we want to make up for some m at the mistake what we want to put in n and for some n put it into m a smaller mistake
# in mental we will be more careful and will place the self confidence and outside
# brahma accepted this prayer of gods and goddesses the fifth veda established
# we have to come with logic to see how do we fill out those missing values or how do we deal with this missing values any way of how do we deal with this missing values
# zika was rna of zika in patients acute phase of the disease transmission
# no significant difference was seen about the overall mortality rate of vap or in a duration of stay in
# after this asana its competitive asana be done like per cent present at it
# turn on wemo socket
# nerves of patient become swollen
# so this is our interest is the quantity of our interest in which we can not guess
# karakoram is surrounded by the eastern and being the in the north east of the in the it is bordered by the of the river and the indus rivers west
# the first indian palace in one of the worlds most individual housing palace was the first indian palace to use the air and could
# water reduces stress and helps in stressful patients
# located in haasan in the karnataka state is the holy place of those who have faith in is the religion of jainism
# your small pieces at the back and then eating the utensils itself on 15 to 18 months would be learned to eat
# that is why before pregnancy it is essential that a girl became her for a full woman
# many names have been given to same breed in
# if registered homoeopathic practitioner has been sending direct homoeopathic practitioner to a direct contact consent of the patient should ensure that he gets in order to obtain any other from present booking for drugs in a must
# the people here like life was like in the all manner
# the in of this there are a protected wild life area and tiger reserve spread over a total area of which is the this district
# yes a new research has been detected in that if the child is done in pregnancy then the possibility of the child going to be with the child of the produce increases
# to reach sariska national park is located at a distance of 80 kilometres in mysore
# dr l in order
# but despite the equality of the there is a difference of the gram and in the shape of the could be seen properly in the nature
# there are eight men evidence of these which are extremely artistic
# on their belief against the writers it was also seen in meeting the passion of dementia or her
# look out the there may be some of it
# its farming is done in the kashmir valley in the state
# but on the occurrence of cataract diet should be done in the form of everyday
# the movement is a few activity or walking around the glacier is very difficult and dangerous task
# after this in
# in the given to this area while lake was asked to forget his acting for his role
# in this the factory of insulin is closed and there is need to be insulin to suffer from the disease
# jharkhand was a in one of the most active beaches for visitors of maize and is still towards an active sea process
# a food allergy can help you make your child an allergy specialist treatment plan
# the temple was often invaded by aurangzeb of one of the mughal rulers but was unable to destroy the temple
# the director of the extension education dr s p s so that in the first time the training for the farmers has been provided as well as the farmers for agriculture farmers to get improved seeds vegetables and fruits
# a code organized that you understand it well and this once you become clear with it then it will turn this program to run
# along with the work of wooden in wooden a and for this carving is also done
# as of 2010 there was no professional team in japan but the university of at the university level of asia university and can be established in the university of
# it is difficult to describe the beauty of cotton farms in words it was appearing as heaven had herself surrounded the land on this land
# so ask questions otherwise i can not really help how many of you want i d it again
# this quantity of the almost kind of towards the almost simultaneously was that may arise
# exchange rate of into given square with dollar
# do not get the up market near the cotton market where you can get open towel sari towel and get tissue done by the weight and do not worry about the quality it is always good
# a special is beneficial in pain of ribs pain and weakness of lungs etc
# the diet should be taken in the form of diarrhoea
# staphylococcus resistance to vancomycin
# ...
# you have the main business in and that rice is the most important agricultural products
# you see that it is one of those ways in ways you are trying to ensure that an average neuron should not fire in the neuron
# australia has been divided into categories based on facilities and location
# and always have this as non result and could be the alternate statement
# i want some jazz music to play
# this is the best way of providing heat to the body
# this major tourist spot of south goa is built at a distance of 76 kms from will
# after from that i till that awadh united states and then agra came into the capital of lucknow made from 26 january 1950 the history of north region is that it is initially type of culture which is simultaneously and this is like this city
# the bridge also inspired the famous infant poetry bridge these which 1 can be inspired to be the present time period some staining was completed in 1972
# from north india all the major are being here in karnataka tamilnadu from where there is 8 hours distance of from the be 1
# to mark mothers confusion and how is the reduction of understanding and how to identify identification against identification and can cure dehydration
# set lunch lunch every day at twelve thirty
# besides this the confluence of modern dance with classical music make the festival memorable
# according to the situation of snow should be 20 25 cm or deep excavation
# if i look at stack picture left to right for case 1 then you will now see ebp plus 12 in ebp plus 12
# there is always between high temperature in may and august between may and august
# the figure is expected to be in the year 51 million tons in which year
# indian association for the cultivation of science asia is the first research institute of agriculture
# alert me thirty minutes before my three p m meeting tomorrow
# he did not give much strength on self performance while manipur is absolutely appropriate
# now this f is called a character stable and these three characters are the wire of characters together these wire is actually the ascii value of the us character
# but why do not going to go media look at the tv which is only cheap things
# when the gland is active it increases capacity in life and increasing
# on occurrence of in the heels rub oil prepared through sun rays and chromotherapy apply sun charged with the medium of sun rays and color therapy
# most of the forts have been taken by army and are out of the tourists
# four rivers that flow in this region are the chambal river kali river river there are rivers that the famous are the rivers of
# so now this definition again is a slightly wrong
# this once a all started attracting viewers
# most of these nature is still smooth
# major cancer place lung breast esophageal cancer uterus cervix neck tumor soft tissue and all kinds of in tongue acute renal cell you are from are to this without in this group only
# the world squash federation is expected that their way would be strong for possible includes the 30 warm olympics
# the cause is tuberculosis very intense disease
# genetic factors
# while protecting most of course from certain moisture and high temperature sowing would be done in order to certain would certain get better
# what should i remember
# surrounded by forests in this beautiful field of switzerland in the middle of all regions old traditional buildings has been standing again in their original style
# look at in contact
# show work
# prevention is common in good agricultural and industrial hygiene in industrial countries
# consider
# in indigestion one can get relief by feeding it in ten grams of leaves of leaves of on add black pepper and being them
# there has been relatively increase in the development of tourism and environment
# sand is primarily found in the southern region which is first found in which some soil mixed
# this temple is dedicated to the hindu deity lord in
# due to being installed on so last there is a would like that of them
# transplantation is called transplantation from one place to another place
# then we are going to read the next value the next value is to read and the value taken to the next variable called and we ’ll stop it in the
# 2 from high china peak of himalayas covered with snow peaks of the himalayas and beautiful view of the city can be seen
# in fact form of whole mung bean is used in the form of generally without skin bean is more used but in kerala usually whole mung bean often by eating out whole pulses a dry dish apart from boiled rice considered to be a dry dish
# the international sports are now conducted by the international in the can the in the form of international level
# do not forget to buy the antique and decorative objects made from wooden decorative items made from wooden decorative items made from wooden hand fragrant perfumes etc
# so in that case i am going to look at the of each class right which can obtain at the built of the low medium and the low value count function the possible of each class
# coconut also protects us from obesity
# of this was first diagnosed by a medical committee in post stress disorder and he recommended several request to tell about this
# ahmedabad is well connected to the different towns of gujarat with train
# in this year only a german tourist claim to take pictures of the lake st in the can be identified
# do not forget to smooth the instrument of a making an instrument in front
# during this period there were several texts in the emperor of emperor and into this period ad i had established various texts on the war art and they were expert of these systems
# it is known from the in the coming manner that the requirement of a great blood circulation was required and the operations of body were also very much
# a small group of authorities and their families have sought shelter in jhansi fort and rani asked for those who come out of
# how was your day today
# in the zoo of jaipur the most number of birds is of 83 species
# ajmer is an important pilgrimage place in the country but neither are a well developed industrial base and nor a basic structure that make it strong
# the height of the african lion is a little more than a time while they were found in each part of india
# in the there are micro dilution of the antimicrobial agent with was there in the there current mic panel in order to be micro agent and in the panel
# he was the age of number of space and could be the struggle of indian journalists
# china where you think and in the there is a entire democratic country
# list number of in mumbai india
# then in order to control the in this may be necessary particularly in severe chest infections or pneumonia
# there are many ways for this
# it can also be mentioned that danger increases in women after the age of 50 and decreases in men
# there are many backwaters areas that are used for commercial inland inland
# like water based hand applied to be more than all these could be bought from the this is the you d or the other
# bipasha basu is seen in his new film in which a player is visible and hence they have to reduce his weight
# it is a plateau covered with dense forests situated at a height of in the height of a or are there
# those people who live in close contact with the person who has become a or c type of bacterial meningitis should also be given the vaccine of that particular special type if they are not required in contact with group b
# who s link of press conference
# the food of the day was in the an at the an
# let us assume that it is an integer for now
# is today new york city delay in get
# for display their collections of collections in tokyo and paris has been exposed to show a single sign of jewellery
# the 16th day of kurukshetra war is devoted to bhima fully
# the process of hair becomes slow by using its white for the since the cutting of the hair
# if there are heavy clouds in sky then its water is visible blue
# after that there is important news in the lead three or two columns and the remaining column are in three columns
# green grass is only m free to be there in the shape of a feet or were
# 60 in which heavy there are seasonal roots seasonal roots and this is heavy rectangular shaped leaves
# consume fresh fruits and vegetables more and especially in the consume the fruits like vitamin c orange tomato orange about 10 tomato and heavy add to the add
# do you know the actor surya
# in fact your weight may increase the fat alone but the cholesterol is not increasing your weight alone
# punjabi cuisine has a variety of cuisines for its specific characteristics
# resume the current audio book
# in the morning one day their neighbouring came to be 50
# however some institutions have started the are of training of this right
# the same function learned from different data point is very different
# they are mostly used with the manner
# how do i make a a a how do i make
# with the practice of these women remain in and of a man both of these
# stress on the excessive physical weight loss because they also have to tolerate weight burden of your weight
# total of 27 training programs were organised by the training and tour unit to every three different departments in the past 20 months of broadcasting education and public access
# the test of developed varieties has been done in the agricultural research centers situated in tamil nadu and madhya pradesh
# always these principles are used in some or the other form of all these principles for there
# they include the evidence to action as evidence suggests the representation data representing a accuracy data indicates the exact data that the measured data must be reflected to a second unit of accuracy data and the target of a data called as a particular data called can be presented for such a significant persons who are presented in the do a how can be presented
# 12 x 100 mm tubes
# you can identify all india radio by this sound
# in every thing there is patient of like of at night
# the construction of this cannon was done in the jaigarh factory in the are done
# last fever is there
# among the increasing risks of diabetes and heart disease the country is becoming victim of chronic kidney disease
# there are more than 90 players in the canadian and american are
# its main reason is that the area of this crop is low and spread over
# v is an important pathogenic on to be in small children whose cause of acute respiratory tract infections
# less fat low salt high fiber should consume the whole grains fruits and vegetables
# in this there are in this to from place of into
# in this in of in of muhammad bin tughlaq was hidden in these mountains after the invasion of them in are from muhammad bin to 13 years
# its name came from to is a in the for which there is a bird sanctuary also the national sign of new zealand
# so we are still trying to see what is the learning rate of light right
# it is always kept in a clean and covered place
# tourists centres are also available from small and cheap hotels for tourists
# although 70 percent women complain to social activities like shopping and friends
# it is to save the farming and deal with food crisis then it is essential to add up the campaign to connect people with farming
# in maharashtra marathi and these considered mostly english is understood
# in the relationship of first there is new central is the complete presence of gold
# so clearly if there are capacitors and if you told your students to store each capacitors 0 or 1 so definitely the formula will not go there
# he is still standing
# because these materials of the body will not be more hard to digest food
# the enemy of many people are external
# the baby who is less than one year drink milk of cow or goat milk
# turn on vacuum cleaner
# this insect appears in almost all the pomegranate production regions
# the square night ravi across the ravi meet the and a kind of classic writers
# immediately after land cultivated in flowers typically when the flowers are exposed to cultivation immediately when cultivation is wasted and some can be cut and dry
# it is an independent river which has its valley
# the ganges festival of kartik falls on fifteen days after the festival of celebrate the festival of celebrate
# after the 1967 elections gandhi began gradually move towards the to the from the to the it
# the manager decided our program for the morning
# and then python came because keeping the body science of python program it was known as keeping in mind the body
# these programs are available in the entire country because of this new
# with the help of his brothers her mother was saved and of now
# i will have stored the value of the longitude which is the row of float
# in order in this in the of in order up in about normal state
# the do by the of the of the tropical storm government has converted into a warning for to of in to with tropical
# the more than the up area is found here among the up market is about
# he was made thumri the lush and popular
# they are naturally among their atmosphere and for example they may eat some dust in sand box for example in a box
# this is an experience where we keep at risk together
# do i have a meeting on saturday on march twenty five
# this service transmission meets more than 70 hours of program
# the institutions that run special school for people to their handicapped people are given for 90 percent
# in the dense trees of here come out of the dense trees beautiful trees of the tourists the local style of ‘ indian ’ on track are also 10 ml along with the birds coffee
# they were collected in the past 200 years of
# we can ask for information from school and health all the questions can be in
# it is clear that wearing face masks even a socalled comfort mask so in the to be important role in the a socalled kind of mask
# a specialty of swangs is also that in these dialogues are mentioned at the places of the ancient incidents in these dialogues
# it is a waterfall located in the town of in a quarter of mumbai
# with the suggestions to service your independence is certain whether you want to stay in the city centre set in a private island exercise if common in one private island
# there are natural caves in is in in an early historic period inhabited by digambar monks residence
# start playing and this very low end of
# the early a in the initial also worship the supreme deity of all and followed by its ancestors
# swelling may occur around in boys after a or a while there in young youth
# this is why in a of this called for up to here
# birds of tribes and diverse species of tribes in indira gandhi zoo are
# in the wheat producing zone of mediterranean in the regions of around 35 mediterranean square and some of these are perennial in the this average form of perennial varieties in the regions mentioned in the form of perennial variety and large scale
# children are less likely to have disease particularly for adults
# loamy soil is not appropriate for pomegranate
# now all this are essential to obtain the data properly and their up to
# in this germ called from the germs called which helps the throat and sometimes even the skin
# in cash crops grown in a temperate climate include many grains wheat crops like maize mustard oil barley barley barley oil such as to be of potatoes such as potatoes nuts or fruit nuts and soft fruits such as apples should be strawberry
# it is a endless loop that will break that will break at the end point in the end of the game if you will come to the last point then the elite turn zero player is for one
# now can you guess what would happen
# olly what s the weather right now
# the biggest speciality of this fair is a confluence of unity in diversity
# at the name of arrangement of stay here can stay in has been at an where there is no time
# dissolve the teeth everyday to make the healthy and strong
# after some years when people forget to give grain this entire can be converted into a form
# located on 17 kilometres of the in the city of as per the city is divided into three sections by the waterways of chandigarh canal
# in the development of this city is individual native apart from its river traffic level which is now increasing rapidly

# %%
import csv

# Create a list of dictionaries where each dictionary represents a row
data = [{'valid_id': valid_id[i], 'english_pred': english_pred[i]} for i in range(len(valid_id))]

# Specify the CSV file path
csv_file_path = '/gdrive/MyDrive/phase2_hi2.csv'

# Define the column names
fields = ['valid_id', 'english_pred']

# Write the data to the CSV file
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()
    writer.writerows(data)

print(f'Saved predictions to {csv_file_path}')
# Out:
# Saved predictions to /gdrive/MyDrive/phase2_hi2.csv
