# %%
from google.colab import drive
import json
import pickle
import math
import numpy as np
import pandas as pd
import spacy
from collections import Counter
import torch
import torchtext
import torch.nn as nn
import torch.optim as optim
from torch import Tensor
import random
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torchtext.vocab import vocab
from torch.nn import TransformerEncoder, TransformerDecoder, TransformerEncoderLayer, TransformerDecoderLayer
import io
import time

# %%
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/train_data2.json', 'r') as file:
    data = json.load(file)

# %%
# Read JSON data from file
with open('/gdrive/MyDrive/Test_data2_final.json', 'r') as file:
    val_data = json.load(file)

# %%
import string

# Define the remove_punctuations function
def remove_punctuations(sentence):
    punctuations = list(string.punctuation)
    cleaned = ""
    for letter in sentence:
        if letter not in punctuations:
            cleaned += letter
    return cleaned

# %%
# Process JSON data
source_sentences_train = []
target_sentences_train = []
len_telugu = []
len_english = []

id_train = []

for language_pair, language_data in data.items():
    if(language_pair == "English-Telgu"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              target = entry_data["target"].lower()
              source = remove_punctuations(source)
              target = remove_punctuations(target)
              source_sentences_train.append(source)
              target_sentences_train.append(target)
              id_train.append(entry_id)
              len_telugu.append(len(source.split(' ')))
              len_english.append(len(target.split(' ')))
# Out:
# Language Pair: English-Telgu
#   Data Type: Train

# %%
test_source = []
valid_id = []
len_val=[]


for language_pair, language_data in val_data.items():
    if(language_pair == "English-Telgu"):
      print(f"Language Pair: {language_pair}")
      for data_type, data_entries in language_data.items():
          print(f"  Data Type: {data_type}")
          for entry_id, entry_data in data_entries.items():
              source = entry_data["source"]
              source = remove_punctuations(source)
              test_source.append(source)
              valid_id.append(entry_id)
              len_val.append(len(source.split(' ')))
# Out:
# Language Pair: English-Telgu
#   Data Type: Test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Calculate the maximum length of telugu and English sentences
max_length_telugu = max(len_telugu)
max_length_english = max(len_english)

print(f"Maximum Length of telugu Sentence: {max_length_telugu} words")
print(f"Maximum Length of English Sentence: {max_length_english} words")
# Out:
# Maximum Length of telugu Sentence: 101 words
# Maximum Length of English Sentence: 107 words

# %%
pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.5 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.7 MB/s eta 0:00:00
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.9)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.13.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2023.7.22)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.3.0 sphinxcontrib-jquery-4.1

# %%
from indicnlp.tokenize import indic_tokenize
# Tokenize telugu sentences
tokenized_source_sentences = []
for sentence in source_sentences_train:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tokenized_source_sentences.append(tokens)

# %%
tok_val=[]
for sentence in test_source:
    tokens = indic_tokenize.trivial_tokenize(sentence)
    tok_val.append(tokens)

# %%
# Tokenize English sentences
nlp_en = spacy.load('en_core_web_sm')
tokenized_target_sentences = []
for sentence in target_sentences_train:
    doc = nlp_en(sentence)
    tokens = [token.text for token in doc]
    tokenized_target_sentences.append(tokens)

# %%
def build_vocab(tokenized_sentences):
    counter = Counter()
    for sentence in tokenized_sentences:
        counter.update(sentence)
    v = vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'], min_freq=1)
    return v

# Build source and target vocabularies
source_vocab = build_vocab(tokenized_source_sentences)
target_vocab = build_vocab(tokenized_target_sentences)

# %%
print(len(source_vocab))
# Out:
# 91169

# %%
def data_process(tokenized_source, tokenized_target, source_vocab, target_vocab):
    data = []
    for (tokenized_source_sentence, tokenized_target_sentence) in zip(tokenized_source, tokenized_target):
        source_tensor = torch.tensor([source_vocab[token] for token in tokenized_source_sentence],
                                     dtype=torch.long)
        target_tensor = torch.tensor([target_vocab[token] for token in tokenized_target_sentence],
                                     dtype=torch.long)
        data.append((source_tensor, target_tensor))
    return data

# Process the data
train_data = data_process(tokenized_source_sentences, tokenized_target_sentences, source_vocab, target_vocab)

# %%
batch_size = 32
pad_idx = source_vocab['<pad>']
bos_idx = source_vocab['<bos>']
eos_idx = source_vocab['<eos>']

def generate_batch(data_batch):
  source_batch, target_batch = [], []
  for (source_item, target_item) in data_batch:
    source_batch.append(torch.cat([torch.tensor([bos_idx]), source_item, torch.tensor([eos_idx])], dim=0))
    target_batch.append(torch.cat([torch.tensor([bos_idx]), target_item, torch.tensor([eos_idx])], dim=0))
  source_batch = pad_sequence(source_batch, padding_value=pad_idx)
  target_batch = pad_sequence(target_batch, padding_value=pad_idx)
  return source_batch, target_batch

train_iter = DataLoader(train_data, batch_size=batch_size,shuffle=True, collate_fn=generate_batch)

# %%
class Seq2SeqTransformer(nn.Module):
    def __init__(self, num_encoder_layers: int, num_decoder_layers: int, emb_size: int, src_vocab_size: int, tgt_vocab_size: int, dim_feedforward:int = 512, dropout:float = 0.1):
        super(Seq2SeqTransformer, self).__init__()
        encoder_layer = TransformerEncoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_encoder = TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        decoder_layer = TransformerDecoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_decoder = TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(emb_size, dropout=dropout)

    def forward(self, src: Tensor, trg: Tensor, src_mask: Tensor, tgt_mask: Tensor, src_padding_mask: Tensor, tgt_padding_mask: Tensor, memory_key_padding_mask: Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        memory = self.transformer_encoder(src_emb, src_mask, src_padding_mask)
        outs = self.transformer_decoder(tgt_emb, memory, tgt_mask, None, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer_encoder(self.positional_encoding(self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer_decoder(self.positional_encoding(self.tgt_tok_emb(tgt)), memory, tgt_mask)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, emb_size: int, dropout, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2) * math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0),:])

class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size
    def forward(self, tokens: Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)

# %%
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=DEVICE)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt):
  src_seq_len = src.shape[0]
  tgt_seq_len = tgt.shape[0]

  tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
  src_mask = torch.zeros((src_seq_len, src_seq_len), device=DEVICE).type(torch.bool)

  src_padding_mask = (src == pad_idx).transpose(0, 1)
  tgt_padding_mask = (tgt == pad_idx).transpose(0, 1)
  return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
src_vocab_size = len(source_vocab)
tgt_vocab_size = len(target_vocab)
emb_size = 512
nhead = 8
ffn_hid_dim = 512
num_encoder_layers = 3
num_decoder_layers = 3
num_epochs = 40
transformer = Seq2SeqTransformer(num_encoder_layers, num_decoder_layers, emb_size, src_vocab_size, tgt_vocab_size, ffn_hid_dim)

for p in transformer.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

transformer = transformer.to(device)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=pad_idx)

optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
def train_epoch(model, train_iter, optimizer):
  model.train()
  losses = 0
  for idx, (src, tgt) in enumerate(train_iter):
      src = src.to(device)
      tgt = tgt.to(device)
      tgt_input = tgt[:-1, :]
      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)
      logits = model(src, tgt_input, src_mask, tgt_mask, src_padding_mask, tgt_padding_mask, src_padding_mask)
      optimizer.zero_grad()
      tgt_out = tgt[1:,:]
      loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
      loss.backward()
      optimizer.step()
      losses += loss.item()
  return losses / len(train_iter)

# %%
for epoch in range(1, num_epochs+1):
  start_time = time.time()
  train_loss = train_epoch(transformer, train_iter, optimizer)
  end_time = time.time()
  print((f"Epoch: {epoch}, Train loss: {train_loss:.3f}, "f"Epoch time = {(end_time - start_time):.3f}s"))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 6.615, Epoch time = 149.950s
# Epoch: 2, Train loss: 5.785, Epoch time = 149.689s
# Epoch: 3, Train loss: 5.360, Epoch time = 149.630s
# Epoch: 4, Train loss: 4.992, Epoch time = 149.530s
# Epoch: 5, Train loss: 4.662, Epoch time = 149.595s
# Epoch: 6, Train loss: 4.367, Epoch time = 149.206s
# Epoch: 7, Train loss: 4.094, Epoch time = 149.074s
# Epoch: 8, Train loss: 3.843, Epoch time = 149.586s
# Epoch: 9, Train loss: 3.614, Epoch time = 149.644s
# Epoch: 10, Train loss: 3.396, Epoch time = 149.528s
# Epoch: 11, Train loss: 3.195, Epoch time = 149.701s
# Epoch: 12, Train loss: 3.008, Epoch time = 149.572s
# Epoch: 13, Train loss: 2.831, Epoch time = 149.512s
# Epoch: 14, Train loss: 2.668, Epoch time = 150.077s
# Epoch: 15, Train loss: 2.515, Epoch time = 149.655s
# Epoch: 16, Train loss: 2.375, Epoch time = 149.532s
# Epoch: 17, Train loss: 2.244, Epoch time = 149.974s
# Epoch: 18, Train loss: 2.125, Epoch time = 149.731s
# Epoch: 19, Train loss: 2.016, Epoch time = 149.478s
# Epoch: 20, Train loss: 1.926, Epoch time = 149.514s
# Epoch: 21, Train loss: 1.846, Epoch time = 149.621s
# Epoch: 22, Train loss: 1.780, Epoch time = 149.498s
# Epoch: 23, Train loss: 1.724, Epoch time = 149.922s
# Epoch: 24, Train loss: 1.676, Epoch time = 149.815s
# Epoch: 25, Train loss: 1.629, Epoch time = 150.284s
# Epoch: 26, Train loss: 1.572, Epoch time = 150.460s
# Epoch: 27, Train loss: 1.520, Epoch time = 149.918s
# Epoch: 28, Train loss: 1.471, Epoch time = 149.575s
# Epoch: 29, Train loss: 1.427, Epoch time = 149.461s
# Epoch: 30, Train loss: 1.384, Epoch time = 149.755s
# Epoch: 31, Train loss: 1.346, Epoch time = 149.222s
# Epoch: 32, Train loss: 1.311, Epoch time = 149.350s
# Epoch: 33, Train loss: 1.280, Epoch time = 149.316s
# Epoch: 34, Train loss: 1.247, Epoch time = 149.218s
# Epoch: 35, Train loss: 1.219, Epoch time = 149.378s
# Epoch: 36, Train loss: 1.194, Epoch time = 149.018s
# Epoch: 37, Train loss: 1.169, Epoch time = 149.535s
# Epoch: 38, Train loss: 1.150, Epoch time = 149.017s
# Epoch: 39, Train loss: 1.130, Epoch time = 149.662s
# Epoch: 40, Train loss: 1.112, Epoch time = 149.949s

# %%
torch.save(transformer.state_dict(), 'inference_model')

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol, device):
    src = src.to(device)
    src_mask = src_mask.to(device)
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(device)
    for i in range(max_len-1):
        memory = memory.to(device)
        memory_mask = torch.zeros(ys.shape[0], memory.shape[0]).to(device).type(torch.bool)
        tgt_mask = (generate_square_subsequent_mask(ys.size(0)).type(torch.bool)).to(device)
        out = model.decode(ys, memory, tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()
        ys = torch.cat([ys, torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == eos_idx:
            break
    return ys

# %%
def translate(model, src, src_vocab, tgt_vocab, device):
    model.eval()
    unk_token_idx = src_vocab.get_stoi()['<unk>']

    src_indices = [src_vocab[token] if token in src_vocab else unk_token_idx for token in src]

    tokens = [bos_idx] + src_indices + [eos_idx]
    num_tokens = len(tokens)
    src = torch.LongTensor(tokens).reshape(num_tokens, 1).to(device)

    src_mask = torch.zeros(num_tokens, num_tokens).to(device, dtype=torch.bool)
    tgt_tokens = greedy_decode(model, src, src_mask, max_len=num_tokens + 5, start_symbol=bos_idx, device=device).flatten()

    translated_tokens = [tgt_vocab.get_itos()[idx] if idx != unk_token_idx else '<unk>' for idx in tgt_tokens]

    translated_sentence = " ".join(translated_tokens).replace("<bos>", "").replace("<eos>", "")
    translated_sentence = " ".join(translated_sentence.split())
    return translated_sentence

# %%
print(tokenized_source_sentences[3])
# Out:
# ['ఉత్తరాఖండ్', 'స్థానిక', 'ప్రజలను', 'సాధారణంగా', 'ఉత్తరాఖండి', 'అని', 'పిలవబడతారు', 'మరియు', 'కొన్నిసార్లు', 'గర్హ్వాల్', 'లేదా', 'కుమావున్', 'ప్రాంతంలో', 'వారి', 'మూలస్థలాన్ని', 'బట్టి', 'ప్రత్యేకంగా', 'గర్హ్వాలి', 'లేదా', 'కుమవునీ', 'అని', 'పిలవబడతారు']

# %%
print(len(tok_val))
# Out:
# 12830

# %%
english_pred = []
for sentence in tok_val:
  pred = translate(transformer, sentence, source_vocab, target_vocab, DEVICE)
  print(pred)
  english_pred.append(pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# gopal at our wall now his wall was came on the wall
# delete my shopping list
# many times cough does not get stronger than cough
# if the community does not look at the media because media is getting mature to bring attention on the media because to the
# four layers of on the bank of in some very well
# the roots obtained its aroma is ancient fragrant and full of aroma
# if all these medicines are sold then the health of blood
# ladakh is one of the most populous region in india
# tell me when the comes of areas
# the first three becoming a backwaters at place where sacred fig out water becoming infested with at
# compared to the other than the new born baby is considered to be a
# meena kumari had said to be released on meena kumari chauhan said ashok kumar is said that this situation is
# can you list all the submitted fresh scholarship applications in the academic year on nsp of user with application i d can
# there are four coral reefs and the andaman nicobar islands which are located in the gulf war of kutch and kutch salt
# this expenses is more difficult to make expenses in your fixed expenses
# for full produce the temple of very do not spread around in full are
# by drinking water tourists in evening regularly do a crowd of travellers
# the nearest fruits to reach here is sent to the market
# he used to get these collection where more people get to while collecting crime
# the people of every through style are nepali and tibet then near this three kingdoms live across the borders of the
# for the rest of the nursery should be done
# what s you need for you to buy it depending on what you do
# they enjoyed many soft things saying that they are the out of which poor can be
# those fish and other person are making of an injury in the form of who more
# on first mixing two blood circulation one should massage the over
# according to the aihole inscription set these very you during his empire were imprisoned or a great like to three becoming a noble in s provinces
# st huge church named john at this church of saint him goes to in 1857
# some diseases can also be called reach these
# another storm died during the delta was killed at the delta with this delta
# this is because of our reason we accept farming her was not able to perform like women and men are very active in comparison to
# for the new york tourists opened this shop at a distance of only
# what s the name from which movie is given this music
# the tourists who get less cold india s weight
# send me email to
# if the big sitting is not done on keeping the heart disease then the chance to give bad heart of the
# he is unable to bring out the brain working with normal circumstances etc because of which on not eating many diseases like
# check mail for any mail from said
# in diabetes by treatment special schools related to diabetes is very important
# how many people live in arunachal pradesh
# send email
# if the main symptoms of ulcer are ulcer ulcer could be different people
# according to the people s becoming scared so fast growing culture is point out of view the central culture of india has fallen
# for the entire picnic spot the field of snow is getting mature and life
# as the previous campaign the stateowned oil resources related to gas at the stateowned unit and there are kept in such a
# dense vegetation and plants are covered with snow throughout the year
# at the same time intense pain in the at least and
# in those parks of india that can be reached easily and which has achieved fame wild life tourism has increased there
# justice to its initial stage press council is said to be making him aware of such a situation while losing his debt will be on getting the advice
# generally the grass is not done on this earth
# what alarms do i have set
# on the occasion of delhi 2014 the air service of at of which condition parts were organised in a program at different age club level excess of india whose
# hello has my inbox gone up
# how many valid coupons do not even in the house
# each number of a place twice
# after this very etc get the some tv box office
# the early asian games were you in 1999 and sri lanka on february 1999 and sri lanka
# in dysentery excessive amount of long duration its aroma and camphor oil is less
# wine is tribal such as wine and the body loss of wine
# the current example is of hrithik roshan
# if you buy goods of cleaning your items cleaning and getting clothing items you re often spending less while you re shopping
# for the best wearing a due dates to death an open quite an open every corner of traditions every along with a
# diabetes patients of diabetes are affected with diabetes but due to this disease on how bad effect is on the eyes which does not
# if the big bags can be used to go to the hands feet like an from bonds
# this incident led to a large provincial governments between two regional kingdoms
# he made use of drama which was used very well
# they are also more symptoms of this disease
# one should not wash the person with taking meal s good quality element whose
# seeing the heavy stock of wheat is this within
# the delta is capable of losing a kite once
# the chief reason of the mushroom production on the product is the harmful disease due to ill effects
# on the hand of devi the horse riding went on the shoulders
# the music center of more than british national park is an even on in
# the outer layer of the world over an world s turn was found out on the door of emperor ashoka while can
# the committee has made this matter through selling of citizens on private sectors the media coverage of media coverage of the people s press commission do nt want to perform
# any ideas head of both
# shyam shyam used to cut their skin on and make their skin when
# ok google did angelina jolie leave brad pitt
# do nt forget my sister gift card
# if the layers of then here is essentially the actual needs of a becomes comparatively more at your height
# the do fall of for at then whether the empire was during and 30 years ashoka ruled over 30 years
# count down at the time of the time
# it also is useful for the poor needy and full of acid
# in romantic fruits getting each of cheap goods are getting ready then their main purpose is to
# turn the speaker volume
# in spine a state of attention should be given to
# search page for the in of succession
# coming here for devotees worship and energy at times enjoyed the worship of on house contraction
# in malwa south indian empire several times attacked the western chalukya empire ruled the malwa state on their rule which houses of malwa and in malwa state
# for work of these work the big bags under other machines are used
# there are world markets in the country
# yes i want to know to include latest news
# wild animals get disturbed
# how its possible
# in manyara national park even in eastern africa eastern parks are seen with big mud volcano there
# the private channel tone up to 7 weeks while on 7 early may the vehicle to take the land out from country s
# heavy rains may be cured in the children and the problems of cold storage period
# similar things you can do with vegetables as well
# play i want you again to play the podcast
# there are five rooms made by the island on the island which had five large rooms to get out of the
# the ahmedabad museum is also famous for different species of america american and australia
# massage by the your fingers by moving the circular fashion in a circular fashion
# situated 20 km away from per kilo the main center of nalanda are on 20 kms
# in gujarat the chalukya relations of gujrat are included during the chalukya kings
# in the case of the different ways of farming make sure to daily at the has been seen some times enjoyed by the in
# as per the was situated at the height of them from to in as per the was six kilometres away from production of to in the at
# close to the wide field of human state s there are 12 many including which is presented by cultural he on the
# in swang the entire today is dependent on the one side of some items
# is today the their thanks
# on walls beautiful designs of flowers and powder in water
# the quantity of these seeds are not properly getting 45 times enjoyed
# this number of tourists from 12 percent of the world are in america kerala s united states
# if the big won then this pain arises in the market
# for local tourists the hill station get a tea park yield of new york at 9 kilometres away
# an rail head for getting hurt dudhwa national park is established in dudhwa national park
# what will the weather be today night
# delete the food number on the list
# now this you ll see what you see in which you feel that
# set an alarm for next tuesday at eight am
# for example you can focus on some chronic bronchitis such as at the rate of
# the end of the at the time when sowing is done in the us before five minutes out of a five minutes before the
# breath therapy is not able to bring artificial nails but also helps in several ways to keep getting rid of physical and mental problems
# be silent for thirty minutes
# in hindi cinema surgery times like these are his son to the son of on salman khan state
# there are shops of both for each sides
# if your business trips is done then the address of big bag just on the screen of every
# in many diseases of muscular rheumatism is some part of the body then by controlling the weight of the body after up as well
# after the harvesting the growth of at a right way is increase in the growth of able
# for pure dance also named as at are given a singer named and in lower the dance he is trained where the dance on
# play a r s music
# after working for the security than normal state s goal the time of publishing matter
# then there is a lot of benefit by giving warmth 1 to the whom there is
# hence if the menstruation is put on this side
# it is fully possible if the geographical conditions of not just a as well then new born baby becomes an
# make sure the contact information provided by a reservation for contact information and sure
# land which has been called do cultivation of flora
# for 16 years old shivaji died in the court of bijapur sultan the court held a great camp and remained under the remove of the getting hurt at
# how much percent did i spend on my money today
# if we set a becoming like then
# for some days back the diseases of the whole life will not come
# from october to the colonial work starts in the yet and birds have their border
# however due to the wine is difficult to access this coast
# if the big layers of then lord mahavir was asked
# current local events
# then it flows with water mainly by also keep
# spinal cord has small big established in the spinal cord
# because of this reason they should use some be done
# approximately 20 square kilometers ahead of is set up to may due to losing but the reason of god s design is then the first design of
# a formal only began to worship shri place increase the founder of shri
# every pit is dug by the worm loss below the navel
# if the river is the main territory of then the village is torn out to buy water s published
# good and effective message to development it vessels
# in the year tourists after at the fifth p m to get the event checked at three p m
# for the working people accommodation information related to society who is reaching in
# some women of the royal family should experience the power to patients of different family
# for the big getting an cool wind is this very good
# actually the fibers of lemongrass is cut in oil or loss of 75 percent
# the independence of 1947 from the first stage of 1947 and to be excessive then government
# many unique thing to visit in and more than those tourists who come towards him
# during summer the steps of use in the formation of organic cultivation here is dr
# the food materials should be fed with fat loss of appetite many diseases and gradually produces various diseases
# especially if the birds are sold in to shopping
# here food habits the south india is also sold in the external affairs
# this oil means given us to three types of activities
# once again the related to new hard work is done from everywhere then the plot
# among medicinal plants also grow in the jungle garden
# varanasi is a main religious center it is the hindu religion in hindu cities hence at seven sacred cities like
# in the practice of one should put the palms and hand on the ground
# if the credit of bringing or big movement then the efforts of serious movement is made to bring on the other hand then efforts are being made to bring the next product movement
# in amla based on an cycle of fast growing nutritive elements should be taken
# it is clear from that developing countries of america and other developed countries of which make sure to convert deep and big markets
# on the general public at farming buy lunch its home
# please contact customer care for ola money wallet
# suda nisfi should be done by taking 12 tola medicine eating medicine before going
# in some days swelling of the body she is working at the other she could fully
# please reply to my most recent email
# if tourists get the center of attraction then alone is the main
# if any big they are sold at then the height of to at of with fruits wide and height is 15
# if we are thinking of every pleasant building here
# it is designated by the various different any how
# the nearest plane and rail head from madhya pradesh to bhopal
# the area is dry it becomes dry for growing out
# how much time is it
# apart from self prepared established civil or current president of the raj kapoor has decided to not in the case of the progressive writers association with the association of 10 april disorders
# the music works with an all over the cold storage capacity named to some distance
# for the blue mountain an blue water is located at a height of with then
# in jungle around you will feel about state causes part of them who were at the time of establishing a
# in order to make them this medicine a more eat this medicine
# itching occurs in skin constipation and nausea
# his works like the works of this house used to be kept
# by putting hills in the hills as much loss this species has developed this species of nature there in the same
# the forest of black pepper are found to be primarily responsible for long sticks
# this is one of the largest lakes covering lakes
# i want to want to want the acting and want to see me
# this person who got 13 tonnes of corn is 3 percent shade every day in december also every eight days and
# besides this the chandigarh has been recorded a small range of 2500 units under the same
# while sleeping at night one glass of glass milk does not feel that having milk stay shiny soft beautiful by removing the deficiency of water
# lower volume please
# her life and oral traditional versions of many other written in her life are there
# in hilly areas at a distance of more ancient lake each name of have been do
# the medium of boat increases in developing and boat races is more complete by the medium of
# it is also symbol of human to stay
# although this scheme has been a significant progress in the indian program then journalists can also be emerging before the indian broadcast industry
# where is a close farming
# olly do i have any new email from dan
# if you ’re getting out for window shopping then make sure to make sure so your comfortable clothes will be
# it is estimated to be run by the list of rivers draining into the brahmaputra river india
# the odisha government has signed a private company on port blair s own company s private company based on the food
# in ayurveda it is called paralysis and child becoming serious
# although the state has the largest railway network throughout the country though its typical yield is the sixth largest railway station despite the sixth largest railway
# the storm is expected to get new zealand that die without running on its 24 hours are expected to get
# not this it is also used in this those chemicals which are used
# hence cotton fiber and medium of medium quality is developed in the form of medium
# in winters the ripening of work get taste with its taste and beautiful people
# one plant of the an average generation of 40 kg can be obtained from
# on the banks of the river banks into different industries is sent here
# going to the other corner of an corner famous from a corner of not only use is available
# play some songs for children
# get to settled amidst vehicles the next vehicles
# by consuming 1 morning evening making injection of 1 morning evening due to arunshika there is
# on gulf war gulf war in world and all the other areas
# for the first aid of very kilometers and 3 kms away from production is made 3 kms and on them the journey is
# the area of poor people also here are the last railway station in the valleys
# every newspaper published in a do weekly two weekly also different newspapers fast newspapers and three newspapers can be sung in bengali
# you can control on buttermilk or coriander should get control of coriander by taking 100 grams of fenugreek in food habits
# those who know whether cancer has become out of the or middle
# at a distance of beautiful glaciers is there
# the first of the film of which was presented by three stage of a three stage of discussion on this law was organised
# do you know how to do
# for the production of very well india s medicinal plants and general are exported in the state for rice farming
# by giving sun rays and color therapy just on the medium of sun rays color therapy up to one hundred grams thrice a day in urine stops getting
# the lama tour of india took place in also stones at rupees and is provided you out to 3 rupees per person from every 10
# in the farm of sri nagar not just bring the soil erosion for himself then after becoming about one inches they are not taking in a hot water for half to 20 cm
# due to monsoon depression feels difficulty in turn
# their condition is sold at different places
# in 1972 the state of 1972 since 1972 the state government is 23 years old in every life style below the average age of 18
# the current ruler of union territory was in its presentday area
# alert me about my dentist appointment at two p m
# if this disease is not prepared then many getting mature because of many layers of dust
# one should drink honey mixed in diseases like indigestion bile intestine cough etc
# there are unlimited stock of patient
# some people use saffron on colour
# if the agriculture correct improvements in agricultural development this working is also the mother s milk because the elderly and agriculture of agriculture s
# the cave number is getting stuck in cave number
# there is an ancient times for afflicted with jains
# for the reached considered as if considered the fixed quality of it is worth seeing
# save my date for this afternoon
# the film s love for fun is getting maximum
# those who are not able to get long or who shows up to their muscles or their meaning if we do not go inside anything then disease will also come out
# for the then the you know of the subarnarekha in manipur which include the tributaries of manipur at the hills like
# according to the general agreement the maximum harm to the onion is done in a market for those group of close by
# new shoes will take new shoes during the day
# their family is very attractive and rich in greenery
# have i received any new emails
# view points can also be seen from green revolution head to the dam
# even though this could not come to a survey even though a survey
# for the head of serious national democratic alliance is a situation of style making a trees against big in must
# can my email address if i just got in
# please delete this event
# make sure your business accounts set up on social media accounts so others may follow you
# in such a situation the contemporary of the tradition was seen to wear these clothing stores near me who
# this disease spreads more than aids also because of the blood which goes very easily to the body of other people
# body if the hormones poisonous effect of the body is ignored then bring out to the fat while looking at the
# how is the weather right now
# if women become more in comparison to women with smoking women then the danger of the heart disease increases because they s reaction becomes healthy
# his match should be chosen on the occasion of world s speech are
# turn off my lamp lamp
# if everybody is not making then the government wants to keep the farmers on getting farming then farming of about
# send the report to the customer service
# any new messages do not big messages in my email
# there are four groups of blood a b m i all the blood
# at the storage capacity of the farmers roof as well as the storage
# when do not catch the then hard cold chain
# firstly it is said that with liver with the name of at as if an individual is troubled by life then store the heart beat
# according to these reasons when onion was produced from last year then chance to buy per year when at
# can you give yourself once while shopping for shopping
# in this way contaminated things affect skin directly which causes problems in this disease vomiting and problems occur in this
# it is a point that we should buy our last week
# basil medicine lemon pregnancy should not use for
# in approximately 10000 acres of land per person can be taken out
# patients of asthma make use of patient not doing intoxication
# do not feed had skin diseases due to ultraviolet light
# in the ancient india the times for not 20 with the poor state is completely separated within northern borders of the current
# these bones are not forest set up tigers tiger heart and increasing
# of the of the of of chandigarh view point on the river no doubt reached the high level by govind sagar lake
# if there is not being any effect on the amount of wheat then saying is not saying that the production
# mughal emperor aurangzeb who was set up to the southern emperor aurangzeb had done this place in 24 times for 24 aurangabad
# for the hard work do not feel weight but the capacity of also remains
# america india also established in england canada and with classical artists the scientific interest of classical music not to understand the brain
# indian public school the member of place said 10 journalists plant considered to be a public school when country s school then the school got making a better arrangement making him lie in
# the blood sugar increases by becoming slight carelessness and at the diagnosis of cataract is done
# when i met then i started looking at the first day from seeing him to see her that he is aware to the central nervous
# sometimes cancer of getting damaged cells start
# meet hiv in hiv and infected patients get a chance to areas
# at the second part of this hill in gall bladder rotting
# is it at are not two p m train
# tell them to purchase if they re going to purchase well
# the reserve project of manas national park has been declared tiger reserve
# the cure of this disease can be done by seed treatment by seed treatment
# play a as the playlist of s two
# can you check my rewards on the which i got in the of education
# the best alternative to prevent heart diseases of heart like do not of liver
# in the caves this caves come into existence or a village level different
# resume audiobook
# if the country becomes unconscious then king the getting out of the country
# folding the right leg by lifting it keep it on left thigh with the left thigh and should be below
# in rural areas today only make use of various kinds of diseases are most popular
# the king of king said that king of turn was towards the lower time after some time when my statue is radio made out after losing my own
# yes it is the most artistic taste of the legs national park been made up and out of the it any artistic figures be
# clear every event from my entire calendar
# till a time it was ruled by the portuguese and portuguese in diu
# the height of knees elbows on the ground is a
# worms of stomach starts with of patient of for of has food
# alternately you might be able to lose the debts on some loans because as you re paying this loan in increasing the interest
# in the construction of the initial you used to speak years
# with these instruments the children suffering with cerebral palsy are able to do many
# another example is if people live in the northeast region situated in meghalaya border with assam while the people
# amla oil is a lot beneficial for hair
# you should prevent this water loose motions getting out of gas lemon
# for cataract the solution
# if the big sheet of then press construction of at distance press copy then every characters are
# while paying attention to the public the effective solution of the public
# now my small daughter is to her daughter also she going to the second year by saying her
# it is necessary that you do the practice of such as you must follow it together with you
# after getting down the debt bhima do not buy them at all
# cave number is of little help in cave
# what is the total holding in my apy account with pran number to pran number
# wemo on
# what is the weather
# for the name of than also a temple complex was built in front and four sides of the temple five stars
# in the sectors of this idea increasing green revolution poultry and production of fish etc women are with to pay attention to women
# for full buses also reached the night and vehicles by private vehicles are made
# by doing this the root of maximum nutrients could grow deep towards the nutritive elements consequently is capable of using the moisture
# apart from this pomegranate farming is done in spain morocco iran and airport is being done in big
# this dim on the eyes entrance of light of bed and by which vision reduces
# if the apart from big beach is the largest place in the world s largest
# can you tell me more about the festival
# keeping this on mind the things given below to mind
# i like india is very fond of
# this word can be explained in a word or situation
# the medicines of disease are as follows
# in also very etc mahmood the young man made up to at his empty stomach
# bachchan was less than released in 2009 due to the out of 2009 money
# the works from tamil nadu government has got been awarded in got to be the government
# by constipation he has much of 4 diseases in use of 4 weeks in night while sleeping
# maximum finger will get scared of famous lens
# tweet a complaint about my shoes at
# after independence dr rajendra prasad was started rajendra prasad on its publication
# your most likely to make sure you are nt able to sell your most any things to you
# in like the different becoming pink or to create due to cataract is also big
# at times the problem of vomiting and headache persists
# if the leaf then bay leaf is unable to help feed many types of health related problems
# place takeout for seven p m
# tell me the details of my brother of brother
# these debts are generally small rate and lower monthly payments will make payments run
# besides this the land will be less than the other where ever farmers go on
# girls are problem related to this problem related to their personality because despite losing their personality but now their personality becomes so good you do not feel good to make them know this method
# the child should only be able to say that in women of less age they are unable to
# can you play music by pink a bridge
# if it is not used to raise the door of the whole places through then hotels
# on the song if a apart from each other then state s that for collecting crime and country s becoming
# special emphasis was laid on increasing level from the like national level very high levels of institution so that the institution of very government towards itself in 1989 are sold in chennai bring land management eastern
# in children the danger of infection in deficiency of vitamin a happens more the effect of disease of heart and people can get
# therefore do not wear cotton farming
# please describe an elephant to me
# download vaccination certificate for beneficiary registered with very etc to register
# similarly foreign business has come under the same way of farming related to farming like gardening encouragement and also got done
# for the big significance of krishna river
# raipur city of bastar is near bastar railway station
# in is a shortage of pain relief by not being a
# delhi was one of the most important cities during the world because delhi sultanate was one of the most important major powers of the sultanate
# after that he then named these knowledge of others two months and the again recorded to be a month of jhum cultivation
# add to my calendar every thursday at other thursday
# but if it ’s too sweet milk said “ please purchase it on not just then “ she will accept it to be cut sringeri srinivas simply major or said “
# due to this change there is a different ranges of agriculture
# if the treatment of mental then different types is known by the
# if apart from it protects the body from afflicted years i ve adopted this method by keeping my whole body healthy
# here both of birds are seen completely white marble long with the black deer on which are seen the over red color of blue and
# he will bring more production of the agricultural science center so to do n’t pay attention to the less production techniques of the agricultural
# any recent emails
# it can be identified if our body becomes alright even from normal market
# for the rest of due to an group of at media is there
# if children get regular use it after regular medical stores
# for accommodation at this place is written on this place
# the first muslim five by the muslim date of delhi thus he established the delhi sultanate and the of
# if june or again the journey of then every months can be done here
# the prominent indian in the is the samaj division known as prominent indian gets right from its trees
# mrs gandhi reports say that at first two days mrs of gandhi had started to grow general on in april mrs indira holiday home
# while than some hundred hill station over diet are and on the heart of tourists do not
# in the due of the deficiency of vitamin a it is essential to
# this means you should buy on 10 2000 if you re going through a month
# today the every k are reached at 30 k out of there was no –
# she has many as a related movie related to different films
# this happens with a very reason of tobacco in women in comparison to men
# there are way through enjoying air route therefore also that look for weight and weight
# play next song of my selected
# for the sense of in order to fill out the traditions of karnataka because social change in over men while women adopting the social change by female reforms
# from here the rate of per hectare state of june and then walking again by the last stage
# the kerala city is known by the name of
# so for more produce weeds i need to make more production
# the film yellow fever through her army has shown the first category
# the first channel of will first channel on 1 january 1994 which was 24 hours news channel in india with 24 hours news
# tell me when my next meeting
# right to control or drugs on the disease free by using medicines
# for the breast cancer the set of clan deity is there
# what is the big
# his six like india farming is done in with khyal performance can be any
# near this there is a tiger reserve
# the government of india has become one of the destination man through airways for 300 kilometres in 2010
# the solution of the manure can be reduced on an occasion of planting
# the height of valley of flowers getting out from the sea level is up to
# if your purchases like you visit to find a agency or website
# if full menstruation is stopped
# 54 km the nearest km east from dhanbad is 9 km to east from india
# send an email to john when one will take out home tonight
# this is while land use where by which on the basis of production
# if the economic point of view then do not sowing buy deep and to dense agriculture
# there are multiple benefits at the calendar event
# tweet at whatever i did not receive my order on time
# in between and yamuna is not less any priority is also not done
# farming is done in order to grow more and subtropical regions type
# at some places of assam it is believed to have been put to at some parts of parts wild elephants that the truth is to gather
# remind me to cut the customers and have a nine am on your side river
# if the boat is long length the him is long then it becomes difficult to keep a narrow stretch on their knee
# for the big work of accommodation every months the farmers are getting attracted to
# a wide she had to sell significant performances in tripura and cultural occasions
# as mentioned on being the head of at once wound increases
# now the surgery is done completely getting weather condition of operation
# the government of lakshadweep islands at great time get to see do weight mangalore mumbai
# have i received any message from will plant
# for the national research institute light out in a research institute traditional surgical operation is a company which gives four agency to
# this is appropriate for various areas and give flowers quickly
# recommend me some local shops
# the united nations in had multiple today production of calculating the united departments and such institutions are very high
# both banks are aware of the banks for foreign exchange everyday every day and central bank central bank and america
# in this fever 10 percent of forest create water becomes use in the form
# indian soil is not essential that this technique of potassium is essential
# on channel channel the committee gave it to as said
# while collecting the big at becoming unconscious and then different aspects of cataract
# do i have any alarms set for tomorrow
# save from the food items related to oil a high and fat
# last for the entire food arrangements is made to reach march crossing road
# the the of the place here 64 cells will be keeps on
# 30 km away from dhanbad is the border of bengal where the famous food industry of india has an center of birla and birla agency after arrival
# if the cars on sale then try to out a that designated produce should be according to salman khan s maximum appropriate
# this is no less than a trekking lovers
# when 2003 the name of into the more than 2003
# to make seeds good variety of onion onion is done in the month of april this is a
# after the in also like of of of in is which the east india company prepared a administrative center and 200 course till then
# how many meetings do i get to mr at the last three months who are
# kashmir is known for skiing in kashmir with kashmir
# if the dysentery if dysentery is removed then it should be fed with
# when we set out to the house or outside the house is estimated with too
# however if you are not making the items of items off in may be better if you are
# by making medicines medicine of fennel medicine is also cut in various
# the water is working with the pressure of water had to
# besides the view of switzerland of switzerland can also be seen free from the same and business methods of then
# if the surgery of mint is done on then menthol or an initial kinds of surgery also
# if the new born baby is working at the farm then different kinds of country shows up then walking on which the patient is comfortable up and staying in all the
# if the supply of heart is less or increasing heart damage is done by create obesity getting up from heart fat stuck in big blood circulation to the whole body blood pressure or arteries
# fever nausea dysentery and peace of the brain are cured in which the spinal cord gets absorbed in
# since their land had four parts of pieces for show an the in front of him to paris on the occasion of not damage every vegetable you put into parts like
# siri cancel all the appointments
# it is situated at a distance of 60 kms from itanagar and the road
# the program came to see schools more than 1500 people from a schools
# if the phone is sold in accordance with the submitted renewal scholarship applications by his date palm and beneficiary name is there
# the vedic followers see all the holy dip later on subjects
# thereafter the transaction records of the transaction and government had those officers were confirmed by the records
# there is also a small temple called an here for nine hundred
# depending on the tradition of a garden and time shivaji was about two centuries but after his death in the death of his independence movement he started lifting up rule over the indian independence and land do not let him participate
# satellite tv can be chosen from big television to be an open number
# if the big considered to be the symptom of at then whether the quantity of fibrous substance is done in the quantity of fat and on species
# olly the living room lights changing the color
# in the an eye of brain stops for working and stress of at hand its hair also makes hair shiny and silk cloth
# do you know the name of the song that is playing
# pain occurring due to hernia is very intense
# i need to make a grocery list
# the if a dealer sees working for a long buy bags which shows you quickly reducing yourself or if you ’re india
# the condition of the child should change this way that he keeps lying down in the lap of
# when endocrine glands arise out in enough quantity then our health remains perfect but in case of the opposite our health to keep them healthy under any condition of the opposite our health
# a lot of wine has spread in italy making its best
# due to its extremely beautiful attraction of lakshadweep is known as exercise for indians from lakshadweep
# as a result skin is flexibility of skin
# on the death rate of new land or death he are five good south
# for then the in gujarat river flows gujarat south tripura and vadodara district
# recipes
# such as due to the of into present are excellent medicine to emerge to emerge the
# by the evening i get the food available on the
# for full development of new countries the chief of developing countries is a problem
# if the crop wants to get less damage than the seed then it should be cultivated
# the elections were drawn
# in these the characters there are two kinds of characters called and
# if your income is sold or you can shop around with unexpected expenses or because you can change expenses in market stock at the unexpected
# remember that there is a safe storage facility was several times for with only
# on 8 july of in of of of of in of of of in is then different at land four
# if the child is working to take special care of the child
# on
# which increases death on the muscles of heart because of which the part of heart beat increases
# in dwarka from outside we can go to the island group on boats
# recent headlines
# meghalaya has made food grains of 2001 a of patient to of with
# at the same place of these stock researchers have should never seen that heart attack the heart attack of heart beat
# bharatpur is the residence of wild life at first place where wild boar to be here
# if the them is done from here then wild life cycle has been reached in tropical evergreen forests then out of subtropical wild
# the farm which has good yield of farm
# the menstruation cycle which is available for the next ones
# it was founded by the arab traveller ibn and the she was developed in other areas from india
# the waterfall of on while biggest waterfall is simply to go in forests
# tweet my order at one hundred p m tweet to customer service that i get a hundred p m customer service
# once the rock houses which are still kept in a state of human welfare charitable trust and then the families line of big plant will be center to center at the
# how much attention was to stop the districts of does her vision enough and he was also inspired by him
# in 16th century several texts mention her of which the first muhammad of her in malik kafur to be struck by malik kafur in
# if the long growth rate of long then this section will give you a good idea of that company is s body
# for right now the air route but the estimate of it is being done towards
# only this if the job is not taken out of our emotions and we get out of our internal
# can you check my rewards set on amazon what s on
# turn on the wemo plug
# in where one or the other parts of these days the crop getting mature is done at other place where the need of water is done continuously for growing the water bodies
# in meghalaya forests its extremely rich in asia are considered to be
# talk to mom about mom
# there were several types of flowers on the side where some people quickly made available to cover the clothes on moving ahead
# of the more than of with are kept safe and they grow
# the film was released on 24 april 2020
# turn off a lamp
# can you turn lower the lights in the twenty percent
# mumbai is the gate of india and commercial city
# in this matter the farmers do not need to sell the capacity of then
# in the last stage of the farm 10 percent treatment should be done by putting 20 kilogram of soil in
# the following rulers asked the title farming of nizam to create a title patient or are known as through fast growing
# at surat the chinese for him is sold
# often one variety is given many names
# if you are not having the police yet take it out the in a the the
# after three days in our research he was sent to him on a village street fight to get him
# there are very much even in sri lanka in the temple of find a walls in far east india and on 6 miles
# special train silver is available in special attraction here
# meghalaya received on 21 january 1972 as its own state status
# normally women do not get interest with then ill effects on s even though
# if significant death rate of significant agents are called the within cell bottle set up to then the wood
# it could be a part of the city where the far ahead is like
# this treatment is quite expensive and dried up
# try to keep your body healthy at an interval of every two at one end out every night try to
# the most main reason of diabetes is that disease is produced due to diabetes
# heart is between the two lungs strong different from the left side of sixth pay attention to it
# the restaurant include on darjeeling restaurant on new york road transport road dr a with while parts of new york road goes to the on the road route road
# you can use new york times or they are sold for
# but this quality of flowers get down s weight becomes the effect of while controlling the yield of on then he
# the arrangement of boating is available in the valley of boating
# very soon for farming is getting farming done but it does not be possible that any time between environment to at the development of environment
# after busy during the busy work of then from here people have to see approximately 20 feet which is situated at
# in the east to west the bay of bengal are within the
# the largest coal fields in the state was the largest coal district in
# like children tonic as a tonic for children
# madhya pradesh also one of the kingdom to parts
# paralysis if paralysis are included in the other form of to be
# if you ’re not comfortable then too much use the clothes for making him becomes disease free and seen from getting your sitting on the
# due to this it would help prevent the causes of aging
# for the different states motor travellers used to enjoy the water while sitting or then five stars can enjoy fun and again
# in national institute museum about 70 percent damage the national institute of disease raised people
# on skin by the upper layer of these spots no one should feel that nerves get damaged fall below the spot
# in amla based on an give rise to the situation of human also every
# if the arteries of their brain then different kinds of at farming is going to many
# although mosquito from mosquitoes that mosquitoes for protection against mosquitoes and in front of mosquitoes bite in getting out
# the focus of on set up is the international protest protest and disease are
# do you know the weather you know
# your stomach should send each person home and getting 20 minutes after your face will soon be able to every 15 minutes after doing if you send
# for the deafness can be the disease of deafness stage the swelling of ear and right
# people who spend life long life by saying the people as well because of the changing sun pure air water of
# maximum production of big very government and union territory some time to control movement
# remind me about my anniversary of me a day
# zika granted the first permission in june 2016 to be country in the can its be agreed for
# what time is it in london right now
# after the metro channel launched more hours in television program was started
# tell me what the world news headlines on
# she was then immediately start b c music thus he is working in history
# if the contraceptive pills then vaccine would be given
# if the big at farming of then call center of only due to vidya balan up from the neighbouring country are
# if the ulcer acidity may be produced from blockage in stomach then ulcer gets destroyed by ulcer or ulcer
# its shape is at a distance of 2 kilometres from on the number of but a big his english to be
# following the satavahana empire and the satavahana empire further divided into five smaller kingdoms
# the also is expected to create from the had done is that significant wave of
# it is situated on the name of level werkudara had the son of brahma sarovar on the name of brahma
# in november 1970 the tropical
# if gandhi had done the then abdul parts of the gandhi to abdul parts khan abdul parts of pune and to etc
# while car dealer can set up to on entrance in manyara national park
# please add appointment at the doctor before said to be wednesday at the office
# if the big hard work is done then whether big change is the newspaper
# the nearest statue of over kangra is situated around bed
# the malabar coast of malabar it was said to be the general expression provided
# organic fertilizers will sell them potatoes rice potatoes etc
# an extremely six hundred and does not accept the style according to is again the clothes made of at different places are built by situation itself
# hence the people who should take the problem of high accident that is often causes of defect in high accident or are suffering from rheumatism by starting of the patients in
# save my music to do list and keep
# what s the address of brad pitt starred in
# one of the total number of total total he has been trying to also in
# uttar pradesh jammu and kashmir is located on the north eastern part of jammu kashmir uttaranchal rrb eastern
# in karnataka s first dose flowers of flowers are in karnataka
# fever swelling or an are seen on swelling in fever before swelling or big disorders extremely light
# on occurrence of a chance of not paying direct symptoms by the joint summit
# which increases death on the muscles of heart because of which the part of heart beat increases
# if again go on then before bed applying powder 2 grams grinding black pepper mixed in equal quantity then eat
# the first five hundred years of
# the history of 19th century becomes the history of journalism
# after getting the vaginal discharge at least once again and use of vaginal irrigation on the for ten days
# in most famous 10 percent land is made for black pepper
# your that classes should be 180 than on twitter for
# what are you making your guests drink if they come to know of it even slightly then people will run away from
# the different as per not is god shiva
# the region is a major waterfall designated as the largest sources of human from mineral resources
# this within light cough can also be used
# in which few months death of patient arises
# but in 1990 the gulf war of gulf war of gulf war and while crossing private channel on private channel cnn
# all roads and night bus services are available from shillong to all major towns of meghalaya and night by the northeastern states including independence
# brother we call the hands of to people the east but raising awareness
# it is situated on 17 km from warangal and to 80 km from warangal and warangal
# it is used for pimples pimples and red blood
# this is famous for its natural at different becoming extinct
# but what day do you think about the day you are thinking that sleep on time of these day it can
# alauddin was a nephew and a nephew while his nephew
# the british army suffered a of small town amer and later on the mughals been killed by bijapur government towards itself after bijapur government wants to accept his attention
# ultimately becomes a patient of man
# current time in new york
# if the big surgery is done on 2 or more than that job
# according to
# if hindi cinema is getting out of any things then they could be sold to his km
# ...
# in cinema its name is known with the name of oxford war
# the states that northwest of the march are heavily patients across northwest and before the
# send me notifications before buy bags to the citrus set
# as well there is a lot of color in hair as its fruit will be visible
# in all these countries one should not do any serious injury fast growing it s finger tips
# after sowing it can be taken from its age till several years
# stop forty minutes of forty minutes
# it is not an matter to be said condition of land
# i want to get enrolled myself in an institute offering programs in engineering and technology i get a list of such institutes in
# the indian journalists are actually writers for serious discussion on the indian journalists
# on not all weeks you were given to three weeks
# for the angle of getting it into eight am
# the western ghats and mountains on the slopes of the himalayas are formed in the eastern ghats
# he got sitar education from his father late khan
# play rock playlist
# but in soon as jahangir made out frequently do the the a the the the the
# of ten people s elephant becomes the district second to getting him
# to if s
# for this the requirement of more amount of oil was done then getting away from the skin disease s as well
# if the capital of delhi is then due to open
# the world famous jagannath temple jagannath temple who is being do not accept
# alexa keep classic rock
# the kumbh fair held in winters every twelve years on the banks of the ganga river lies within an major festival of twelve
# in the language of different this patient is called see his patient
# set india on delhi sultan in with its of so much all tughlaq dynasties including of in
# his work was also true that the duties were farming of an are two three the pain that he practiced by the music lovers
# on not uttar pradesh that not the national park new zealand do the traditional cycle of could be operated or
# if you ’re not able to understand the one thing then do n’t understand the things that instead of doing things go on
# charming scenes filled all around the heart makes it from mind
# under the fort of southwest situated a small fort is called an open gate
# show the business number of very email
# if the person does not get into sleep then he did not
# there are numerous sites including environment tourism which are a famous national park and valmiki national park
# the patients of tuberculosis are working at a small place so that tuberculosis has full family
# who is the good man
# for the harvest crop should be dried after drying up for the market
# if you re looking like then finding out a specific item will likely to fix it
# the branches will get to do very few days
# this is called the place of a which is called
# show me the weather tomorrow
# who should start my calendar high after wednesday at eight hundred and six hundred
# you can help your debts to get your debts the different government
# if the big yield is not keeping the farm free from then also
# here is also big building from within also today
# for the centuries only such a system where traditional medical sciences is available to follow the people who follow traditional rules of
# suddenly if any accident or becomes old then to do surgery then to keep eye treatment instead of
# you can also call the repair of your research by which you can know that its repair and expensive than what you
# hanuman temple at her place but a group of walking on the temple is visible but you can see if there
# it is generally seen from the perspective of settlements on increasing at the beginning of 15 or more years later to see the point
# how do you buy
# on the leader of the life cycle future goes to
# considering this land to be human heads is reported to be the reach here and later different from royal
# set alarm for nine am
# to these spots sonu nigam in the film
# jokes
# this compound interest is 75 percent interest on the type of per year
# if any disorder or loss of then digestion can be cured away
# olly where is my house to
# in october for controlling groundnut in groundnut spray one hector of mustard oil or in place 75 percent of making a powder 25 kg per hector
# its own useful for removing the island of north button island is its own useful for its own
# according to some records an records of out cancer and getting is called them
# the first being at the becoming are then second even though an came to is
# travel ticket
# for full fervor kashmir university is the main university of this area
# for this needs you can find out how much you are getting injured in the emergency fund if you ve checked up every
# due to the high shine of snow the water flows here through airways
# if the mauryan period had done various aspects of mauryan gupta especially market their c news agency
# in some food substances there is fibers of each other
# but women do not only men but women are also popular men but women do not become highest in popular dance
# can you set my sisters location for this event
# by applying cough coughing repeatedly getting out of it is extremely harmful
# remember to cut out to be your favorite items for the life you might not
# in order to fight the ability of mineral capacity and other diseases getting up to others are
# she says that the way there is a reaction on the skin by the
# in april 2006 the leaders were carved out of 15 april a meeting with element of africa
# the at the indian then with in india whether abundance of only on the thar desert is done
# set sure that tour this agreement was always on a those afflicted with him while controlling the risk of then getting
# on the set of in on due to into then as the on below is
# in such the situation only those women should continue to grow and work according to
# affected plants their yield is reduced and production capacity also
# a nepali army led to two further generally in india rana is also led by the nepali effect of lucknow in different parts of india
# country s total if full of producer is 64 part of the country s agriculture is
# chand spent his last days in uttar pradesh english she spent his in north india
# their names are plot to be normal
# at the present temple there is a myth behind the foundation of the
# the food materials rich with iron magnesium and vitamin c are given in excess quantity
# in the rampur of this time there was of ancient capital for
# in the country there is little ghee oil and food grains which do not have
# his economic movement was also a lack of low per
# i liked the audience sitting on
# please call an taxi to four hours and mark me the theater to be sent
# such a compost is called super compost
# what s the cheap price for the first book fair
# its plant is made on both sides by the branches and country becoming smooth
# siri play my pop playlist
# according to this agreement satellite tv is running on satellite tv with satellite broadcasting system various from satellite tv can be shown
# traditional the if akbar is applying to her religious heads the in his empire some is particularly certain in the state of islam and through an even humid change
# remove everything from the calendar
# valmiki national park has taken from near then also by the railway
# on occurrence of exercise in nervous system and hands feet get help in reach
# will it be nice on friday
# the climber does not get oxygen fully before
# but at present it is related to the girls getting out of these girls even if they are
# what is the capital of philadelphia
# for full needle injection or country the injection is getting mature
# it has been proved much better known for its own practical
# hinduism is the main religion of the population of hinduism to it
# the second longest river of kerala is one of the major tributaries on the major tributaries of the kerala river
# the virus of nose at first 10 to 12 days when the flow of nose occurs due to the through air route infection and it occurs in other
# on an actual occasion reach the here to getting is areas like putting hand from has
# according to the rules of place at the meeting there is a chance of making the sugarcane juice of sugarcane by
# where to buy cannon cameras
# this means that if it is used to happen in any kind of problem then the people suffering from rheumatism to of
# in the production of expensive and high seeds by making the farm so that the product of high quality will be sold at that
# in this more than its biggest medium market is as follows
# the indian army staff s generally took assistance of reducing the indian army
# by go to market through market there is also the knowledge of better and then in front gets there should not be any focus
# keeping the water starts getting sleep at that time
# do takeaway this restaurant
# turn on the rice very rice very high
# it is a pilgrimage for bihar state under bihar
# journalists of to journalists better in the river are found in the shape of the ganges
# olly the the the at the whenever he wants to get out from work to species
# seeing it the does not die louder
# the statue of on every side of as soon as winters is sold
# the southwest monsoon lies to the bay of bengal arm and the arabian sea branch of the
# for the black at times due to into with the late out of royalty pandit ravishankar the music of gandharva college is highly national movement
# the hindu religion of kerala during the reign of justice made in which the bhakti movement saw the period of hindu
# every two years later the pilgrims gets organised here
# you will remember to make a model that the place agricultural or a certified public ’s
# in patient s benefit from getting intense pain in right world
# fast growing distillation in possible the distillation process is going to
# the highest average rainfall is in july august
# please turn off the lights in this room
# in one stage the marriage of marriage to be a man ’s age she starred opposite to avoid her daughter who is put
# gandhiji s journalism will be chosen on the floor
# according to dr an average temperature of two hours at four hours is not completely appropriate to create obstacles but after some hours patient can
# how should i do the next street
# in agricultural technology he big not demanding to raise the surgery then he puts his treadmill to light at some distance
# alternately you can see the according to focus on the getting a or not bring on the grown
# homeopathic medicine good if menstruation is caused by the beginning of some part cramps in the early body and soft
# dimapur to see kohima is situated on the out of to style bring do not forget to buy
# that year he appeared in the bengali film through hard to at tamil nadu then the bengali film parts of bengali
# according to the 2015 tiger reserve in bangladesh 2015 tiger reserve is approximately 180 km
# with whom hari ki of vegetable was kept in this place then also went to his life
# show all vaccination centres in area with pincode a age group 18 years can get free to people from age
# while the last menstruation for becomes the strong pala emperor ashoka up too much is making his territories
# what s going on for the event
# before the mughal era of mughal era was not done by the indian hindu temples in north india
# now in educated people had a good newspaper
# the organizations like india the demand for achieving this very earth
# if rose sandalwood lavender lavender over are helpful in are then help
# for this there can be juice tomato lake in onion
# maharaja before maharaja the maharaja of maharaja and maharaja the maharaja of maharaja are given to maharaja towards his sons uncle and kumar were given were
# the mountainous area is the most charming waterfall
# for state to 1963 the tamil telugu malayalam covered state include malayalam till date of tamil nadu
# it is the second largest city in ladakh and later the second largest
# getting an copper be bought through species of at times like place the arab and egypt will
# what music did her birth play shows an successful role in to new york at her birth character he played a successful
# if there is infection or not any bleeding also can be done immediately
# the evergreen river covered with the banks of the slopes are situated at a distance of 13 kms from gaya
# important home information
# pulakeshin ii then the
# the patient can told that blood should get anemia is called minimum on other hand
# make me this song if its layers then
# narmada river was sent by the tour to the narmada river
# please set up the results of june to the it set for the production
# in the music music role of becoming a like india health he is climate
# if the sea drinks take oil leaving the sea then it will also be big publication in water
# top model car
# by sowing the farm at an interval of sowing the farm soil get help of useful technology done at farming of then it is possible that
# land is made in compost or leaves getting up to at times enjoyed the capacity to at other whether
# how much will cook trump on today
# the nearest sanctuary in india is also that in any sanctuary the kanha national park which does not
# ok google tweet to at becoming a g m t v
# here not only the ordinary component can be decorated with the increasing grandeur and at the form of a
# show latest news from new york
# explain what is next
# take the juice of green vegetables and vitamin a
# resume the playback of in the more than of
# besides the destroyed fort there is a fort of large market in india made up of black market improved movement to out areas whose peak
# all the main credit score be women in a but studies like before joining cards then means credit cards debit card and cards may even
# the architecture of the on the indian subcontinent has been influenced a well
# due to these scholars who are symbol of their special architecture movement to the wall of the patient not
# what times you are often used your gym is used on
# play chess with me
# it is also true that if half to get half shoes then at clean your stomach and if you do n’t go to clean then if you should take out of being out of occurrence of constipation gas piles then whether you
# the main gate of bastar is at the main door of bastar temple
# pine trees cedar and cedar are found at the low height of different
# do i change this light to
# for the first world s vision construction set up on the gym and gym
# goa is active in goa s white life yet and world heritage list for world heritage sites situated on the world heritage list for every year
# make sure to do a work in your soil at the working bag for you
# using my freecharge account will die using my freecharge
# that vehicle will take a car while losing the bus stand out through at other side he went to radio
# this occurs due to some problem
# as a result the editor of due to an effective promotion and war is called
# when the bark of disease while on the bark small spots are removed
# but if its basic colors then on 15 minutes of making the normal bottle of india is usually given two or
# if big plant is practiced in the then getting out of circulation weight is done in the direction of dog sitting
# according to his famous found gavaskar was tour to india next day and actually she was appreciated to the percent
# turn off the no in the of
# do i want to exercise
# turmeric mix a juice of turmeric and mixing in eyes below the eyes
# some people are watching ice skating for people but some can play the artificial games made with help games
# test of location is done of the lists
# then come in the shoulder by shoulder movement
# the dry court did not accept any done by at of has happens the to within also happened close
# this disease has become the effect of nature that nature has achieved the effect of
# their architecture is also so simple that market is no one
# districts her story if at the story of then normal state place she wants to hear normal but forest of reading between the class
# the central government has the power signs on national importance being like a national importance
# actually our hearing power should be ten steps beyond our hearing power
# among the animals of simlipal national park are becoming dry like are then it takes
# could you delete my shopping list
# with regular exercise food etc is done in the fort even today
# even today the bigger dam is not visible to the big hall

# %%
import csv

# Create a list of dictionaries where each dictionary represents a row
data = [{'valid_id': valid_id[i], 'english_pred': english_pred[i]} for i in range(len(valid_id))]

# Specify the CSV file path
csv_file_path = '/gdrive/MyDrive/phase2_tel2.csv'

# Define the column names
fields = ['valid_id', 'english_pred']

# Write the data to the CSV file
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()
    writer.writerows(data)

print(f'Saved predictions to {csv_file_path}')
# Out:
# Saved predictions to /gdrive/MyDrive/phase2_tel2.csv

# %%
print(len(english_pred))
# Out:
# 12830
